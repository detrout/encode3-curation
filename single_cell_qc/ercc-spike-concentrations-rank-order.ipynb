# %% [markdown]
# Labs submitted tsvs for their spike in concentrations, they are of course formatted differently.

# %%
import pandas
import os
import collections

# %%
from load_spike_table import load_spike_table

# %%
spikes = load_spike_table()
spikes.rank()
# Out:
#             Caltech Single  Caltech 1000x  Gingeras-Ambion Mix 1  \
# ERCC-00002            90.0           90.0                   90.0
# ERCC-00003            81.5           81.5                   81.5
# ERCC-00004            88.0           88.0                   88.0
# ERCC-00007             NaN            NaN                    NaN
# ERCC-00009            81.5           81.5                   81.5
# ERCC-00012             9.5            9.5                    9.5
# ERCC-00013            27.0           27.0                   27.0
# ERCC-00014            39.0           39.0                   39.0
# ERCC-00016            15.0           15.0                   15.0
# ERCC-00017             9.5            9.5                    9.5
# ERCC-00018             NaN            NaN                    NaN
# ERCC-00019            57.0           57.0                   57.0
# ERCC-00022            73.5           73.5                   73.5
# ...
