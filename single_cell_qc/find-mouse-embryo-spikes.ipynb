# %% [markdown]
# # Introduction
#
# Brian wants "all of the spikes data from the mouse embryo series (e11.5, e13.5, e14.5, e15.5, e16.5, but not P0) and combine it in to 1 table of FPKM values"

# %%
import pandas
import numpy
import os
import sys
import time
import collections

# %%
try:
    import save_rnaseq_madqc
except ImportError as e:
    print("Launch notebook server with startnb")

# %%
query_url = 'search/?type=experiment&assay_term_name=RNA-seq'
cache_name = 'rnaseq-experiments.shelf'
cache = save_rnaseq_madqc.caching_encoded_experiment_loader(query_url, cache_name)
# Out:
# Reading 140 of 1408 records in 0.09593840200068371 seconds
# Reading 280 of 1408 records in 0.042379406999316416 seconds
# Reading 420 of 1408 records in 0.04536383199956617 seconds
# Reading 560 of 1408 records in 0.033109973001046455 seconds
# Reading 700 of 1408 records in 0.06831830400005856 seconds
# Reading 840 of 1408 records in 0.024399958998401416 seconds
# Reading 980 of 1408 records in 0.31791950300066674 seconds
# Reading 1120 of 1408 records in 0.25477535000027274 seconds
# Reading 1260 of 1408 records in 0.034925001998999505 seconds
# Reading 1400 of 1408 records in 0.06976228500025172 seconds
# Read 1408 records in 0.9868920169992634 seconds

# %%
def find_mouse_embryo_experiments(cache, limit=None):
    """Look for wold mouse embryo experimments.
    """
    experiments = []
    for i, experiment_id in enumerate(cache):
        experiment = cache[experiment_id]
        experiment_lab = experiment['lab']

        if experiment_lab['@id'] == '/labs/barbara-wold/':
            for replicate in experiment['replicates']:
                library = replicate['library']
                library_id = library['@id']
                starting_quantity = library.get('nucleic_acid_starting_quantity')
                starting_units = library.get('nucleic_acid_starting_quantity_units')
                biosample = library['biosample']
                biosample_id = biosample['@id']
                life_stage = biosample['life_stage']
                age = biosample.get('age')
                age_units = biosample.get('age_units')
                biosample_term_name = biosample.get('biosample_term_name')
                organism = biosample['organism']
                species = organism['name']

                if life_stage == 'embryonic' and species == 'mouse' and starting_units == 'ng':
                    pretty_age = "{} {}".format(age, age_units)
                    experiments.append((pretty_age, biosample_term_name, experiment_id, library_id))
                    print(experiment_id, biosample_id, age, age_units, starting_quantity, starting_units, biosample_term_name)

        if limit and i > limit:
            return experiments

    return experiments
    
experiments = find_mouse_embryo_experiments(cache)
#grid
# Out:
# ENCSR347SQR /biosamples/ENCBS896ZED/ 13.5 day 10 ng limb
# ENCSR347SQR /biosamples/ENCBS176PGP/ 13.5 day 10 ng limb
# ENCSR541XZK /biosamples/ENCBS066IEL/ 11.5 day 10 ng limb
# ENCSR541XZK /biosamples/ENCBS681XPR/ 11.5 day 10 ng limb
# ENCSR906YQZ /biosamples/ENCBS355TAQ/ 15.5 day 10 ng stomach
# ENCSR906YQZ /biosamples/ENCBS915SZN/ 15.5 day 10 ng stomach
# ENCSR792RJV /biosamples/ENCBS185VNZ/ 13.5 day 10 ng midbrain
# ENCSR792RJV /biosamples/ENCBS725LVX/ 13.5 day 10 ng midbrain
# ENCSR343YLB /biosamples/ENCBS825LGT/ 14.5 day 10.0 ng midbrain
# ENCSR343YLB /biosamples/ENCBS849BXE/ 14.5 day 10.0 ng midbrain
# ENCSR928OXI /biosamples/ENCBS431CVS/ 14.5 day 10.0 ng neural tube
# ENCSR080EVZ /biosamples/ENCBS156DHU/ 16.5 day 10 ng forebrain
# ENCSR080EVZ /biosamples/ENCBS512LKA/ 16.5 day 10 ng forebrain
# ENCSR020DGG /biosamples/ENCBS955JPC/ 16.5 day 10 ng heart
# ENCSR020DGG /biosamples/ENCBS217XWR/ 16.5 day 10 ng heart
# ENCSR504GEG /biosamples/ENCBS731ALA/ 14.5 day 10.0 ng kidney
# ENCSR504GEG /biosamples/ENCBS454WSU/ 14.5 day 10.0 ng kidney
# ENCSR752RGN /biosamples/ENCBS811RMD/ 15.5 day 10 ng forebrain
# ENCSR752RGN /biosamples/ENCBS841GER/ 15.5 day 10 ng forebrain
# ENCSR867YNV /biosamples/ENCBS314UPI/ 14.5 day 10.0 ng liver
# ENCSR867YNV /biosamples/ENCBS237YNZ/ 14.5 day 10.0 ng liver
# ENCSR284AMY /biosamples/ENCBS522YOW/ 11.5 day 10 ng liver
# ENCSR284AMY /biosamples/ENCBS746POP/ 11.5 day 10 ng liver
# ENCSR115TWD /biosamples/ENCBS956BQY/ 13.5 day 10 ng neural tube
# ENCSR115TWD /biosamples/ENCBS549OYR/ 13.5 day 10 ng neural tube
# ENCSR216NEG /biosamples/ENCBS471PIU/ 14.5 day 10.0 ng limb
# ENCSR216NEG /biosamples/ENCBS300NIO/ 14.5 day 10.0 ng limb

# %%
sorted(experiments)
# Out:
# [('11.5 day',
#   'embryonic facial prominence',
#   'ENCSR848HOX',
#   '/libraries/ENCLB331VAA/'),
#  ('11.5 day',
#   'embryonic facial prominence',
#   'ENCSR848HOX',
#   '/libraries/ENCLB761PCA/'),
#  ('11.5 day', 'forebrain', 'ENCSR160IIN', '/libraries/ENCLB471QMM/'),
#  ('11.5 day', 'forebrain', 'ENCSR160IIN', '/libraries/ENCLB835LVO/'),
#  ('11.5 day', 'heart', 'ENCSR691OPQ', '/libraries/ENCLB347FRI/'),
#  ('11.5 day', 'heart', 'ENCSR691OPQ', '/libraries/ENCLB601XLL/'),
#  ('11.5 day', 'hindbrain', 'ENCSR760TOE', '/libraries/ENCLB061TDP/'),
#  ('11.5 day', 'hindbrain', 'ENCSR760TOE', '/libraries/ENCLB454ZUS/'),
#  ('11.5 day', 'limb', 'ENCSR541XZK', '/libraries/ENCLB495FUZ/'),
#  ('11.5 day', 'limb', 'ENCSR541XZK', '/libraries/ENCLB979DZW/'),
#  ('11.5 day', 'liver', 'ENCSR284AMY', '/libraries/ENCLB055KYV/'),
#  ('11.5 day', 'liver', 'ENCSR284AMY', '/libraries/ENCLB357KYA/'),
#  ('11.5 day', 'midbrain', 'ENCSR307BCA', '/libraries/ENCLB426JKF/'),
#  ('11.5 day', 'midbrain', 'ENCSR307BCA', '/libraries/ENCLB659UFY/'),
#  ('11.5 day', 'neural tube', 'ENCSR337FYI', '/libraries/ENCLB162EJJ/'),
#  ('11.5 day', 'neural tube', 'ENCSR337FYI', '/libraries/ENCLB627LDZ/'),
#  ('13.5 day',
#   'embryonic facial prominence',
#   'ENCSR538WYL',
#   '/libraries/ENCLB032PUJ/'),
#  ('13.5 day',
#   'embryonic facial prominence',
#   'ENCSR538WYL',
#   '/libraries/ENCLB304NDN/'),
#  ('13.5 day', 'forebrain', 'ENCSR970EWM', '/libraries/ENCLB177SFU/'),
#  ('13.5 day', 'forebrain', 'ENCSR970EWM', '/libraries/ENCLB807ODU/'),
#  ('13.5 day', 'heart', 'ENCSR284YKY', '/libraries/ENCLB351WRP/'),
#  ('13.5 day', 'heart', 'ENCSR284YKY', '/libraries/ENCLB690TFQ/'),
#  ('13.5 day', 'hindbrain', 'ENCSR921PRX', '/libraries/ENCLB312IAF/'),
#  ('13.5 day', 'hindbrain', 'ENCSR921PRX', '/libraries/ENCLB517UIN/'),
#  ('13.5 day', 'limb', 'ENCSR347SQR', '/libraries/ENCLB238AFW/'),
#  ('13.5 day', 'limb', 'ENCSR347SQR', '/libraries/ENCLB724HXC/'),
#  ('13.5 day', 'liver', 'ENCSR448MXQ', '/libraries/ENCLB504REE/'),
#  ('13.5 day', 'liver', 'ENCSR448MXQ', '/libraries/ENCLB863LLT/'),
#  ('13.5 day', 'midbrain', 'ENCSR792RJV', '/libraries/ENCLB051RZO/'),
#  ('13.5 day', 'midbrain', 'ENCSR792RJV', '/libraries/ENCLB426MFX/'),
#  ('13.5 day', 'neural tube', 'ENCSR115TWD', '/libraries/ENCLB302GKB/'),
#  ('13.5 day', 'neural tube', 'ENCSR115TWD', '/libraries/ENCLB327XFF/'),
#  ('14.5 day',
#   'embryonic facial prominence',
#   'ENCSR823VEE',
#   '/libraries/ENCLB015WCJ/'),
#  ('14.5 day',
#   'embryonic facial prominence',
#   'ENCSR823VEE',
#   '/libraries/ENCLB254AMJ/'),
#  ('14.5 day', 'forebrain', 'ENCSR185LWM', '/libraries/ENCLB336GOL/'),
#  ('14.5 day', 'forebrain', 'ENCSR185LWM', '/libraries/ENCLB964APA/'),
#  ('14.5 day', 'heart', 'ENCSR727FHP', '/libraries/ENCLB584VFZ/'),
#  ('14.5 day', 'heart', 'ENCSR727FHP', '/libraries/ENCLB931ORG/'),
#  ('14.5 day', 'hindbrain', 'ENCSR559TRB', '/libraries/ENCLB567WFL/'),
#  ('14.5 day', 'hindbrain', 'ENCSR559TRB', '/libraries/ENCLB989QNS/'),
#  ('14.5 day', 'intestine', 'ENCSR932TRU', '/libraries/ENCLB030NEC/'),
#  ('14.5 day', 'intestine', 'ENCSR932TRU', '/libraries/ENCLB156EMG/'),
#  ('14.5 day', 'kidney', 'ENCSR504GEG', '/libraries/ENCLB813BQB/'),
#  ('14.5 day', 'kidney', 'ENCSR504GEG', '/libraries/ENCLB949WIO/'),
#  ('14.5 day', 'limb', 'ENCSR216NEG', '/libraries/ENCLB906TKN/'),
#  ('14.5 day', 'limb', 'ENCSR216NEG', '/libraries/ENCLB949YQN/'),
#  ('14.5 day', 'liver', 'ENCSR867YNV', '/libraries/ENCLB200EFP/'),
#  ('14.5 day', 'liver', 'ENCSR867YNV', '/libraries/ENCLB278MMD/'),
#  ('14.5 day', 'lung', 'ENCSR039ADS', '/libraries/ENCLB220DVX/'),
#  ('14.5 day', 'lung', 'ENCSR039ADS', '/libraries/ENCLB819PZM/'),
#  ('14.5 day', 'midbrain', 'ENCSR343YLB', '/libraries/ENCLB000EUQ/'),
#  ('14.5 day', 'midbrain', 'ENCSR343YLB', '/libraries/ENCLB597GRF/'),
#  ('14.5 day', 'neural tube', 'ENCSR928OXI', '/libraries/ENCLB214UZM/'),
#  ('14.5 day', 'neural tube', 'ENCSR928OXI', '/libraries/ENCLB377PCX/'),
#  ('14.5 day', 'stomach', 'ENCSR290RRR', '/libraries/ENCLB409LKR/'),
#  ('14.5 day', 'stomach', 'ENCSR290RRR', '/libraries/ENCLB595PNG/'),
#  ('15.5 day',
#   'embryonic facial prominence',
#   'ENCSR636CWO',
#   '/libraries/ENCLB150ZJS/'),
#  ('15.5 day',
#   'embryonic facial prominence',
#   'ENCSR636CWO',
#   '/libraries/ENCLB256STD/'),
#  ('15.5 day', 'forebrain', 'ENCSR752RGN', '/libraries/ENCLB373ANW/'),
#  ('15.5 day', 'forebrain', 'ENCSR752RGN', '/libraries/ENCLB567JQE/'),
#  ('15.5 day', 'heart', 'ENCSR597UZW', '/libraries/ENCLB526KEI/'),
#  ('15.5 day', 'heart', 'ENCSR597UZW', '/libraries/ENCLB835IBO/'),
#  ('15.5 day', 'hindbrain', 'ENCSR401BSG', '/libraries/ENCLB507CWD/'),
#  ('15.5 day', 'hindbrain', 'ENCSR401BSG', '/libraries/ENCLB614EHD/'),
#  ('15.5 day', 'intestine', 'ENCSR370SFB', '/libraries/ENCLB042OTC/'),
#  ('15.5 day', 'intestine', 'ENCSR370SFB', '/libraries/ENCLB079XWZ/'),
#  ('15.5 day', 'kidney', 'ENCSR062VTB', '/libraries/ENCLB209CGK/'),
#  ('15.5 day', 'kidney', 'ENCSR062VTB', '/libraries/ENCLB783FQC/'),
#  ('15.5 day', 'limb', 'ENCSR830IVQ', '/libraries/ENCLB105VLP/'),
#  ('15.5 day', 'limb', 'ENCSR830IVQ', '/libraries/ENCLB646LEJ/'),
#  ('15.5 day', 'liver', 'ENCSR611PTP', '/libraries/ENCLB215FCS/'),
#  ('15.5 day', 'liver', 'ENCSR611PTP', '/libraries/ENCLB599UVX/'),
#  ('15.5 day', 'lung', 'ENCSR457RRW', '/libraries/ENCLB873UUE/'),
#  ('15.5 day', 'lung', 'ENCSR457RRW', '/libraries/ENCLB975KAO/'),
#  ('15.5 day', 'midbrain', 'ENCSR557RMA', '/libraries/ENCLB028XWK/'),
#  ('15.5 day', 'midbrain', 'ENCSR557RMA', '/libraries/ENCLB073YDX/'),
#  ('15.5 day', 'neural tube', 'ENCSR004XCU', '/libraries/ENCLB082UHO/'),
#  ('15.5 day', 'neural tube', 'ENCSR004XCU', '/libraries/ENCLB672ISU/'),
#  ('15.5 day', 'stomach', 'ENCSR906YQZ', '/libraries/ENCLB110FBI/'),
#  ('15.5 day', 'stomach', 'ENCSR906YQZ', '/libraries/ENCLB753FMG/'),
#  ('16.5 day', 'forebrain', 'ENCSR080EVZ', '/libraries/ENCLB026UUS/'),
#  ('16.5 day', 'forebrain', 'ENCSR080EVZ', '/libraries/ENCLB430WXG/'),
#  ('16.5 day', 'heart', 'ENCSR020DGG', '/libraries/ENCLB535BBV/'),
#  ('16.5 day', 'heart', 'ENCSR020DGG', '/libraries/ENCLB696ITY/'),
#  ('16.5 day', 'hindbrain', 'ENCSR285WZV', '/libraries/ENCLB662TIG/'),
#  ('16.5 day', 'hindbrain', 'ENCSR285WZV', '/libraries/ENCLB987VRV/'),
#  ('16.5 day', 'intestine', 'ENCSR848GST', '/libraries/ENCLB008KBU/'),
#  ('16.5 day', 'intestine', 'ENCSR848GST', '/libraries/ENCLB287BOO/'),
#  ('16.5 day', 'kidney', 'ENCSR537GNQ', '/libraries/ENCLB496KJW/'),
#  ('16.5 day', 'kidney', 'ENCSR537GNQ', '/libraries/ENCLB540BPI/'),
#  ('16.5 day', 'liver', 'ENCSR826HIQ', '/libraries/ENCLB424YVG/'),
#  ('16.5 day', 'liver', 'ENCSR826HIQ', '/libraries/ENCLB489BJY/'),
#  ('16.5 day', 'lung', 'ENCSR992WBR', '/libraries/ENCLB123VIC/'),
#  ('16.5 day', 'lung', 'ENCSR992WBR', '/libraries/ENCLB626WMA/'),
#  ('16.5 day', 'midbrain', 'ENCSR367ZPZ', '/libraries/ENCLB733PDT/'),
#  ('16.5 day', 'midbrain', 'ENCSR367ZPZ', '/libraries/ENCLB841PIC/'),
#  ('16.5 day', 'stomach', 'ENCSR466KZY', '/libraries/ENCLB732ZDB/'),
#  ('16.5 day', 'stomach', 'ENCSR466KZY', '/libraries/ENCLB852NKM/')]

# %%
experiment_grid = pandas.DataFrame(
    { age: { tissue: list(grid[age][tissue])[0] for tissue in grid[age]} for age in grid }
)
experiment_grid
# Out:
#                                     11.5         13.5         14.5  \
# embryonic facial prominence  ENCSR848HOX  ENCSR538WYL  ENCSR823VEE
# forebrain                    ENCSR160IIN  ENCSR970EWM  ENCSR185LWM
# heart                        ENCSR691OPQ  ENCSR284YKY  ENCSR727FHP
# hindbrain                    ENCSR760TOE  ENCSR921PRX  ENCSR559TRB
# intestine                            NaN          NaN  ENCSR932TRU
# kidney                               NaN          NaN  ENCSR504GEG
# limb                         ENCSR541XZK  ENCSR347SQR  ENCSR216NEG
# liver                        ENCSR284AMY  ENCSR448MXQ  ENCSR867YNV
# lung                                 NaN          NaN  ENCSR039ADS
# midbrain                     ENCSR307BCA  ENCSR792RJV  ENCSR343YLB
# neural tube                  ENCSR337FYI  ENCSR115TWD  ENCSR928OXI
# stomach                              NaN          NaN  ENCSR290RRR
#
#                                     15.5         16.5
# embryonic facial prominence  ENCSR636CWO          NaN
# forebrain                    ENCSR752RGN  ENCSR080EVZ
# heart                        ENCSR597UZW  ENCSR020DGG
# hindbrain                    ENCSR401BSG  ENCSR285WZV
# intestine                    ENCSR370SFB  ENCSR848GST
# kidney                       ENCSR062VTB  ENCSR537GNQ
# limb                         ENCSR830IVQ          NaN
# liver                        ENCSR611PTP  ENCSR826HIQ
# lung                         ENCSR457RRW  ENCSR992WBR
# midbrain                     ENCSR557RMA  ENCSR367ZPZ
# neural tube                  ENCSR004XCU          NaN
# stomach                      ENCSR906YQZ  ENCSR466KZY

# %%
def load_spike_rsems(cache, keys, limit=None):
    keys = list(keys)
    total = len(keys)
    chunk = max(total // 10, 1)
    tzero = time.monotonic()
    tprev = tzero
    
    for i, experiment_id in enumerate(keys):
        experiment = cache[experiment_id]
        fpkms = []
        for file in save_rnaseq_madqc.find_rsem(experiment['files']):
            url = 'https://www.encodeproject.org' + file.href
            fpkm = pandas.read_csv(url, usecols=[0,6], sep='\t', index_col=0)
            fpkm.columns = [file.library_id]
            fpkms.append(fpkm)

        if fpkms:
            yield (experiment_id, pandas.concat(fpkms, axis=1))
            
        if (i + 1) % chunk == 0:
            tnow = time.monotonic()
            print("{} of {} in {:.2f} sec".format(
                i, total, tnow-tprev))
            tprev = tnow

        if limit and i > limit:
            return

# %%
for age in sorted(grid):
    row = grid[age]
    for tissue in sorted(row):
        print(age,  tissue, list(row[tissue])[0])
# Out:
# 11.5 embryonic facial prominence ENCSR848HOX
# 11.5 forebrain ENCSR160IIN
# 11.5 heart ENCSR691OPQ
# 11.5 hindbrain ENCSR760TOE
# 11.5 limb ENCSR541XZK
# 11.5 liver ENCSR284AMY
# 11.5 midbrain ENCSR307BCA
# 11.5 neural tube ENCSR337FYI
# 13.5 embryonic facial prominence ENCSR538WYL
# 13.5 forebrain ENCSR970EWM
# 13.5 heart ENCSR284YKY
# 13.5 hindbrain ENCSR921PRX
# 13.5 limb ENCSR347SQR
# 13.5 liver ENCSR448MXQ
# 13.5 midbrain ENCSR792RJV
# 13.5 neural tube ENCSR115TWD
# 14.5 embryonic facial prominence ENCSR823VEE
# 14.5 forebrain ENCSR185LWM
# 14.5 heart ENCSR727FHP
# 14.5 hindbrain ENCSR559TRB
# 14.5 intestine ENCSR932TRU
# 14.5 kidney ENCSR504GEG
# 14.5 limb ENCSR216NEG
# 14.5 liver ENCSR867YNV
# 14.5 lung ENCSR039ADS
# 14.5 midbrain ENCSR343YLB
# 14.5 neural tube ENCSR928OXI
# 14.5 stomach ENCSR290RRR
# 15.5 embryonic facial prominence ENCSR636CWO
# 15.5 forebrain ENCSR752RGN
# 15.5 heart ENCSR597UZW
# 15.5 hindbrain ENCSR401BSG
# 15.5 intestine ENCSR370SFB
# 15.5 kidney ENCSR062VTB
# 15.5 limb ENCSR830IVQ
# 15.5 liver ENCSR611PTP
# 15.5 lung ENCSR457RRW
# 15.5 midbrain ENCSR557RMA
# 15.5 neural tube ENCSR004XCU
# 15.5 stomach ENCSR906YQZ
# 16.5 forebrain ENCSR080EVZ
# 16.5 heart ENCSR020DGG
# 16.5 hindbrain ENCSR285WZV
# 16.5 intestine ENCSR848GST
# 16.5 kidney ENCSR537GNQ
# 16.5 liver ENCSR826HIQ
# 16.5 lung ENCSR992WBR
# 16.5 midbrain ENCSR367ZPZ
# 16.5 stomach ENCSR466KZY
