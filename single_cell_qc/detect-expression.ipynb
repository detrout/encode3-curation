# %% [markdown]
# Is there anything consistently expressed accross most of the experiments?

# %%
import pandas
from rsemcache import RSEMCache

# %%
# Out:
# {'Hs_asp_purkinje_UMB5294_poolsplit': ['13843',
#   '13844',
#   '13845',
#   '13846',
#   '13847',
#   '13848',
#   '13849',
#   '13850',
#   '13851',
#   '13852',
#   '13853',
#   '13854',
#   '13855',
#   '13856',
#   '13857',
#   '13858',
#   '13859',
#   '13860'],
#  'Hs_asp_purkinje_UMB5294_single': ['13824',
#   '13825',
#   '13826',
#   '13827',
#   '13828',
#   '13829',
#   '13830',
#   '13831',
#   '13832',
#   '13833',
#   '13834',
#   '13835',
#   '13836',
#   '13837',
#   '13838',
#   '13839',
#   '13840',
#   '13841',
#   '13842'],
#  'Hs_purkinje_poolsplit': ['13645',
#   '13646',
#   '13647',
#   '13648',
#   '13649',
#   '13650',
#   '13651',
#   '13652',
#   '13653',
#   '13654',
#   '13655',
#   '13656',
#   '13657',
#   '13658',
#   '13659',
#   '13660',
#   '13661',
#   '13662',
#   '13663',
#   '13664'],
#  'Hs_purkinje_single': ['13625',
#   '13626',
#   '13627',
#   '13628',
#   '13629',
#   '13630',
#   '13631',
#   '13632',
#   '13633',
#   '13634',
# ...
