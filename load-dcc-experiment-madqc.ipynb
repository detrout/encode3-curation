# %% [markdown]
# The DCC has made available QC metrics for the experiments submitted. We need to try to draw some conclusions from them.

# %%
import pandas
import numpy
import pprint
import collections

# %%
from curation_common import *

# %%
server = ENCODED('www.encodeproject.org')
server.load_netrc()

# %%
query = server.get_json('search/?type=experiment&lab.title=Barbara Wold, Caltech')
# &award.rfa=ENCODE3

# %%
experiments = {}
for i, record in enumerate(query['@graph']):
    accession = record['@id'][len('/experiments/'):-1]
    experiments[accession] = server.get_json(record['@id'])
    if i % 10 == 0:
        print(i, len(query['@graph']))
# Out:
# 0 299
# 10 299
# 20 299
# 30 299
# 40 299
# 50 299
# 60 299
# 70 299
# 80 299
# 90 299
# 100 299
# 110 299
# 120 299
# 130 299
# 140 299
# 150 299
# 160 299
# 170 299
# 180 299
# 190 299
# 200 299
# 210 299
# 220 299
# 230 299
# 240 299
# 250 299
# 260 299
# 270 299
# 280 299
# 290 299

# %%
def format_organism(url):
    url = [ x for x in url.split('/') if len(x) > 0 ]
    return url[-1]

def aliases_to_wold_id(aliases):
    if len(aliases) > 1:
        raise RuntimeError("You need to do more work. Several library aliases: %s", aliases)
    elif len(aliases) == 1:
        alias = aliases[0].replace('barbara-wold:', '')
    else:
        alias = ''
    return alias

# %%
rows = []
for accession, detail in experiments.items():
    # For all the files in an experiment
    for f in detail['files']:
        # look at files that have quality control metrics attached
        if len(f['quality_metrics']) > 0:
            qc = f['quality_metrics']
            replicate = f['replicate']
            library = replicate['library']
            biosample = library['biosample']
            alias = aliases_to_wold_id(library['aliases'])
            # make sure there's only one QC metric attached to a file 
            assert len(qc) == 1
            # we only want to look at the MAD scores right now.
            # we're ignoring the STAR & RSEM scores and just
            # investigating Rafa's MAD QC output.
            if 'MadQualityMetric' in qc[0]['@type']:
                record = collections.OrderedDict(
                    # long list of things to identify a particular experiment replicate
                    (('experiment', accession), 
                     ('organism', format_organism(biosample['organism'])),
                     ('biosample', biosample['biosample_term_name']),
                     ('age', biosample['age'] + ' ' + biosample.get('age_units', '')),
                     ('starting', library.get('nucleic_acid_starting_quantity', numpy.nan)),
                     ('starting_units', library.get('nucleic_acid_starting_quantity_units', numpy.nan)),
                     ('bio_rep', replicate['biological_replicate_number']),
                     ('tech_rep', replicate['technical_replicate_number']),
                     ('library_id', alias),
                     # the qc metrics
                     ('Pearson', qc[0]['Pearson correlation']),
                     ('Spearman', qc[0]['Spearman correlation']),
                     ('MAD', qc[0]['MAD of log ratios']),
                     ('SD', qc[0]['SD of log ratios']),
                    ))
                rows.append(record)
experiment_qc = pandas.DataFrame(rows, columns=record.keys())

# %% [markdown]
# Show (some of) the data.

# %%
experiment_qc
# Out:
#       experiment organism                    biosample       age starting  \
# 0    ENCSR830IVQ    mouse                         limb  15.5 day       10
# 1    ENCSR830IVQ    mouse                         limb  15.5 day       10
# 2    ENCSR538WYL    mouse  embryonic facial prominence  13.5 day       10
# 3    ENCSR538WYL    mouse  embryonic facial prominence  13.5 day       10
# 4    ENCSR932TRU    mouse                    intestine  14.5 day     10.0
# 5    ENCSR932TRU    mouse                    intestine  14.5 day     10.0
# 6    ENCSR080EVZ    mouse                    forebrain  16.5 day       10
# 7    ENCSR080EVZ    mouse                    forebrain  16.5 day       10
# 8    ENCSR636CWO    mouse  embryonic facial prominence  15.5 day       10
# 9    ENCSR636CWO    mouse  embryonic facial prominence  15.5 day       10
# 10   ENCSR285WZV    mouse                    hindbrain  16.5 day       10
# 11   ENCSR285WZV    mouse                    hindbrain  16.5 day       10
# 12   ENCSR921PRX    mouse                    hindbrain  13.5 day       10
# 13   ENCSR921PRX    mouse                    hindbrain  13.5 day       10
# 14   ENCSR691OPQ    mouse                        heart  11.5 day       10
# 15   ENCSR691OPQ    mouse                        heart  11.5 day       10
# 16   ENCSR758TAD    mouse                Purkinje cell   8 month     50.0
# 17   ENCSR758TAD    mouse                Purkinje cell   8 month     50.0
# 18   ENCSR225BBK    human       bipolar spindle neuron   53 year       13
# 19   ENCSR225BBK    human       bipolar spindle neuron   53 year       13
# 20   ENCSR970EWM    mouse                    forebrain  13.5 day       10
# 21   ENCSR970EWM    mouse                    forebrain  13.5 day       10
# 22   ENCSR752RGN    mouse                    forebrain  15.5 day       10
# 23   ENCSR752RGN    mouse                    forebrain  15.5 day       10
# 24   ENCSR848GST    mouse                    intestine  16.5 day       10
# 25   ENCSR848GST    mouse                    intestine  16.5 day       10
# 26   ENCSR347SQR    mouse                         limb  13.5 day       10
# 27   ENCSR347SQR    mouse                         limb  13.5 day       10
# 28   ENCSR157NLF    human                Purkinje cell   20 year       30
# 29   ENCSR157NLF    human                Purkinje cell   20 year       30
# ..           ...      ...                          ...       ...      ...
# 166  ENCSR039ADS    mouse                         lung  14.5 day     10.0
# 167  ENCSR039ADS    mouse                         lung  14.5 day     10.0
# 168  ENCSR527RFK    mouse                    forebrain     0 day       13
# 169  ENCSR527RFK    mouse                    forebrain     0 day       13
# 170  ENCSR401BSG    mouse                    hindbrain  15.5 day       10
# 171  ENCSR401BSG    mouse                    hindbrain  15.5 day       10
# 172  ENCSR667TOX    mouse                  neural tube     0 day     10.0
# 173  ENCSR667TOX    mouse                  neural tube     0 day     10.0
# 174  ENCSR772FQU    mouse                      bladder     0 day     10.0
# 175  ENCSR772FQU    mouse                      bladder     0 day     10.0
# 176  ENCSR541XZK    mouse                         limb  11.5 day       10
# 177  ENCSR541XZK    mouse                         limb  11.5 day       10
# 178  ENCSR337FYI    mouse                  neural tube  11.5 day       10
# 179  ENCSR337FYI    mouse                  neural tube  11.5 day       10
# 180  ENCSR826HIQ    mouse                        liver  16.5 day       10
# 181  ENCSR826HIQ    mouse                        liver  16.5 day       10
# 182  ENCSR611PTP    mouse                        liver  15.5 day       10
# 183  ENCSR611PTP    mouse                        liver  15.5 day       10
# 184  ENCSR062VTB    mouse                       kidney  15.5 day       10
# 185  ENCSR062VTB    mouse                       kidney  15.5 day       10
# 186  ENCSR597UZW    mouse                        heart  15.5 day       10
# 187  ENCSR597UZW    mouse                        heart  15.5 day       10
# 188  ENCSR906YQZ    mouse                      stomach  15.5 day       10
# 189  ENCSR906YQZ    mouse                      stomach  15.5 day       10
# 190  ENCSR438XCG    mouse                       thymus     0 day     10.0
# 191  ENCSR438XCG    mouse                       thymus     0 day     10.0
# 192  ENCSR504GEG    mouse                       kidney  14.5 day     10.0
# 193  ENCSR504GEG    mouse                       kidney  14.5 day     10.0
# 194  ENCSR457RRW    mouse                         lung  15.5 day       10
# 195  ENCSR457RRW    mouse                         lung  15.5 day       10
#
#     starting_units  bio_rep  tech_rep library_id   Pearson  Spearman    MAD  \
# 0               ng        1         1      16134  0.986437  0.987857  0.186
# 1               ng        2         1      16135  0.986437  0.987857  0.186
# 2               ng        1         1      16106  0.978883  0.981664  0.199
# 3               ng        2         1      16107  0.978883  0.981664  0.199
# 4               ng        2         1      15091  0.985479  0.988529  0.181
# 5               ng        1         1      15090  0.985479  0.988529  0.181
# 6               ng        1         1      16140  0.985635  0.987653  0.223
# 7               ng        2         1      16141  0.985635  0.987653  0.223
# 8               ng        1         1      16136  0.981865  0.983680  0.161
# 9               ng        2         1      16137  0.981865  0.983680  0.161
# 10              ng        1         1      16144  0.979463  0.981760  0.210
# 11              ng        2         1      16145  0.979463  0.981760  0.210
# 12              ng        1         1      16104  0.992032  0.993175  0.132
# 13              ng        2         1      16105  0.992032  0.993175  0.132
# 14              ng        1         1      15015  0.986908  0.987609  0.228
# 15              ng        2         1      15016  0.986908  0.987609  0.228
# 16           cells        1         1      15241  0.978679  0.974901  0.378
# 17           cells        2         1      15242  0.978679  0.974901  0.378
# 18              pg        1         1      14485  0.630935  0.678207  1.377
# 19              pg        2         1      14486  0.630935  0.678207  1.377
# 20              ng        1         1      16100  0.991285  0.992348  0.174
# 21              ng        2         1      16101  0.991285  0.992348  0.174
# 22              ng        1         1      16116  0.991985  0.993495  0.133
# 23              ng        2         1      16117  0.991985  0.993495  0.133
# 24              ng        1         1      16152  0.989852  0.990637  0.191
# 25              ng        2         1      16153  0.989852  0.990637  0.191
# 26              ng        1         1      16110  0.993134  0.994352  0.131
# 27              ng        2         1      16111  0.993134  0.994352  0.131
# 28           cells        1         1      13665  0.955192  0.946682  0.476
# 29           cells        2         1      13666  0.955192  0.946682  0.476
# ..             ...      ...       ...        ...       ...       ...    ...
# 166             ng        1         1      15082  0.989389  0.991977  0.152
# 167             ng        2         1      15083  0.989389  0.991977  0.152
# 168             pg        2         1      14629  0.431121  0.586513  1.727
# 169             pg        1         1      14626  0.431121  0.586513  1.727
# 170             ng        1         1      16120  0.990933  0.992010  0.158
# 171             ng        2         1      16121  0.990933  0.992010  0.158
# 172             ng        2         1      15482  0.990533  0.991312  0.190
# 173             ng        1         1      15481  0.990533  0.991312  0.190
# 174             ng        2         1      15496  0.980005  0.980840  0.232
# 175             ng        1         1      15495  0.980005  0.980840  0.232
# 176             ng        2         1      15020  0.991923  0.993166  0.170
# 177             ng        1         1      15019  0.991923  0.993166  0.170
# 178             ng        2         1      15022  0.991864  0.993248  0.156
# 179             ng        1         1      15021  0.991864  0.993248  0.156
# 180             ng        1         1      16148  0.990513  0.989997  0.198
# 181             ng        2         1      16149  0.990513  0.989997  0.198
# 182             ng        2         1      16127  0.990187  0.989885  0.193
# 183             ng        1         1      16126  0.990187  0.989885  0.193
# 184             ng        1         1      16132  0.987195  0.989872  0.162
# 185             ng        2         1      16133  0.987195  0.989872  0.162
# 186             ng        1         1      16122  0.974374  0.976954  0.312
# 187             ng        2         1      16123  0.974374  0.976954  0.312
# 188             ng        1         1      16130  0.975151  0.977791  0.172
# 189             ng        2         1      16131  0.975151  0.977791  0.172
# 190             ng        1         1      15483  0.989391  0.989820  0.199
# 191             ng        2         1      15484  0.989391  0.989820  0.199
# 192             ng        2         1      15095  0.972030  0.971610  0.472
# 193             ng        1         1      15094  0.972030  0.971610  0.472
# 194             ng        1         1      16124  0.991279  0.993015  0.132
# 195             ng        2         1      16125  0.991279  0.993015  0.132
#
#         SD
# 0    0.338
# 1    0.338
# 2    0.444
# 3    0.444
# 4    0.353
# 5    0.353
# 6    0.350
# 7    0.350
# 8    0.390
# 9    0.390
# 10   0.416
# 11   0.416
# 12   0.260
# 13   0.260
# 14   0.339
# 15   0.339
# 16   0.469
# 17   0.469
# 18   1.974
# 19   1.974
# 20   0.284
# 21   0.284
# 22   0.261
# 23   0.261
# 24   0.307
# 25   0.307
# 26   0.245
# 27   0.245
# 28   0.691
# 29   0.691
# ..     ...
# 166  0.302
# 167  0.302
# 168  2.883
# 169  2.883
# 170  0.275
# 171  0.275
# 172  0.285
# 173  0.285
# 174  0.425
# 175  0.425
# 176  0.268
# 177  0.268
# 178  0.261
# 179  0.261
# 180  0.297
# 181  0.297
# 182  0.300
# 183  0.300
# 184  0.335
# 185  0.335
# 186  0.516
# 187  0.516
# 188  0.473
# 189  0.473
# 190  0.328
# 191  0.328
# 192  0.507
# 193  0.507
# 194  0.282
# 195  0.282
#
# [196 rows x 13 columns]

# %% [markdown]
# we have 10, 30, 50 cell sets, 13 pg and 10 ng data.

# %%
set([ '%s %s' % (x, y) for x,y in experiment_qc[['starting', 'starting_units']].values ])
# Out:
# {'10 cells',
#  '10 ng',
#  '10.0 ng',
#  '100 ng',
#  '11 cells',
#  '13 pg',
#  '30 cell-equivalent',
#  '30 cells',
#  '30.0 cell-equivalent',
#  '30.0 cells',
#  '50.0 cells',
#  'nan nan'}

# %% [markdown]
# Save data to CSV

# %%
experiment_qc.to_csv('/tmp/experiment-mad-qc.csv', index=False)
