# %% [markdown]
# # Introduction

# %% [markdown]
# Ken gave me a list of experiment IDs and would like to find the corresponding RSEM files for them.

# %%
import pandas
import os
import sys

# %%
ROOTS = [
    os.path.expanduser('~/proj/encode3-curation'),
    os.path.expanduser('~/proj/htsworkflow'),
]
for r in ROOTS:
    if r not in sys.path:
        sys.path.append(r)

# %%
from curation_common import *

# %%
server = ENCODED('www.encodeproject.org')
server.load_netrc()

# %%
import save_rnaseq_madqc

# %%
experiment_db = {}
experiment_db['ENCSR919QJT'] = server.get_json('https://www.encodeproject.org/experiments/ENCSR919QJT/')

# %%
query_url = 'search/?type=experiment&assay_term_name=RNA-seq'
cache_name = 'rnaseq-experiments.shelf'
experiments_db = save_rnaseq_madqc.caching_encoded_experiment_loader(query_url, cache_name)
# Out:
# Reading 150 of 1504 records in 0.008860171001288109 seconds
# Reading 300 of 1504 records in 0.0060497469967231154 seconds
# Reading 450 of 1504 records in 0.005841838006745093 seconds
# Reading 600 of 1504 records in 0.008946743997512385 seconds
# Reading 750 of 1504 records in 0.006682738006929867 seconds
# Reading 900 of 1504 records in 0.007477486986317672 seconds
# Reading 1050 of 1504 records in 0.039147881005192176 seconds
# Reading 1200 of 1504 records in 0.05147456799750216 seconds
# Reading 1350 of 1504 records in 0.026019398006610572 seconds
# Reading 1500 of 1504 records in 0.06485720399359707 seconds
# Read 1504 records in 0.22535777599841822 seconds

# %%
for f in experiments_db['ENCSR919QJT']['files']:
    wewant = [
'/files/ENCFF114MWR/',
'/files/ENCFF331TCQ/',
'/files/ENCFF780SJS/',
'/files/ENCFF555SHC/',
    ]
    
    analysis_step_version = f.get('analysis_step_version')
    software_versions = []
    if analysis_step_version:
        analysis_step = analysis_step_version['analysis_step']
        output_file_types = analysis_step['output_file_types']
        software_versions = analysis_step_version.get('software_versions')
                
        for version in software_versions:
            software = version['software']
            software_type = software.get('software_type')
            print(f["@id"], f['@id'] in wewant, f['file_format'], f['output_type'], software['name'])
# Out:
# /files/ENCFF815WBQ/ False bam alignments rna-pipelines
# /files/ENCFF815WBQ/ False bam alignments lrna-align-tophat-pe
# /files/ENCFF815WBQ/ False bam alignments concat-fastqs
# /files/ENCFF815WBQ/ False bam alignments tophat
# /files/ENCFF815WBQ/ False bam alignments bowtie
# /files/ENCFF815WBQ/ False bam alignments tophat_bam_xsA_tag_fix.pl
# /files/ENCFF183FCB/ False bam alignments rna-pipelines
# /files/ENCFF183FCB/ False bam alignments lrna-align-tophat-pe
# /files/ENCFF183FCB/ False bam alignments concat-fastqs
# /files/ENCFF183FCB/ False bam alignments tophat
# /files/ENCFF183FCB/ False bam alignments bowtie
# /files/ENCFF183FCB/ False bam alignments tophat_bam_xsA_tag_fix.pl
# /files/ENCFF544QSS/ False bigWig minus strand signal of all reads rna-pipelines
# /files/ENCFF544QSS/ False bigWig minus strand signal of all reads lrna-signals-stranded
# /files/ENCFF544QSS/ False bigWig minus strand signal of all reads star
# /files/ENCFF544QSS/ False bigWig minus strand signal of all reads bedgraphtobigwig
# /files/ENCFF725OJU/ False bigWig minus strand signal of unique reads rna-pipelines
# /files/ENCFF725OJU/ False bigWig minus strand signal of unique reads lrna-signals-stranded
# /files/ENCFF725OJU/ False bigWig minus strand signal of unique reads star
# /files/ENCFF725OJU/ False bigWig minus strand signal of unique reads bedgraphtobigwig
# /files/ENCFF557WHA/ False bigWig plus strand signal of all reads rna-pipelines
# /files/ENCFF557WHA/ False bigWig plus strand signal of all reads lrna-signals-stranded
# /files/ENCFF557WHA/ False bigWig plus strand signal of all reads star
# /files/ENCFF557WHA/ False bigWig plus strand signal of all reads bedgraphtobigwig
# /files/ENCFF838RJI/ False bigWig plus strand signal of unique reads rna-pipelines
# /files/ENCFF838RJI/ False bigWig plus strand signal of unique reads lrna-signals-stranded
# /files/ENCFF838RJI/ False bigWig plus strand signal of unique reads star
# /files/ENCFF838RJI/ False bigWig plus strand signal of unique reads bedgraphtobigwig
# /files/ENCFF544QUQ/ False bigWig plus strand signal of all reads rna-pipelines
# /files/ENCFF544QUQ/ False bigWig plus strand signal of all reads lrna-signals-stranded
# /files/ENCFF544QUQ/ False bigWig plus strand signal of all reads star
# /files/ENCFF544QUQ/ False bigWig plus strand signal of all reads bedgraphtobigwig
# /files/ENCFF822PHO/ False bigWig plus strand signal of unique reads rna-pipelines
# /files/ENCFF822PHO/ False bigWig plus strand signal of unique reads lrna-signals-stranded
# /files/ENCFF822PHO/ False bigWig plus strand signal of unique reads star
# /files/ENCFF822PHO/ False bigWig plus strand signal of unique reads bedgraphtobigwig
# /files/ENCFF628XTT/ False bigWig minus strand signal of unique reads rna-pipelines
# /files/ENCFF628XTT/ False bigWig minus strand signal of unique reads lrna-signals-stranded
# /files/ENCFF628XTT/ False bigWig minus strand signal of unique reads star
# /files/ENCFF628XTT/ False bigWig minus strand signal of unique reads bedgraphtobigwig
# /files/ENCFF211DVY/ False bigWig minus strand signal of all reads rna-pipelines
# /files/ENCFF211DVY/ False bigWig minus strand signal of all reads lrna-signals-stranded
# /files/ENCFF211DVY/ False bigWig minus strand signal of all reads star
# /files/ENCFF211DVY/ False bigWig minus strand signal of all reads bedgraphtobigwig
# /files/ENCFF886TZT/ False bam alignments rna-pipelines
# /files/ENCFF886TZT/ False bam alignments lrna-align-star-pe
# /files/ENCFF886TZT/ False bam alignments concat-fastqs
# /files/ENCFF886TZT/ False bam alignments star
# /files/ENCFF886TZT/ False bam alignments samtools
# /files/ENCFF523BJX/ False bam alignments rna-pipelines
# /files/ENCFF523BJX/ False bam alignments lrna-align-star-pe
# /files/ENCFF523BJX/ False bam alignments concat-fastqs
# /files/ENCFF523BJX/ False bam alignments star
# /files/ENCFF523BJX/ False bam alignments samtools
# /files/ENCFF030QUJ/ False bam transcriptome alignments rna-pipelines
# /files/ENCFF030QUJ/ False bam transcriptome alignments lrna-align-star-pe
# /files/ENCFF030QUJ/ False bam transcriptome alignments concat-fastqs
# /files/ENCFF030QUJ/ False bam transcriptome alignments star
# /files/ENCFF030QUJ/ False bam transcriptome alignments samtools
# /files/ENCFF042IYY/ False bam transcriptome alignments rna-pipelines
# /files/ENCFF042IYY/ False bam transcriptome alignments lrna-align-star-pe
# /files/ENCFF042IYY/ False bam transcriptome alignments concat-fastqs
# /files/ENCFF042IYY/ False bam transcriptome alignments star
# /files/ENCFF042IYY/ False bam transcriptome alignments samtools
# /files/ENCFF193BIJ/ False bigWig plus strand signal of unique reads rna-pipelines
# /files/ENCFF193BIJ/ False bigWig plus strand signal of unique reads lrna-signals-stranded
# /files/ENCFF193BIJ/ False bigWig plus strand signal of unique reads star
# /files/ENCFF193BIJ/ False bigWig plus strand signal of unique reads bedgraphtobigwig
# /files/ENCFF568WLO/ False tsv transcript quantifications rna-pipelines
# /files/ENCFF568WLO/ False tsv transcript quantifications lrna-quantification
# /files/ENCFF568WLO/ False tsv transcript quantifications rsem
# /files/ENCFF568SFZ/ False bigWig minus strand signal of unique reads rna-pipelines
# /files/ENCFF568SFZ/ False bigWig minus strand signal of unique reads lrna-signals-stranded
# /files/ENCFF568SFZ/ False bigWig minus strand signal of unique reads star
# /files/ENCFF568SFZ/ False bigWig minus strand signal of unique reads bedgraphtobigwig
# /files/ENCFF630CGH/ False bigWig plus strand signal of all reads rna-pipelines
# /files/ENCFF630CGH/ False bigWig plus strand signal of all reads lrna-signals-stranded
# /files/ENCFF630CGH/ False bigWig plus strand signal of all reads star
# /files/ENCFF630CGH/ False bigWig plus strand signal of all reads bedgraphtobigwig
# /files/ENCFF787VSP/ False tsv transcript quantifications rna-pipelines
# /files/ENCFF787VSP/ False tsv transcript quantifications lrna-quantification
# /files/ENCFF787VSP/ False tsv transcript quantifications rsem
# /files/ENCFF330RBH/ False bigWig minus strand signal of all reads rna-pipelines
# /files/ENCFF330RBH/ False bigWig minus strand signal of all reads lrna-signals-stranded
# /files/ENCFF330RBH/ False bigWig minus strand signal of all reads star
# /files/ENCFF330RBH/ False bigWig minus strand signal of all reads bedgraphtobigwig
# /files/ENCFF397UQV/ False bigWig minus strand signal of unique reads rna-pipelines
# /files/ENCFF397UQV/ False bigWig minus strand signal of unique reads lrna-signals-stranded
# /files/ENCFF397UQV/ False bigWig minus strand signal of unique reads star
# /files/ENCFF397UQV/ False bigWig minus strand signal of unique reads bedgraphtobigwig
# /files/ENCFF409RBT/ False bigWig plus strand signal of unique reads rna-pipelines
# /files/ENCFF409RBT/ False bigWig plus strand signal of unique reads lrna-signals-stranded
# /files/ENCFF409RBT/ False bigWig plus strand signal of unique reads star
# /files/ENCFF409RBT/ False bigWig plus strand signal of unique reads bedgraphtobigwig
# /files/ENCFF237ZHN/ False bigWig plus strand signal of all reads rna-pipelines
# /files/ENCFF237ZHN/ False bigWig plus strand signal of all reads lrna-signals-stranded
# /files/ENCFF237ZHN/ False bigWig plus strand signal of all reads star
# /files/ENCFF237ZHN/ False bigWig plus strand signal of all reads bedgraphtobigwig
# /files/ENCFF114MWR/ True tsv gene quantifications rna-pipelines
# /files/ENCFF114MWR/ True tsv gene quantifications lrna-quantification
# /files/ENCFF114MWR/ True tsv gene quantifications rsem
# /files/ENCFF760VGM/ False bigWig minus strand signal of all reads rna-pipelines
# /files/ENCFF760VGM/ False bigWig minus strand signal of all reads lrna-signals-stranded
# /files/ENCFF760VGM/ False bigWig minus strand signal of all reads star
# /files/ENCFF760VGM/ False bigWig minus strand signal of all reads bedgraphtobigwig
# /files/ENCFF780SJS/ True tsv gene quantifications rna-pipelines
# /files/ENCFF780SJS/ True tsv gene quantifications lrna-quantification
# /files/ENCFF780SJS/ True tsv gene quantifications rsem

# %%
rsems = list(save_rnaseq_madqc.find_all_rsem(experiments_db['ENCSR919QJT']['files']))
rsems
# Out:
# [FileInfo(date_created='2015-08-24T20:23:06.215398+00:00', file_id='/files/ENCFF114MWR/', library_id='ENCLB738UVO', experiment_id='ENCSR919QJT', assembly='hg19', genome_annotation='V19', spikes_used=['ENCSR156CIL'], href='/files/ENCFF114MWR/@@download/ENCFF114MWR.tsv'),
#  FileInfo(date_created='2015-08-24T20:24:56.110443+00:00', file_id='/files/ENCFF780SJS/', library_id='ENCLB652BFV', experiment_id='ENCSR919QJT', assembly='hg19', genome_annotation='V19', spikes_used=['ENCSR156CIL'], href='/files/ENCFF780SJS/@@download/ENCFF780SJS.tsv')]

# %%
rsems[0]._asdict()
# Out:
# OrderedDict([('date_created', '2015-08-24T20:23:06.215398+00:00'),
#              ('file_id', '/files/ENCFF114MWR/'),
#              ('library_id', 'ENCLB738UVO'),
#              ('experiment_id', 'ENCSR919QJT'),
#              ('assembly', 'hg19'),
#              ('genome_annotation', 'V19'),
#              ('spikes_used', ['ENCSR156CIL']),
#              ('href', '/files/ENCFF114MWR/@@download/ENCFF114MWR.tsv')])

# %%
[ x for x in experiments_db['ENCSR919QJT']['replicates'] if x['library']['@id'] == '/libraries/ENCLB738UVO/']
# Out:
# [{'@id': '/replicates/d7d2bb3a-37cc-4c98-8e4b-ded1f086b98f/',
#   '@type': ['Replicate', 'Item'],
#   'aliases': [],
#   'biological_replicate_number': 1,
#   'date_created': '2014-04-22T20:09:02.562461+00:00',
#   'experiment': '/experiments/ENCSR919QJT/',
#   'library': {'@id': '/libraries/ENCLB738UVO/',
#    '@type': ['Library', 'Item'],
#    'accession': 'ENCLB738UVO',
#    'aliases': ['thomas-gingeras:291691'],
#    'alternate_accessions': [],
#    'award': '/awards/U54HG007004/',
#    'biosample': {'@id': '/biosamples/ENCBS381KGR/',
#     '@type': ['Biosample', 'Item'],
#     'accession': 'ENCBS381KGR',
#     'age': '37',
#     'age_display': '37 year',
#     'age_units': 'year',
#     'aliases': ['john-stamatoyannopoulos:24825'],
#     'alternate_accessions': [],
#     'award': '/awards/U54HG007010/',
#     'biosample_synonyms': [],
#     'biosample_term_id': 'EFO:0002184',
#     'biosample_term_name': 'H4',
#     'biosample_type': 'immortalized cell line',
#     'characterizations': [],
#     'constructs': [],
#     'date_created': '2014-02-24T23:22:13.094982+00:00',
#     'dbxrefs': ['GEO:SAMN04284361'],
#     'description': '',
#     'developmental_slims': [],
#     'donor': {'@id': '/human-donors/ENCDO337AAA/',
#      '@type': ['HumanDonor', 'Donor', 'Item'],
#      'accession': 'ENCDO337AAA',
#      'age': '37',
#      'age_units': 'year',
#      'aliases': ['john-stamatoyannopoulos:h.NCI-H460'],
#      'alternate_accessions': [],
#      'award': '/awards/U54HG007010/',
#      'characterizations': [],
#      'children': [],
#      'date_created': '2014-01-17T09:15:27.467160+00:00',
#      'dbxrefs': ['GEO:SAMN04284605'],
#      'documents': [],
#      'lab': '/labs/john-stamatoyannopoulos/',
#      'life_stage': 'adult',
#      'organism': {'@id': '/organisms/human/',
#       '@type': ['Organism', 'Item'],
#       'name': 'human',
#       'schema_version': '2',
#       'scientific_name': 'Homo sapiens',
#       'status': 'current',
#       'taxon_id': '9606',
#       'uuid': '7745b647-ff15-4ff3-9ced-b897d4e2983c'},
#      'parents': [],
#      'references': [],
#      'schema_version': '6',
#      'sex': 'male',
#      'siblings': [],
#      'status': 'released',
#      'submitted_by': '/users/d730c730-c7fa-4c98-a916-850edfad52a2/',
#      'uuid': '4284dbc2-f1ea-4360-a8ef-8df1f71ca3b5'},
#     'lab': '/labs/john-stamatoyannopoulos/',
#     'life_stage': 'adult',
#     'organ_slims': [],
#     'organism': {'@id': '/organisms/human/',
#      '@type': ['Organism', 'Item'],
#      'name': 'human',
#      'schema_version': '2',
#      'scientific_name': 'Homo sapiens',
#      'status': 'current',
#      'taxon_id': '9606',
#      'uuid': '7745b647-ff15-4ff3-9ced-b897d4e2983c'},
#     'parent_of': [],
#     'pooled_from': [],
#     'protocol_documents': [],
#     'references': [],
#     'rnais': [],
#     'schema_version': '12',
#     'sex': 'male',
#     'source': {'@id': '/sources/atcc/',
#      '@type': ['Source', 'Item'],
#      'aliases': [],
#      'description': 'American Type Culture Collection (ATCC)',
#      'name': 'atcc',
#      'schema_version': '3',
#      'status': 'current',
#      'title': 'ATCC',
#      'url': 'http://www.atcc.org/',
#      'uuid': 'eadabaf1-d5b6-4b48-8847-e86461f12101'},
#     'status': 'released',
#     'submitted_by': {'@id': '/users/d730c730-c7fa-4c98-a916-850edfad52a2/',
#      '@type': ['User', 'Item'],
#      'lab': '/labs/john-stamatoyannopoulos/',
#      'title': 'Michael Buckley',
#      'uuid': 'd730c730-c7fa-4c98-a916-850edfad52a2'},
#     'summary': 'Homo sapiens  H4 immortalized cell line',
#     'system_slims': [],
#     'talens': [],
#     'treatments': [],
#     'uuid': '3746fe9a-9112-4c3f-b705-ce5eb01bf75c'},
#    'date_created': '2014-04-22T20:06:40.854021+00:00',
#    'dbxrefs': ['GEO:GSM2072608'],
#    'depleted_in_term_id': ['SO:0000252'],
#    'depleted_in_term_name': ['rRNA'],
#    'documents': [{'@id': '/documents/20952fb2-f48e-4fd6-abd4-a22774878d8b/',
#      '@type': ['Document', 'Item'],
#      'aliases': ['thomas-gingeras:291691_protocol'],
#      'attachment': {'download': '291691.pdf',
#       'href': '@@download/attachment/291691.pdf',
#       'type': 'application/pdf'},
#      'award': {'@id': '/awards/U54HG007004/',
#       '@type': ['Award', 'Item'],
#       'description': "The overall goal of this project is to generate fine-structure RNA maps in human and mouse (C57BL/6NJ) tissues and primary cell lines using a variety of high-throughput sequencing platforms, to evaluate the biological importance of novel transcripts by determining if evidence of their translated products can be identified. From each sample analyzed, we propose to isolate long (>200 nucleotides) and short (< 200 nucleotides) RNA in biological duplicate. Illumina-based maps for these samples will initially be generated using (1) RNA sequencing (-seq) of ribosomal (r-)RNA depleted long total RNA. (2) RNA-seq of tobacco acid pyrophosphatase (TAP) pre-treated short RNA (3) Pair-end Cap Analysis of Gene Expression (PE-CAGE) of total RNA. Additionally, for a subset of primary cell lines we will generate the above libraries from nuclear and cytoplasmic subcellular fractions. Long RNA-Seq data will be distilled down into functional elements consisting of splice junctions, polyadenylatio sites and de novo genes and transcripts. The short RNA data will be distilled into contigs representing the 5' ends of short RNAs up to the read length. PE-CAGE data will be analyzed to form clusters representing the 5' ends of transcripts linked to a tag internal to the transcript body. Importantly, each element will be assessed for reproducibility using a nonparametric Irreproducible Detection Rate (nplDR) script. Collectively, these data will allow for the detection of novel transcribed regions and supportive information as to the location of promoter regions and subcellular residence of transcripts. In aggregate, these data will be used to generate models of both noncoding and protein coding transcripts and to distinguish isoforms at complex loci necessary to obtain a comprehensive view of mammalian transcriptomes. For a subset of these samples we will simultaneously collect the genome sequence of the human donors to provide a reference map that will be used to map the RNA data against and derive information concerning allele-specific expression and RNA editing. Unannotated transcript models will be tested using long-range (PacBio/454) sequencing. Lastly, proteogenomic analysis will be done and the results compared against the unannotated transcripts.",
#       'end_date': '2016-07-31',
#       'name': 'U54HG007004',
#       'pi': '/users/09d05b87-4d30-4dfb-b243-3327005095f2/',
#       'project': 'ENCODE',
#       'rfa': 'ENCODE3',
#       'schema_version': '2',
#       'start_date': '2012-09-21',
#       'status': 'current',
#       'title': 'LANDSCAPE OF TRANSCRIPTION IN HUMAN AND MOUSE',
#       'url': 'http://projectreporter.nih.gov/project_info_details.cfm?aid=8402436',
#       'uuid': '90be62e4-0757-4097-b5cf-2e6a20240a6f',
#       'viewing_group': 'ENCODE'},
#      'date_created': '2014-04-22T20:04:09.354531+00:00',
#      'description': 'This document describes the construction of library:thomas-gingeras:291691',
#      'document_type': 'general protocol',
#      'lab': {'@id': '/labs/thomas-gingeras/',
#       '@type': ['Lab', 'Item'],
#       'address1': '500 Sunnyside Blvd',
#       'awards': ['/awards/U54HG007004/', '/awards/U54HG004557/'],
#       'city': 'Woodbury',
#       'country': 'USA',
#       'fax': '516-422-4109',
#       'institute_label': 'CSHL',
#       'institute_name': 'Cold Spring Harbor Laboratory',
#       'name': 'thomas-gingeras',
#       'phone1': '516-422-4105',
#       'phone2': '',
#       'pi': '/users/09d05b87-4d30-4dfb-b243-3327005095f2/',
#       'postal_code': '11797',
#       'schema_version': '3',
#       'state': 'NY',
#       'status': 'current',
#       'title': 'Thomas Gingeras, CSHL',
#       'uuid': 'dfc72c8c-d45c-4acd-979b-49fc93cf3c62'},
#      'references': ['/publications/f6f6a405-e284-4e5a-93b4-524ac2000854/',
#       '/publications/a66aada1-0a84-4ba6-9f00-06758cf7390a/'],
#      'schema_version': '5',
#      'status': 'released',
#      'submitted_by': {'@id': '/users/0abbd494-b852-433c-b360-93996f679dae/',
#       '@type': ['User', 'Item'],
#       'lab': '/labs/thomas-gingeras/',
#       'title': 'Carrie Davis',
#       'uuid': '0abbd494-b852-433c-b360-93996f679dae'},
#      'urls': [],
#      'uuid': '20952fb2-f48e-4fd6-abd4-a22774878d8b'}],
#    'extraction_method': 'see document',
#    'fragmentation_method': 'shearing (Covaris generic)',
#    'lab': '/labs/thomas-gingeras/',
#    'library_size_selection_method': 'Only RNAs greater than 200 nucleotides.  The insert for the library was excised from an agarose gel',
#    'lysis_method': 'see document',
#    'nucleic_acid_term_id': 'SO:0000356',
#    'nucleic_acid_term_name': 'RNA',
#    'schema_version': '5',
#    'size_range': '>200',
#    'spikeins_used': [{'@id': '/references/ENCSR156CIL/',
#      '@type': ['Reference', 'FileSet', 'Dataset', 'Item'],
#      'accession': 'ENCSR156CIL',
#      'aliases': ['thomas-gingeras:AmbionMix1', 'barbara-wold:ERCC'],
#      'alternate_accessions': ['ENCSR686QUF'],
#      'assembly': [],
#      'award': '/awards/U54HG007004/',
#      'contributing_files': [],
#      'date_created': '2014-08-25T23:24:26.809519+00:00',
#      'date_released': '2014-01-01',
#      'dbxrefs': [],
#      'description': 'Ambion mix 1 spike-ins',
#      'documents': ['/documents/7ae25f97-ab0a-448b-b345-cfffd6368c90/',
#       '/documents/28fef8e0-e171-450d-b66d-e3d199531cf2/'],
#      'files': ['/files/ENCFF001RTP/', '/files/ENCFF001RTP/'],
#      'lab': '/labs/thomas-gingeras/',
#      'month_released': 'January, 2014',
#      'original_files': ['/files/ENCFF001RTP/'],
#      'reference_type': 'spike-in',
#      'references': ['/publications/f6f6a405-e284-4e5a-93b4-524ac2000854/'],
#      'related_files': ['/files/ENCFF001RTP/'],
#      'revoked_files': [],
#      'schema_version': '8',
#      'status': 'released',
#      'submitted_by': '/users/0abbd494-b852-433c-b360-93996f679dae/',
#      'uuid': '1986343c-a156-43f3-b1a4-1761f1786df5'}],
#    'status': 'released',
#    'strand_specificity': True,
#    'submitted_by': '/users/0abbd494-b852-433c-b360-93996f679dae/',
#    'treatments': [],
#    'uuid': 'acc89a8e-838c-42bc-807c-df4fc2cb6fde'},
#   'notes': '{}',
#   'schema_version': '6',
#   'status': 'released',
#   'submitted_by': '/users/0abbd494-b852-433c-b360-93996f679dae/',
#   'technical_replicate_number': 1,
#   'uuid': 'd7d2bb3a-37cc-4c98-8e4b-ded1f086b98f'}]

# %%
gene_quants = [ x for x in experiments_db['ENCSR919QJT']['files'] if x['@id'] in wewant ]

# %%
len(gene_quants)
# Out:
# 2

# %%
len(experiments_db['ENCSR919QJT']['files'])
# Out:
# 30

# %%
def add_library_info(experiments_db, rsem):
    experiment_id = rsem['experiment_id']
    library_id = rsem['library_id']
    library_obj_id = '/libraries/{}/'.format(library_id)
    experiment = experiments_db[experiment_id]
    replicates = experiment['replicates']
    replicate = [ x for x in replicates if x['library']['@id'] == library_obj_id][0]
    library = replicate['library']
    biosample = library['biosample']
    rsem['lab'] = save_rnaseq_madqc.url_end(experiment['lab']['@id'])
    rsem['starting'] = library.get('nucleic_acid_starting_quantity')
    rsem['starting_units'] = library.get('nucleic_acid_starting_quantity_units')
    rsem['biosample_id'] = save_rnaseq_madqc.url_end(biosample['@id'])
    rsem['organism'] = biosample['organism']['name']
    rsem['age'] = biosample['age']
    rsem['age_units'] = biosample.get('age_units')
    rsem['biosample_lab'] = save_rnaseq_madqc.url_end(biosample['lab'])
    rsem['biological_replicate_number'] = replicate['biological_replicate_number']
    rsem['technical_replicate_number'] = replicate['technical_replicate_number']
    rsem['biosample_type'] = biosample['biosample_type']
    rsem['replication_type'] = experiment['replication_type']

# %%
with open('kens-ids.txt') as instream:
    rsems = []
    for line in instream:
        experiment_id = line.strip()
        experiment = experiments_db[experiment_id]
        for rsem in save_rnaseq_madqc.find_all_rsem(experiment['files']):
            rsem = rsem._asdict()
            rsem['href'] = 'https://www.encodeproject.org' + rsem['href']
            add_library_info(experiments_db, rsem)
            rsems.append(rsem)

# %% [markdown]
# Looking for fields:
# ,experiment,lab,rfa,description,organism,biosample,biosample_lab,age,starting,library_id,spikeins_used,Pearson,Spearman,MAD,SD

# %%
len(rsems)
# Out:
# 492

# %%
for rsem in rsems:
    rsem['spikes_used'] = ','.join(rsem['spikes_used'])

# %%
rsem.keys()
# Out:
# odict_keys(['date_created', 'file_id', 'library_id', 'experiment_id', 'assembly', 'genome_annotation', 'spikes_used', 'href', 'lab', 'starting', 'starting_units', 'biosample_id', 'organism', 'age', 'age_units', 'biosample_lab', 'biological_replicate_number', 'technical_replicate_number', 'biosample_type', 'replication_type'])

# %%
df = pandas.DataFrame(rsems, columns=rsems[0].keys())

# %%
df.to_csv('/tmp/rsem_urls.tsv', sep='\t')

# %%
df
# Out:
#                          date_created              file_id   library_id  \
# 0    2015-06-25T01:16:17.139561+00:00  /files/ENCFF042WGS/  ENCLB555ALW
# 1    2015-06-25T01:18:19.581724+00:00  /files/ENCFF708OYI/  ENCLB555ANB
# 2    2015-12-18T01:46:21.022710+00:00  /files/ENCFF881JHI/  ENCLB426JGB
# 3    2015-12-18T01:47:52.152484+00:00  /files/ENCFF254RPS/  ENCLB387BDY
# 4    2015-05-28T02:02:45.092076+00:00  /files/ENCFF370KKZ/  ENCLB755HPY
# 5    2015-05-28T02:01:06.991856+00:00  /files/ENCFF096DQV/  ENCLB088PVJ
# 6    2015-01-06T23:51:07.759378+00:00  /files/ENCFF211LIT/  ENCLB595PNG
# 7    2015-01-06T23:51:22.374497+00:00  /files/ENCFF501QKH/  ENCLB409LKR
# 8    2015-10-02T18:53:30.846721+00:00  /files/ENCFF887QYY/  ENCLB373ANW
# 9    2015-10-02T18:55:27.775310+00:00  /files/ENCFF487ALN/  ENCLB567JQE
# 10   2015-06-25T01:07:43.474962+00:00  /files/ENCFF111SEX/  ENCLB018ZZZ
# 11   2015-06-25T01:09:45.115978+00:00  /files/ENCFF755GEI/  ENCLB019ZZZ
# 12   2016-02-24T19:54:48.297404+00:00  /files/ENCFF985PDI/  ENCLB019ZZZ
# 13   2016-02-24T19:52:07.720568+00:00  /files/ENCFF797YZO/  ENCLB018ZZZ
# 14   2015-04-17T00:53:36.542574+00:00  /files/ENCFF652PQZ/  ENCLB182ZZZ
# 15   2015-04-17T00:51:51.543947+00:00  /files/ENCFF520PXU/  ENCLB181ZZZ
# 16   2016-02-24T19:28:59.401599+00:00  /files/ENCFF847LUK/  ENCLB181ZZZ
# 17   2016-02-24T19:31:29.000691+00:00  /files/ENCFF947SAO/  ENCLB182ZZZ
# 18   2015-06-25T00:36:56.666866+00:00  /files/ENCFF229LIX/  ENCLB555AWI
# 19   2015-06-25T00:40:09.084841+00:00  /files/ENCFF503QBP/  ENCLB555AWH
# 20   2016-02-29T21:07:23.267188+00:00  /files/ENCFF354AZS/  ENCLB555AWH
# 21   2016-02-29T21:05:40.716453+00:00  /files/ENCFF505GUJ/  ENCLB555AWI
# 22   2015-05-28T01:26:16.396841+00:00  /files/ENCFF120PLK/  ENCLB335CWF
# 23   2015-05-28T01:24:39.329577+00:00  /files/ENCFF805BVE/  ENCLB862KOP
# 24   2015-08-20T00:34:19.559489+00:00  /files/ENCFF667WSC/  ENCLB297PER
# 25   2015-08-20T00:36:36.592542+00:00  /files/ENCFF562TXM/  ENCLB794DVD
# 26   2015-10-02T18:55:37.546100+00:00  /files/ENCFF142IPK/  ENCLB082UHO
# 27   2015-10-02T18:57:32.980076+00:00  /files/ENCFF990GEJ/  ENCLB672ISU
# 28   2015-10-02T18:53:19.205775+00:00  /files/ENCFF232GHI/  ENCLB852NKM
# 29   2015-10-02T18:55:22.144443+00:00  /files/ENCFF803QGE/  ENCLB732ZDB
# ..                                ...                  ...          ...
# 462  2015-06-24T23:51:55.430033+00:00  /files/ENCFF961TGO/  ENCLB555AQF
# 463  2015-06-24T23:49:52.173143+00:00  /files/ENCFF761BVV/  ENCLB555AQE
# 464  2016-02-23T21:38:24.023754+00:00  /files/ENCFF199BWJ/  ENCLB952YYH
# 465  2016-02-23T21:36:03.103500+00:00  /files/ENCFF979PZW/  ENCLB093BKT
# 466  2015-05-28T01:13:47.516947+00:00  /files/ENCFF416NCQ/  ENCLB260JQO
# 467  2015-05-28T01:17:43.307937+00:00  /files/ENCFF598YQI/  ENCLB925VWI
# 468  2015-08-24T18:23:21.286029+00:00  /files/ENCFF772CWV/  ENCLB392ZIG
# 469  2015-08-24T18:25:22.523558+00:00  /files/ENCFF813CAE/  ENCLB036TZY
# 470  2015-07-02T22:51:07.858781+00:00  /files/ENCFF263TID/  ENCLB817LXB
# 471  2015-07-02T22:49:06.275416+00:00  /files/ENCFF774MTJ/  ENCLB260QNG
# 472  2015-06-25T01:19:27.458915+00:00  /files/ENCFF436XMQ/  ENCLB020ZZZ
# 473  2015-06-25T01:21:36.847611+00:00  /files/ENCFF684KLL/  ENCLB021ZZZ
# 474  2016-02-24T20:06:06.367369+00:00  /files/ENCFF110UGQ/  ENCLB020ZZZ
# 475  2016-02-24T20:08:24.355833+00:00  /files/ENCFF764AOQ/  ENCLB021ZZZ
# 476  2015-04-17T00:28:26.719130+00:00  /files/ENCFF857UYC/  ENCLB184ZZZ
# 477  2015-04-17T00:26:47.697138+00:00  /files/ENCFF726GGW/  ENCLB183ZZZ
# 478  2016-02-24T00:24:51.798857+00:00  /files/ENCFF803YED/  ENCLB183ZZZ
# 479  2016-02-24T00:26:37.647954+00:00  /files/ENCFF455HQT/  ENCLB184ZZZ
# 480  2015-06-24T23:43:01.760654+00:00  /files/ENCFF458UOE/  ENCLB555AVL
# 481  2015-06-24T23:41:05.612320+00:00  /files/ENCFF461AOR/  ENCLB555AVD
# 482  2015-08-20T06:54:26.395739+00:00  /files/ENCFF327XVW/  ENCLB237FQL
# 483  2015-08-20T06:52:37.156217+00:00  /files/ENCFF691GEO/  ENCLB773OBJ
# 484  2015-08-20T00:47:54.499017+00:00  /files/ENCFF449ASM/  ENCLB695YMT
# 485  2015-08-20T00:46:03.680157+00:00  /files/ENCFF346UQA/  ENCLB059TNM
# 486  2015-10-02T19:00:52.385077+00:00  /files/ENCFF994LOF/  ENCLB696ITY
# 487  2015-10-02T19:02:42.284673+00:00  /files/ENCFF339EOB/  ENCLB535BBV
# 488  2015-07-02T22:49:46.639748+00:00  /files/ENCFF232PNH/  ENCLB658ICO
# 489  2015-07-02T22:51:47.373490+00:00  /files/ENCFF201GLL/  ENCLB741KQB
# 490  2015-10-02T18:56:24.279176+00:00  /files/ENCFF598ZGD/  ENCLB177SFU
# 491  2015-10-02T18:58:17.221699+00:00  /files/ENCFF339GUO/  ENCLB807ODU
#
#     experiment_id assembly genome_annotation              spikes_used  \
# 0     ENCSR000CUL     hg19               V19              ENCSR470JZL
# 1     ENCSR000CUL     hg19               V19              ENCSR470JZL
# 2     ENCSR379YAE     hg19               V19              ENCSR156CIL
# 3     ENCSR379YAE     hg19               V19              ENCSR156CIL
# 4     ENCSR897KTO     hg19               V19              ENCSR156CIL
# 5     ENCSR897KTO     hg19               V19              ENCSR156CIL
# 6     ENCSR290RRR     mm10                M4              ENCSR884LPM
# 7     ENCSR290RRR     mm10                M4              ENCSR884LPM
# 8     ENCSR752RGN     mm10                M4              ENCSR884LPM
# 9     ENCSR752RGN     mm10                M4              ENCSR884LPM
# 10    ENCSR000AAJ     hg19               V19              ENCSR156CIL
# 11    ENCSR000AAJ     hg19               V19              ENCSR156CIL
# 12    ENCSR000AAJ   GRCh38               V24              ENCSR156CIL
# 13    ENCSR000AAJ   GRCh38               V24              ENCSR156CIL
# 14    ENCSR000AEY     hg19               V19              ENCSR470JZL
# 15    ENCSR000AEY     hg19               V19              ENCSR470JZL
# 16    ENCSR000AEY   GRCh38               V24              ENCSR470JZL
# 17    ENCSR000AEY   GRCh38               V24              ENCSR470JZL
# 18    ENCSR000COY     hg19               V19              ENCSR402QNO
# 19    ENCSR000COY     hg19               V19              ENCSR402QNO
# 20    ENCSR000COY   GRCh38               V24              ENCSR402QNO
# 21    ENCSR000COY   GRCh38               V24              ENCSR402QNO
# 22    ENCSR198TKA     hg19               V19              ENCSR156CIL
# 23    ENCSR198TKA     hg19               V19              ENCSR156CIL
# 24    ENCSR625QJI     hg19               V19              ENCSR156CIL
# 25    ENCSR625QJI     hg19               V19              ENCSR156CIL
# 26    ENCSR004XCU     mm10                M4              ENCSR884LPM
# 27    ENCSR004XCU     mm10                M4              ENCSR884LPM
# 28    ENCSR466KZY     mm10                M4              ENCSR884LPM
# 29    ENCSR466KZY     mm10                M4              ENCSR884LPM
# ..            ...      ...               ...                      ...
# 462   ENCSR000CUP     hg19               V19              ENCSR470JZL
# 463   ENCSR000CUP     hg19               V19              ENCSR470JZL
# 464   ENCSR429EWK   GRCh38               V24              ENCSR156CIL
# 465   ENCSR429EWK   GRCh38               V24              ENCSR156CIL
# 466   ENCSR919MZM     hg19               V19              ENCSR156CIL
# 467   ENCSR919MZM     hg19               V19              ENCSR156CIL
# 468   ENCSR313IUO     hg19               V19  ENCSR013YHQ,ENCSR133ALU
# 469   ENCSR313IUO     hg19               V19  ENCSR013YHQ,ENCSR133ALU
# 470   ENCSR772FQU     mm10                M4  ENCSR013YHQ,ENCSR133ALU
# 471   ENCSR772FQU     mm10                M4  ENCSR013YHQ,ENCSR133ALU
# 472   ENCSR000AAK     hg19               V19              ENCSR156CIL
# 473   ENCSR000AAK     hg19               V19              ENCSR156CIL
# 474   ENCSR000AAK   GRCh38               V24              ENCSR156CIL
# 475   ENCSR000AAK   GRCh38               V24              ENCSR156CIL
# 476   ENCSR000AEZ     hg19               V19              ENCSR470JZL
# 477   ENCSR000AEZ     hg19               V19              ENCSR470JZL
# 478   ENCSR000AEZ   GRCh38               V24              ENCSR470JZL
# 479   ENCSR000AEZ   GRCh38               V24              ENCSR470JZL
# 480   ENCSR000CPM     hg19               V19              ENCSR402QNO
# 481   ENCSR000CPM     hg19               V19              ENCSR402QNO
# 482   ENCSR233IJT     hg19               V19              ENCSR156CIL
# 483   ENCSR233IJT     hg19               V19              ENCSR156CIL
# 484   ENCSR669KQU     hg19               V19              ENCSR156CIL
# 485   ENCSR669KQU     hg19               V19              ENCSR156CIL
# 486   ENCSR020DGG     mm10                M4              ENCSR884LPM
# 487   ENCSR020DGG     mm10                M4              ENCSR884LPM
# 488   ENCSR526SEX     mm10                M4  ENCSR013YHQ,ENCSR133ALU
# 489   ENCSR526SEX     mm10                M4  ENCSR013YHQ,ENCSR133ALU
# 490   ENCSR970EWM     mm10                M4              ENCSR884LPM
# 491   ENCSR970EWM     mm10                M4              ENCSR884LPM
#
#                                                   href              lab  \
# 0    https://www.encodeproject.org/files/ENCFF042WG...  thomas-gingeras
# 1    https://www.encodeproject.org/files/ENCFF708OY...  thomas-gingeras
# 2    https://www.encodeproject.org/files/ENCFF881JH...  thomas-gingeras
# 3    https://www.encodeproject.org/files/ENCFF254RP...  thomas-gingeras
# 4    https://www.encodeproject.org/files/ENCFF370KK...  thomas-gingeras
# 5    https://www.encodeproject.org/files/ENCFF096DQ...  thomas-gingeras
# 6    https://www.encodeproject.org/files/ENCFF211LI...     barbara-wold
# 7    https://www.encodeproject.org/files/ENCFF501QK...     barbara-wold
# 8    https://www.encodeproject.org/files/ENCFF887QY...     barbara-wold
# 9    https://www.encodeproject.org/files/ENCFF487AL...     barbara-wold
# 10   https://www.encodeproject.org/files/ENCFF111SE...  thomas-gingeras
# 11   https://www.encodeproject.org/files/ENCFF755GE...  thomas-gingeras
# 12   https://www.encodeproject.org/files/ENCFF985PD...  thomas-gingeras
# 13   https://www.encodeproject.org/files/ENCFF797YZ...  thomas-gingeras
# 14   https://www.encodeproject.org/files/ENCFF652PQ...  thomas-gingeras
# 15   https://www.encodeproject.org/files/ENCFF520PX...  thomas-gingeras
# 16   https://www.encodeproject.org/files/ENCFF847LU...  thomas-gingeras
# 17   https://www.encodeproject.org/files/ENCFF947SA...  thomas-gingeras
# 18   https://www.encodeproject.org/files/ENCFF229LI...  thomas-gingeras
# 19   https://www.encodeproject.org/files/ENCFF503QB...  thomas-gingeras
# 20   https://www.encodeproject.org/files/ENCFF354AZ...  thomas-gingeras
# 21   https://www.encodeproject.org/files/ENCFF505GU...  thomas-gingeras
# 22   https://www.encodeproject.org/files/ENCFF120PL...  thomas-gingeras
# 23   https://www.encodeproject.org/files/ENCFF805BV...  thomas-gingeras
# 24   https://www.encodeproject.org/files/ENCFF667WS...  thomas-gingeras
# 25   https://www.encodeproject.org/files/ENCFF562TX...  thomas-gingeras
# 26   https://www.encodeproject.org/files/ENCFF142IP...     barbara-wold
# 27   https://www.encodeproject.org/files/ENCFF990GE...     barbara-wold
# 28   https://www.encodeproject.org/files/ENCFF232GH...     barbara-wold
# 29   https://www.encodeproject.org/files/ENCFF803QG...     barbara-wold
# ..                                                 ...              ...
# 462  https://www.encodeproject.org/files/ENCFF961TG...  thomas-gingeras
# 463  https://www.encodeproject.org/files/ENCFF761BV...  thomas-gingeras
# 464  https://www.encodeproject.org/files/ENCFF199BW...  thomas-gingeras
# 465  https://www.encodeproject.org/files/ENCFF979PZ...  thomas-gingeras
# 466  https://www.encodeproject.org/files/ENCFF416NC...  thomas-gingeras
# 467  https://www.encodeproject.org/files/ENCFF598YQ...  thomas-gingeras
# 468  https://www.encodeproject.org/files/ENCFF772CW...     barbara-wold
# 469  https://www.encodeproject.org/files/ENCFF813CA...     barbara-wold
# 470  https://www.encodeproject.org/files/ENCFF263TI...     barbara-wold
# 471  https://www.encodeproject.org/files/ENCFF774MT...     barbara-wold
# 472  https://www.encodeproject.org/files/ENCFF436XM...  thomas-gingeras
# 473  https://www.encodeproject.org/files/ENCFF684KL...  thomas-gingeras
# 474  https://www.encodeproject.org/files/ENCFF110UG...  thomas-gingeras
# 475  https://www.encodeproject.org/files/ENCFF764AO...  thomas-gingeras
# 476  https://www.encodeproject.org/files/ENCFF857UY...  thomas-gingeras
# 477  https://www.encodeproject.org/files/ENCFF726GG...  thomas-gingeras
# 478  https://www.encodeproject.org/files/ENCFF803YE...  thomas-gingeras
# 479  https://www.encodeproject.org/files/ENCFF455HQ...  thomas-gingeras
# 480  https://www.encodeproject.org/files/ENCFF458UO...  thomas-gingeras
# 481  https://www.encodeproject.org/files/ENCFF461AO...  thomas-gingeras
# 482  https://www.encodeproject.org/files/ENCFF327XV...  thomas-gingeras
# 483  https://www.encodeproject.org/files/ENCFF691GE...  thomas-gingeras
# 484  https://www.encodeproject.org/files/ENCFF449AS...  thomas-gingeras
# 485  https://www.encodeproject.org/files/ENCFF346UQ...  thomas-gingeras
# 486  https://www.encodeproject.org/files/ENCFF994LO...     barbara-wold
# 487  https://www.encodeproject.org/files/ENCFF339EO...     barbara-wold
# 488  https://www.encodeproject.org/files/ENCFF232PN...     barbara-wold
# 489  https://www.encodeproject.org/files/ENCFF201GL...     barbara-wold
# 490  https://www.encodeproject.org/files/ENCFF598ZG...     barbara-wold
# 491  https://www.encodeproject.org/files/ENCFF339GU...     barbara-wold
#
#     starting   starting_units biosample_id organism      age age_units  \
# 0       None             None  ENCBS472ENC    human  unknown      None
# 1       None             None  ENCBS471ENC    human  unknown      None
# 2       None             None  ENCBS806KLM    human  unknown      None
# 3       None             None  ENCBS343AKO    human  unknown      None
# 4       None             None  ENCBS916BSF    human  unknown      None
# 5       None             None  ENCBS542LAX    human       21      week
# 6       10.0               ng  ENCBS987ARB    mouse     14.5       day
# 7       10.0               ng  ENCBS715ONU    mouse     14.5       day
# 8         10               ng  ENCBS811RMD    mouse     15.5       day
# 9         10               ng  ENCBS841GER    mouse     15.5       day
# 10      None             None  ENCBS018RNA    human       45      year
# 11      None             None  ENCBS019RNA    human        6      year
# 12      None             None  ENCBS019RNA    human        6      year
# 13      None             None  ENCBS018RNA    human       45      year
# 14      None             None  ENCBS054RNA    human       22      week
# 15      None             None  ENCBS053RNA    human       20      week
# 16      None             None  ENCBS053RNA    human       20      week
# 17      None             None  ENCBS054RNA    human       22      week
# 18      None             None  ENCBS469ENC    human  unknown      None
# 19      None             None  ENCBS470ENC    human  unknown      None
# 20      None             None  ENCBS470ENC    human  unknown      None
# 21      None             None  ENCBS469ENC    human  unknown      None
# 22      None             None  ENCBS995MDT    human  unknown      None
# 23      None             None  ENCBS386PWK    human       21      week
# 24      None             None  ENCBS446PPO    human       37      year
# 25      None             None  ENCBS641PGO    human       37      year
# 26        10               ng  ENCBS944KEZ    mouse     15.5       day
# 27        10               ng  ENCBS206NRE    mouse     15.5       day
# 28        10               ng  ENCBS243DCE    mouse     16.5       day
# 29        10               ng  ENCBS793TEW    mouse     16.5       day
# ..       ...              ...          ...      ...      ...       ...
# 462     None             None  ENCBS465ENC    human  unknown      None
# 463     None             None  ENCBS466ENC    human  unknown      None
# 464     None             None  ENCBS636GUU    human       37      year
# 465     None             None  ENCBS636GUU    human       37      year
# 466     None             None  ENCBS635PXV    human       34      year
# 467     None             None  ENCBS442ZTY    human       34      year
# 468       30  cell-equivalent  ENCBS677XMX    human        6      year
# 469       30  cell-equivalent  ENCBS998GBF    human        6      year
# 470     10.0               ng  ENCBS437LDX    mouse        0       day
# 471     10.0               ng  ENCBS809DPZ    mouse        0       day
# 472     None             None  ENCBS020RNA    human       64      year
# 473     None             None  ENCBS021RNA    human       38      year
# 474     None             None  ENCBS020RNA    human       64      year
# 475     None             None  ENCBS021RNA    human       38      year
# 476     None             None  ENCBS056RNA    human       19      week
# 477     None             None  ENCBS055RNA    human       28      week
# 478     None             None  ENCBS055RNA    human       28      week
# 479     None             None  ENCBS056RNA    human       19      week
# 480     None             None  ENCBS613ENC    human  unknown      None
# 481     None             None  ENCBS612ENC    human  unknown      None
# 482     None             None  ENCBS052WQU    human  unknown      None
# 483     None             None  ENCBS021ENC    human  unknown      None
# 484     None             None  ENCBS519AAA    human       24      year
# 485     None             None  ENCBS518AAA    human       24      year
# 486       10               ng  ENCBS955JPC    mouse     16.5       day
# 487       10               ng  ENCBS217XWR    mouse     16.5       day
# 488     10.0               ng  ENCBS337KCK    mouse        0       day
# 489     10.0               ng  ENCBS694SYF    mouse        0       day
# 490       10               ng  ENCBS273RVL    mouse     13.5       day
# 491       10               ng  ENCBS793ZRY    mouse     13.5       day
#
#                biosample_lab  biological_replicate_number  \
# 0            thomas-gingeras                            1
# 1            thomas-gingeras                            2
# 2    john-stamatoyannopoulos                            1
# 3    john-stamatoyannopoulos                            2
# 4            thomas-gingeras                            2
# 5            thomas-gingeras                            1
# 6               barbara-wold                            2
# 7               barbara-wold                            1
# 8             len-pennacchio                            1
# 9             len-pennacchio                            2
# 10           thomas-gingeras                            1
# 11           thomas-gingeras                            2
# 12           thomas-gingeras                            2
# 13           thomas-gingeras                            1
# 14           thomas-gingeras                            2
# 15           thomas-gingeras                            1
# 16           thomas-gingeras                            1
# 17           thomas-gingeras                            2
# 18           thomas-gingeras                            1
# 19           thomas-gingeras                            2
# 20           thomas-gingeras                            2
# 21           thomas-gingeras                            1
# 22           thomas-gingeras                            2
# 23           thomas-gingeras                            1
# 24           thomas-gingeras                            1
# 25           thomas-gingeras                            2
# 26            len-pennacchio                            1
# 27            len-pennacchio                            2
# 28            len-pennacchio                            1
# 29            len-pennacchio                            2
# ..                       ...                          ...
# 462          thomas-gingeras                            2
# 463          thomas-gingeras                            1
# 464          thomas-gingeras                            1
# 465          thomas-gingeras                            1
# 466          thomas-gingeras                            1
# 467          thomas-gingeras                            2
# 468             barbara-wold                            1
# 469             barbara-wold                            2
# 470             barbara-wold                            2
# 471             barbara-wold                            1
# 472          thomas-gingeras                            1
# 473          thomas-gingeras                            2
# 474          thomas-gingeras                            1
# 475          thomas-gingeras                            2
# 476          thomas-gingeras                            2
# 477          thomas-gingeras                            1
# 478          thomas-gingeras                            1
# 479          thomas-gingeras                            2
# 480          thomas-gingeras                            2
# 481          thomas-gingeras                            1
# 482  john-stamatoyannopoulos                            2
# 483  john-stamatoyannopoulos                            1
# 484  john-stamatoyannopoulos                            2
# 485  john-stamatoyannopoulos                            1
# 486           len-pennacchio                            1
# 487           len-pennacchio                            2
# 488             barbara-wold                            1
# 489             barbara-wold                            2
# 490           len-pennacchio                            1
# 491           len-pennacchio                            2
#
#      technical_replicate_number                 biosample_type  \
# 0                             1                   primary cell
# 1                             1                   primary cell
# 2                             1  in vitro differentiated cells
# 3                             1  in vitro differentiated cells
# 4                             1                   primary cell
# 5                             1                   primary cell
# 6                             1                         tissue
# 7                             1                         tissue
# 8                             1                         tissue
# 9                             1                         tissue
# 10                            1                   primary cell
# 11                            1                   primary cell
# 12                            1                   primary cell
# 13                            1                   primary cell
# 14                            1                         tissue
# 15                            1                         tissue
# 16                            1                         tissue
# 17                            1                         tissue
# 18                            1                   primary cell
# 19                            1                   primary cell
# 20                            1                   primary cell
# 21                            1                   primary cell
# 22                            1                   primary cell
# 23                            1                   primary cell
# 24                            1         immortalized cell line
# 25                            1         immortalized cell line
# 26                            1                         tissue
# 27                            1                         tissue
# 28                            1                         tissue
# 29                            1                         tissue
# ..                          ...                            ...
# 462                           1                   primary cell
# 463                           1                   primary cell
# 464                           2                         tissue
# 465                           1                         tissue
# 466                           1                   primary cell
# 467                           1                   primary cell
# 468                           1                   primary cell
# 469                           1                   primary cell
# 470                           1                         tissue
# 471                           1                         tissue
# 472                           1                   primary cell
# 473                           1                   primary cell
# 474                           1                   primary cell
# 475                           1                   primary cell
# 476                           1                         tissue
# 477                           1                         tissue
# 478                           1                         tissue
# 479                           1                         tissue
# 480                           1                   primary cell
# 481                           1                   primary cell
# 482                           1                   primary cell
# 483                           1                   primary cell
# 484                           1         immortalized cell line
# 485                           1         immortalized cell line
# 486                           1                         tissue
# 487                           1                         tissue
# 488                           1                         tissue
# 489                           1                         tissue
# 490                           1                         tissue
# 491                           1                         tissue
#
#             replication_type
# 0                 anisogenic
# 1                 anisogenic
# 2                   isogenic
# 3                   isogenic
# 4                 anisogenic
# 5                 anisogenic
# 6                   isogenic
# 7                   isogenic
# 8                   isogenic
# 9                   isogenic
# 10                anisogenic
# 11                anisogenic
# 12                anisogenic
# 13                anisogenic
# 14                anisogenic
# 15                anisogenic
# 16                anisogenic
# 17                anisogenic
# 18                  isogenic
# 19                  isogenic
# 20                  isogenic
# 21                  isogenic
# 22                anisogenic
# 23                anisogenic
# 24                  isogenic
# 25                  isogenic
# 26                  isogenic
# 27                  isogenic
# 28                  isogenic
# 29                  isogenic
# ..                       ...
# 462               anisogenic
# 463               anisogenic
# 464             unreplicated
# 465             unreplicated
# 466                 isogenic
# 467                 isogenic
# 468                 isogenic
# 469                 isogenic
# 470                 isogenic
# 471                 isogenic
# 472  anisogenic, sex-matched
# 473  anisogenic, sex-matched
# 474  anisogenic, sex-matched
# 475  anisogenic, sex-matched
# 476  anisogenic, sex-matched
# 477  anisogenic, sex-matched
# 478  anisogenic, sex-matched
# 479  anisogenic, sex-matched
# 480                 isogenic
# 481                 isogenic
# 482                 isogenic
# 483                 isogenic
# 484                 isogenic
# 485                 isogenic
# 486                 isogenic
# 487                 isogenic
# 488                 isogenic
# 489                 isogenic
# 490                 isogenic
# 491                 isogenic
#
# [492 rows x 20 columns]
