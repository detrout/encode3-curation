# %% [markdown]
# Prepare submissions for year 3 quarter 3.
#
# Our first block of submissions is stuff that was started in Y3Q1, but got dropped pending validation.

# %%
import pandas
import paramiko
import gcat

# %%
from curation_common import *

# %%
encode = ENCODED('www.encodeproject.org')
encode.load_netrc()

# %%
submission_root = 'proj/submission/encode-y3q3'
map_name = 'castaneus.txt'

# %% [markdown]
# # create biosamples

# %%
#spreadsheet_name = "Brian's Mice"
#mice_book = gcat.get_file(spreadsheet_name, fmt='pandas_excel')
#mice = mice_book.parse('Sheet 1')

# %%
#created = encode.post_sheet('/biosamples/', mice, verbose=True, dry_run=True)

# %%
#if created:
#    updates = []
#    for row in created:
#        updates.append({'uuid': row['uuid'], 'biosample_accession': row['accession'], 'aliases': row['aliases'][0]})
#    updatesdf = pandas.DataFrame(updates, columns=['uuid', 'biosample_accession', 'aliases'])
#    updatesdf.to_excel('/tmp/update.xlsx')

# %% [markdown]
# # point at y3q3 spreadsheet

# %%
spreadsheet_name = "Rabi Submissions"
book = gcat.get_file(spreadsheet_name, fmt='pandas_excel')

# %% [markdown]
# # create experiments

# %%
experiments = book.parse('Experiments')
created = encode.post_sheet('/experiments/', experiments, dry_run=False, verbose=True)
len(created)
# Out:
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'documents': ['/documents/7c6b71e2-87bd-467a-9cec-f8969ae92c57/', '/documents/9fb8e06c-d145-447a-a606-e7f3dc44b549/'], 'biosample_type': 'tissue', 'related_files': [], '@type': ['experiment', 'dataset', 'item'], 'aliases': ['ali-mortazavi:e11-5-mouse-forebrain-mirna-seq'], 'uuid': '31de9fc3-091a-4238-9f2b-60e17770837a', 'dbxrefs': [], 'date_created': '2015-09-17T21:06:26.353857+00:00', '@id': '/experiments/ENCSR240IDR/', 'assembly': [], 'award': '/awards/U54HG004576/', 'assay_term_name': 'RNA-seq', 'schema_version': '6', 'status': 'proposed', 'biosample_term_name': 'forebrain', 'assay_synonyms': ['transcription profiling by high throughput sequencing', 'RNA-seq assay'], 'contributing_files': [], 'assay_term_id': 'OBI:0001271', 'possible_controls': [], 'dataset_type': 'experiment', 'revoked_files': [], 'lab': '/labs/ali-mortazavi/', 'description': 'miRNA-seq  on embryonic 11.5 day mouse forebrain', 'references': [], 'original_files': [], 'accession': 'ENCSR240IDR', 'replicates': [], 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'alternate_accessions': [], 'files': []}]}
# row 27 created: ENCSR240IDR
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'documents': ['/documents/7c6b71e2-87bd-467a-9cec-f8969ae92c57/', '/documents/9fb8e06c-d145-447a-a606-e7f3dc44b549/'], 'original_files': [], 'related_files': [], 'biosample_term_name': 'midbrain', '@type': ['experiment', 'dataset', 'item'], 'aliases': ['ali-mortazavi:e11-5-mouse-midbrain-mirna-seq'], 'uuid': 'd45dc445-83b2-4062-8368-616e1d5593b7', 'contributing_files': [], 'description': 'miRNA-seq  on embryonic 11.5 day mouse midbrain', '@id': '/experiments/ENCSR152ETW/', 'dataset_type': 'experiment', 'award': '/awards/U54HG004576/', 'assay_term_name': 'RNA-seq', 'schema_version': '6', 'status': 'proposed', 'files': [], 'assay_synonyms': ['transcription profiling by high throughput sequencing', 'RNA-seq assay'], 'dbxrefs': [], 'assay_term_id': 'OBI:0001271', 'possible_controls': [], 'assembly': [], 'revoked_files': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:06:26.655517+00:00', 'biosample_type': 'tissue', 'accession': 'ENCSR152ETW', 'references': [], 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'replicates': [], 'alternate_accessions': []}]}
# row 28 created: ENCSR152ETW
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'documents': ['/documents/7c6b71e2-87bd-467a-9cec-f8969ae92c57/', '/documents/9fb8e06c-d145-447a-a606-e7f3dc44b549/'], 'assay_synonyms': ['transcription profiling by high throughput sequencing', 'RNA-seq assay'], 'related_files': [], 'alternate_accessions': [], 'uuid': '1cbd0513-0906-4e97-b0ae-e5726d725806', 'contributing_files': [], 'description': 'miRNA-seq  on embryonic 11.5 day mouse hindbrain', '@id': '/experiments/ENCSR234WHI/', 'dataset_type': 'experiment', 'biosample_type': 'tissue', 'status': 'proposed', 'award': '/awards/U54HG004576/', 'assay_term_name': 'RNA-seq', 'schema_version': '6', 'files': [], 'references': [], 'possible_controls': [], '@type': ['experiment', 'dataset', 'item'], 'assay_term_id': 'OBI:0001271', 'replicates': [], 'assembly': [], 'revoked_files': [], 'dbxrefs': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:06:26.934277+00:00', 'original_files': [], 'accession': 'ENCSR234WHI', 'biosample_term_name': 'hindbrain', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'aliases': ['ali-mortazavi:e11-5-mouse-hindbrain-mirna-seq']}]}
# row 29 created: ENCSR234WHI
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'documents': ['/documents/7c6b71e2-87bd-467a-9cec-f8969ae92c57/', '/documents/9fb8e06c-d145-447a-a606-e7f3dc44b549/'], 'assay_synonyms': ['transcription profiling by high throughput sequencing', 'RNA-seq assay'], 'related_files': [], 'biosample_term_name': 'cranioface', 'aliases': ['ali-mortazavi:e11-5-mouse-cranioface-mirna-seq'], 'uuid': 'afe3d5bc-d6d3-4dc3-bed9-9d5fbedb8781', 'dbxrefs': [], 'contributing_files': [], '@id': '/experiments/ENCSR091ZTZ/', 'dataset_type': 'experiment', 'original_files': [], 'status': 'proposed', 'award': '/awards/U54HG004576/', 'assay_term_name': 'RNA-seq', 'schema_version': '6', 'files': [], 'references': [], 'description': 'miRNA-seq  on embryonic 11.5 day mouse cranioface', '@type': ['experiment', 'dataset', 'item'], 'assay_term_id': 'OBI:0001271', 'possible_controls': [], 'assembly': [], 'revoked_files': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:06:27.255805+00:00', 'biosample_type': 'tissue', 'accession': 'ENCSR091ZTZ', 'replicates': [], 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'alternate_accessions': []}]}
# row 30 created: ENCSR091ZTZ
# Reponse {'@type': ['result'], 'status': 'success', '@graph': [{'documents': ['/documents/7c6b71e2-87bd-467a-9cec-f8969ae92c57/', '/documents/9fb8e06c-d145-447a-a606-e7f3dc44b549/'], 'assay_synonyms': ['transcription profiling by high throughput sequencing', 'RNA-seq assay'], 'related_files': [], 'alternate_accessions': [], 'uuid': '0e0ae8fe-60de-4818-850a-0522e7490ddc', 'dbxrefs': [], 'contributing_files': [], '@id': '/experiments/ENCSR829OXY/', 'assembly': [], 'biosample_type': 'tissue', 'award': '/awards/U54HG004576/', 'assay_term_name': 'RNA-seq', 'assay_term_id': 'OBI:0001271', 'status': 'proposed', 'biosample_term_name': 'heart', 'description': 'miRNA-seq  on embryonic 11.5 day mouse heart', '@type': ['experiment', 'dataset', 'item'], 'schema_version': '6', 'possible_controls': [], 'dataset_type': 'experiment', 'revoked_files': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:06:27.556259+00:00', 'original_files': [], 'accession': 'ENCSR829OXY', 'references': [], 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'replicates': [], 'aliases': ['ali-mortazavi:e11-5-mouse-heart-mirna-seq'], 'files': []}]}
# row 31 created: ENCSR829OXY
# Reponse {'@type': ['result'], 'status': 'success', '@graph': [{'documents': ['/documents/7c6b71e2-87bd-467a-9cec-f8969ae92c57/', '/documents/9fb8e06c-d145-447a-a606-e7f3dc44b549/'], 'assay_term_name': 'RNA-seq', 'original_files': [], 'related_files': [], 'alternate_accessions': [], 'uuid': 'c374ad14-3be1-49a0-aa86-db9ae6214783', 'dbxrefs': [], 'contributing_files': [], '@id': '/experiments/ENCSR489FQD/', 'assembly': [], 'status': 'proposed', 'award': '/awards/U54HG004576/', 'description': 'miRNA-seq  on embryonic 11.5 day mouse liver', 'assay_term_id': 'OBI:0001271', 'files': [], 'references': [], 'assay_synonyms': ['transcription profiling by high throughput sequencing', 'RNA-seq assay'], '@type': ['experiment', 'dataset', 'item'], 'schema_version': '6', 'possible_controls': [], 'dataset_type': 'experiment', 'revoked_files': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:06:27.869096+00:00', 'biosample_type': 'tissue', 'accession': 'ENCSR489FQD', 'biosample_term_name': 'liver', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'replicates': [], 'aliases': ['ali-mortazavi:e11-5-mouse-liver-mirna-seq']}]}
# row 32 created: ENCSR489FQD
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'documents': ['/documents/7c6b71e2-87bd-467a-9cec-f8969ae92c57/', '/documents/9fb8e06c-d145-447a-a606-e7f3dc44b549/'], 'original_files': [], 'related_files': [], 'biosample_term_name': 'limb', '@type': ['experiment', 'dataset', 'item'], 'aliases': ['ali-mortazavi:e11-5-mouse-limb-mirna-seq'], 'uuid': '336dff5d-7920-43be-8f5b-34771619ab0f', 'contributing_files': [], 'description': 'miRNA-seq  on embryonic 11.5 day mouse limb', '@id': '/experiments/ENCSR900DXS/', 'dataset_type': 'experiment', 'award': '/awards/U54HG004576/', 'assay_term_name': 'RNA-seq', 'schema_version': '6', 'status': 'proposed', 'files': [], 'assay_synonyms': ['transcription profiling by high throughput sequencing', 'RNA-seq assay'], 'dbxrefs': [], 'assay_term_id': 'OBI:0001271', 'possible_controls': [], 'assembly': [], 'revoked_files': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:06:28.152875+00:00', 'biosample_type': 'tissue', 'accession': 'ENCSR900DXS', 'references': [], 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'replicates': [], 'alternate_accessions': []}]}
# row 33 created: ENCSR900DXS
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'documents': ['/documents/7c6b71e2-87bd-467a-9cec-f8969ae92c57/', '/documents/9fb8e06c-d145-447a-a606-e7f3dc44b549/'], 'assay_synonyms': ['transcription profiling by high throughput sequencing', 'RNA-seq assay'], 'related_files': [], 'alternate_accessions': [], 'uuid': 'df418f23-d226-4534-923d-075511188bba', 'contributing_files': [], 'description': 'miRNA-seq  on embryonic 11.5 day mouse neural tube', '@id': '/experiments/ENCSR553BCA/', 'dataset_type': 'experiment', 'biosample_type': 'tissue', 'status': 'proposed', 'award': '/awards/U54HG004576/', 'assay_term_name': 'RNA-seq', 'schema_version': '6', 'files': [], 'references': [], 'possible_controls': [], '@type': ['experiment', 'dataset', 'item'], 'assay_term_id': 'OBI:0001271', 'replicates': [], 'assembly': [], 'revoked_files': [], 'dbxrefs': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:06:28.408613+00:00', 'original_files': [], 'accession': 'ENCSR553BCA', 'biosample_term_name': 'neural tube', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'aliases': ['ali-mortazavi:e11-5-mouse-neural tube-mirna-seq']}]}
# row 34 created: ENCSR553BCA
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'documents': ['/documents/7c6b71e2-87bd-467a-9cec-f8969ae92c57/', '/documents/9fb8e06c-d145-447a-a606-e7f3dc44b549/'], 'original_files': [], 'related_files': [], 'biosample_term_name': 'forebrain', '@type': ['experiment', 'dataset', 'item'], 'aliases': ['ali-mortazavi:e14-5-mouse-forebrain-mirna-seq'], 'uuid': '166f7113-3d95-4ac3-8f32-21d34796b5e1', 'contributing_files': [], 'description': 'miRNA-seq  on embryonic 14.5 day mouse forebrain', '@id': '/experiments/ENCSR665JCF/', 'dataset_type': 'experiment', 'award': '/awards/U54HG004576/', 'assay_term_name': 'RNA-seq', 'schema_version': '6', 'status': 'proposed', 'files': [], 'assay_synonyms': ['transcription profiling by high throughput sequencing', 'RNA-seq assay'], 'dbxrefs': [], 'assay_term_id': 'OBI:0001271', 'possible_controls': [], 'assembly': [], 'revoked_files': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:06:28.723556+00:00', 'biosample_type': 'tissue', 'accession': 'ENCSR665JCF', 'references': [], 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'replicates': [], 'alternate_accessions': []}]}
# row 35 created: ENCSR665JCF
# Reponse {'@type': ['result'], 'status': 'success', '@graph': [{'documents': ['/documents/7c6b71e2-87bd-467a-9cec-f8969ae92c57/', '/documents/9fb8e06c-d145-447a-a606-e7f3dc44b549/'], 'assay_term_name': 'RNA-seq', 'original_files': [], 'related_files': [], 'alternate_accessions': [], 'uuid': 'ad67bf5b-f0bd-4769-9d04-d6f34c88f386', 'dbxrefs': [], 'contributing_files': [], '@id': '/experiments/ENCSR863FYW/', 'assembly': [], 'status': 'proposed', 'award': '/awards/U54HG004576/', 'description': 'miRNA-seq  on embryonic 14.5 day mouse midbrain', 'assay_term_id': 'OBI:0001271', 'files': [], 'references': [], 'assay_synonyms': ['transcription profiling by high throughput sequencing', 'RNA-seq assay'], '@type': ['experiment', 'dataset', 'item'], 'schema_version': '6', 'possible_controls': [], 'dataset_type': 'experiment', 'revoked_files': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:06:28.978990+00:00', 'biosample_type': 'tissue', 'accession': 'ENCSR863FYW', 'biosample_term_name': 'midbrain', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'replicates': [], 'aliases': ['ali-mortazavi:e14-5-mouse-midbrain-mirna-seq']}]}
# row 36 created: ENCSR863FYW
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'documents': ['/documents/7c6b71e2-87bd-467a-9cec-f8969ae92c57/', '/documents/9fb8e06c-d145-447a-a606-e7f3dc44b549/'], 'assay_synonyms': ['transcription profiling by high throughput sequencing', 'RNA-seq assay'], 'related_files': [], 'biosample_term_name': 'hindbrain', 'aliases': ['ali-mortazavi:e14-5-mouse-hindbrain-mirna-seq'], 'uuid': '41dfec86-c40c-4126-bbd9-0cf9e72ceff7', 'dbxrefs': [], 'contributing_files': [], '@id': '/experiments/ENCSR677GOF/', 'dataset_type': 'experiment', 'original_files': [], 'status': 'proposed', 'award': '/awards/U54HG004576/', 'assay_term_name': 'RNA-seq', 'schema_version': '6', 'files': [], 'references': [], 'description': 'miRNA-seq  on embryonic 14.5 day mouse hindbrain', '@type': ['experiment', 'dataset', 'item'], 'assay_term_id': 'OBI:0001271', 'possible_controls': [], 'assembly': [], 'revoked_files': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:06:29.241933+00:00', 'biosample_type': 'tissue', 'accession': 'ENCSR677GOF', 'replicates': [], 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'alternate_accessions': []}]}
# row 37 created: ENCSR677GOF
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'documents': ['/documents/7c6b71e2-87bd-467a-9cec-f8969ae92c57/', '/documents/9fb8e06c-d145-447a-a606-e7f3dc44b549/'], 'assay_synonyms': ['transcription profiling by high throughput sequencing', 'RNA-seq assay'], 'related_files': [], 'alternate_accessions': [], 'uuid': 'b6f4f574-d14d-4155-ae75-afa8d0ccdeb2', 'contributing_files': [], 'description': 'miRNA-seq  on embryonic 14.5 day mouse cranioface', '@id': '/experiments/ENCSR199LBO/', 'dataset_type': 'experiment', 'biosample_type': 'tissue', 'status': 'proposed', 'award': '/awards/U54HG004576/', 'assay_term_name': 'RNA-seq', 'schema_version': '6', 'files': [], 'references': [], 'possible_controls': [], '@type': ['experiment', 'dataset', 'item'], 'assay_term_id': 'OBI:0001271', 'replicates': [], 'assembly': [], 'revoked_files': [], 'dbxrefs': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:06:29.487446+00:00', 'original_files': [], 'accession': 'ENCSR199LBO', 'biosample_term_name': 'cranioface', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'aliases': ['ali-mortazavi:e14-5-mouse-cranioface-mirna-seq']}]}
# row 38 created: ENCSR199LBO
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'documents': ['/documents/7c6b71e2-87bd-467a-9cec-f8969ae92c57/', '/documents/9fb8e06c-d145-447a-a606-e7f3dc44b549/'], 'assay_synonyms': ['transcription profiling by high throughput sequencing', 'RNA-seq assay'], 'related_files': [], 'biosample_term_name': 'liver', 'aliases': ['ali-mortazavi:e14-5-mouse-liver-mirna-seq'], 'uuid': '91287ee5-8333-4b8a-b88e-e482616397fc', 'dbxrefs': [], 'contributing_files': [], '@id': '/experiments/ENCSR510TFQ/', 'dataset_type': 'experiment', 'original_files': [], 'status': 'proposed', 'award': '/awards/U54HG004576/', 'assay_term_name': 'RNA-seq', 'schema_version': '6', 'files': [], 'references': [], 'description': 'miRNA-seq  on embryonic 14.5 day mouse liver', '@type': ['experiment', 'dataset', 'item'], 'assay_term_id': 'OBI:0001271', 'possible_controls': [], 'assembly': [], 'revoked_files': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:06:29.752047+00:00', 'biosample_type': 'tissue', 'accession': 'ENCSR510TFQ', 'replicates': [], 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'alternate_accessions': []}]}
# row 39 created: ENCSR510TFQ
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'documents': ['/documents/7c6b71e2-87bd-467a-9cec-f8969ae92c57/', '/documents/9fb8e06c-d145-447a-a606-e7f3dc44b549/'], 'original_files': [], 'related_files': [], 'biosample_term_name': 'lung', '@type': ['experiment', 'dataset', 'item'], 'aliases': ['ali-mortazavi:e14-5-mouse-lung-mirna-seq'], 'uuid': 'f3f8dd17-56b3-4994-b15d-7eba66a5917c', 'contributing_files': [], 'description': 'miRNA-seq  on embryonic 14.5 day mouse lung', '@id': '/experiments/ENCSR185XJA/', 'dataset_type': 'experiment', 'award': '/awards/U54HG004576/', 'assay_term_name': 'RNA-seq', 'schema_version': '6', 'status': 'proposed', 'files': [], 'assay_synonyms': ['transcription profiling by high throughput sequencing', 'RNA-seq assay'], 'dbxrefs': [], 'assay_term_id': 'OBI:0001271', 'possible_controls': [], 'assembly': [], 'revoked_files': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:06:29.991267+00:00', 'biosample_type': 'tissue', 'accession': 'ENCSR185XJA', 'references': [], 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'replicates': [], 'alternate_accessions': []}]}
# row 40 created: ENCSR185XJA
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'documents': ['/documents/7c6b71e2-87bd-467a-9cec-f8969ae92c57/', '/documents/9fb8e06c-d145-447a-a606-e7f3dc44b549/'], 'biosample_type': 'tissue', 'related_files': [], '@type': ['experiment', 'dataset', 'item'], 'aliases': ['ali-mortazavi:e14-5-mouse-limb-mirna-seq'], 'uuid': '3f95144b-ded8-4cbb-a9ac-40b132bb125e', 'dbxrefs': [], 'date_created': '2015-09-17T21:06:30.230851+00:00', '@id': '/experiments/ENCSR669XBU/', 'assembly': [], 'award': '/awards/U54HG004576/', 'assay_term_name': 'RNA-seq', 'schema_version': '6', 'status': 'proposed', 'biosample_term_name': 'limb', 'assay_synonyms': ['transcription profiling by high throughput sequencing', 'RNA-seq assay'], 'contributing_files': [], 'assay_term_id': 'OBI:0001271', 'possible_controls': [], 'dataset_type': 'experiment', 'revoked_files': [], 'lab': '/labs/ali-mortazavi/', 'description': 'miRNA-seq  on embryonic 14.5 day mouse limb', 'references': [], 'original_files': [], 'accession': 'ENCSR669XBU', 'replicates': [], 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'alternate_accessions': [], 'files': []}]}
# row 41 created: ENCSR669XBU
# Reponse {'@type': ['result'], 'status': 'success', '@graph': [{'documents': ['/documents/7c6b71e2-87bd-467a-9cec-f8969ae92c57/', '/documents/9fb8e06c-d145-447a-a606-e7f3dc44b549/'], 'assay_synonyms': ['transcription profiling by high throughput sequencing', 'RNA-seq assay'], 'related_files': [], 'alternate_accessions': [], 'uuid': 'ebeb171e-028f-4322-acd7-f49017362bab', 'dbxrefs': [], 'contributing_files': [], '@id': '/experiments/ENCSR609EDL/', 'assembly': [], 'biosample_type': 'tissue', 'award': '/awards/U54HG004576/', 'assay_term_name': 'RNA-seq', 'assay_term_id': 'OBI:0001271', 'status': 'proposed', 'biosample_term_name': 'heart', 'description': 'miRNA-seq  on embryonic 14.5 day mouse heart', '@type': ['experiment', 'dataset', 'item'], 'schema_version': '6', 'possible_controls': [], 'dataset_type': 'experiment', 'revoked_files': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:06:30.515902+00:00', 'original_files': [], 'accession': 'ENCSR609EDL', 'references': [], 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'replicates': [], 'aliases': ['ali-mortazavi:e14-5-mouse-heart-mirna-seq'], 'files': []}]}
# row 42 created: ENCSR609EDL
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'documents': ['/documents/7c6b71e2-87bd-467a-9cec-f8969ae92c57/', '/documents/9fb8e06c-d145-447a-a606-e7f3dc44b549/'], 'original_files': [], 'related_files': [], 'biosample_term_name': 'stomach', '@type': ['experiment', 'dataset', 'item'], 'aliases': ['ali-mortazavi:e14-5-mouse-stomach-mirna-seq'], 'uuid': 'd9fcb32d-883f-4168-be0e-48d7b5c67d9b', 'contributing_files': [], 'description': 'miRNA-seq  on embryonic 14.5 day mouse stomach', '@id': '/experiments/ENCSR974QTI/', 'dataset_type': 'experiment', 'award': '/awards/U54HG004576/', 'assay_term_name': 'RNA-seq', 'schema_version': '6', 'status': 'proposed', 'files': [], 'assay_synonyms': ['transcription profiling by high throughput sequencing', 'RNA-seq assay'], 'dbxrefs': [], 'assay_term_id': 'OBI:0001271', 'possible_controls': [], 'assembly': [], 'revoked_files': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:06:30.774298+00:00', 'biosample_type': 'tissue', 'accession': 'ENCSR974QTI', 'references': [], 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'replicates': [], 'alternate_accessions': []}]}
# row 43 created: ENCSR974QTI
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'documents': ['/documents/7c6b71e2-87bd-467a-9cec-f8969ae92c57/', '/documents/9fb8e06c-d145-447a-a606-e7f3dc44b549/'], 'assay_synonyms': ['transcription profiling by high throughput sequencing', 'RNA-seq assay'], 'related_files': [], 'alternate_accessions': [], 'uuid': '7e401f95-26cc-4cbb-97b2-0e0e541c1852', 'contributing_files': [], 'description': 'miRNA-seq  on embryonic 14.5 day mouse intestine', '@id': '/experiments/ENCSR580VUW/', 'dataset_type': 'experiment', 'biosample_type': 'tissue', 'status': 'proposed', 'award': '/awards/U54HG004576/', 'assay_term_name': 'RNA-seq', 'schema_version': '6', 'files': [], 'references': [], 'possible_controls': [], '@type': ['experiment', 'dataset', 'item'], 'assay_term_id': 'OBI:0001271', 'replicates': [], 'assembly': [], 'revoked_files': [], 'dbxrefs': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:06:31.063553+00:00', 'original_files': [], 'accession': 'ENCSR580VUW', 'biosample_term_name': 'intestine', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'aliases': ['ali-mortazavi:e14-5-mouse-intestine-mirna-seq']}]}
# row 44 created: ENCSR580VUW
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'documents': ['/documents/7c6b71e2-87bd-467a-9cec-f8969ae92c57/', '/documents/9fb8e06c-d145-447a-a606-e7f3dc44b549/'], 'assay_synonyms': ['transcription profiling by high throughput sequencing', 'RNA-seq assay'], 'related_files': [], 'biosample_term_name': 'neural tube', 'aliases': ['ali-mortazavi:e14-5-mouse-neural tube-mirna-seq'], 'uuid': 'fbcab85e-b895-465b-822f-53dea2580d74', 'dbxrefs': [], 'contributing_files': [], '@id': '/experiments/ENCSR498DIP/', 'dataset_type': 'experiment', 'original_files': [], 'status': 'proposed', 'award': '/awards/U54HG004576/', 'assay_term_name': 'RNA-seq', 'schema_version': '6', 'files': [], 'references': [], 'description': 'miRNA-seq  on embryonic 14.5 day mouse neural tube', '@type': ['experiment', 'dataset', 'item'], 'assay_term_id': 'OBI:0001271', 'possible_controls': [], 'assembly': [], 'revoked_files': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:06:31.332938+00:00', 'biosample_type': 'tissue', 'accession': 'ENCSR498DIP', 'replicates': [], 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'alternate_accessions': []}]}
# row 45 created: ENCSR498DIP
# Reponse {'@type': ['result'], 'status': 'success', '@graph': [{'documents': ['/documents/7c6b71e2-87bd-467a-9cec-f8969ae92c57/', '/documents/9fb8e06c-d145-447a-a606-e7f3dc44b549/'], 'assay_term_name': 'RNA-seq', 'original_files': [], 'related_files': [], 'alternate_accessions': [], 'uuid': 'a70052c7-f7ef-4f16-820e-62208a54fd98', 'dbxrefs': [], 'contributing_files': [], '@id': '/experiments/ENCSR497ERE/', 'assembly': [], 'status': 'proposed', 'award': '/awards/U54HG004576/', 'description': 'miRNA-seq  on embryonic 14.5 day mouse kidney', 'assay_term_id': 'OBI:0001271', 'files': [], 'references': [], 'assay_synonyms': ['transcription profiling by high throughput sequencing', 'RNA-seq assay'], '@type': ['experiment', 'dataset', 'item'], 'schema_version': '6', 'possible_controls': [], 'dataset_type': 'experiment', 'revoked_files': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:06:31.595376+00:00', 'biosample_type': 'tissue', 'accession': 'ENCSR497ERE', 'biosample_term_name': 'kidney', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'replicates': [], 'aliases': ['ali-mortazavi:e14-5-mouse-kidney-mirna-seq']}]}
# row 46 created: ENCSR497ERE
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'documents': ['/documents/7c6b71e2-87bd-467a-9cec-f8969ae92c57/', '/documents/9fb8e06c-d145-447a-a606-e7f3dc44b549/'], 'assay_synonyms': ['transcription profiling by high throughput sequencing', 'RNA-seq assay'], 'related_files': [], 'biosample_term_name': 'forebrain', 'aliases': ['ali-mortazavi:P0-mouse-forebrain-mirna-seq'], 'uuid': 'fa8877a0-653e-46f3-ad38-91818606d12d', 'dbxrefs': [], 'contributing_files': [], '@id': '/experiments/ENCSR267CQC/', 'dataset_type': 'experiment', 'original_files': [], 'status': 'proposed', 'award': '/awards/U54HG004576/', 'assay_term_name': 'RNA-seq', 'schema_version': '6', 'files': [], 'references': [], 'description': 'miRNA-seq  on postnatal 0 day mouse forebrain', '@type': ['experiment', 'dataset', 'item'], 'assay_term_id': 'OBI:0001271', 'possible_controls': [], 'assembly': [], 'revoked_files': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:06:31.836967+00:00', 'biosample_type': 'tissue', 'accession': 'ENCSR267CQC', 'replicates': [], 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'alternate_accessions': []}]}
# row 47 created: ENCSR267CQC
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'documents': ['/documents/7c6b71e2-87bd-467a-9cec-f8969ae92c57/', '/documents/9fb8e06c-d145-447a-a606-e7f3dc44b549/'], 'assay_synonyms': ['transcription profiling by high throughput sequencing', 'RNA-seq assay'], 'related_files': [], 'alternate_accessions': [], 'uuid': '185b1184-145d-4a6e-9f07-2864e17b27b5', 'contributing_files': [], 'description': 'miRNA-seq  on postnatal 0 day mouse midbrain', '@id': '/experiments/ENCSR353XMS/', 'dataset_type': 'experiment', 'biosample_type': 'tissue', 'status': 'proposed', 'award': '/awards/U54HG004576/', 'assay_term_name': 'RNA-seq', 'schema_version': '6', 'files': [], 'references': [], 'possible_controls': [], '@type': ['experiment', 'dataset', 'item'], 'assay_term_id': 'OBI:0001271', 'replicates': [], 'assembly': [], 'revoked_files': [], 'dbxrefs': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:06:32.125372+00:00', 'original_files': [], 'accession': 'ENCSR353XMS', 'biosample_term_name': 'midbrain', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'aliases': ['ali-mortazavi:P0-mouse-midbrain-mirna-seq']}]}
# row 48 created: ENCSR353XMS
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'documents': ['/documents/7c6b71e2-87bd-467a-9cec-f8969ae92c57/', '/documents/9fb8e06c-d145-447a-a606-e7f3dc44b549/'], 'assay_synonyms': ['transcription profiling by high throughput sequencing', 'RNA-seq assay'], 'related_files': [], 'biosample_term_name': 'hindbrain', 'aliases': ['ali-mortazavi:P0-mouse-hindbrain-mirna-seq'], 'uuid': 'abad13f3-f5b2-467e-9832-402479d3fa16', 'dbxrefs': [], 'contributing_files': [], '@id': '/experiments/ENCSR308SIN/', 'dataset_type': 'experiment', 'original_files': [], 'status': 'proposed', 'award': '/awards/U54HG004576/', 'assay_term_name': 'RNA-seq', 'schema_version': '6', 'files': [], 'references': [], 'description': 'miRNA-seq  on postnatal 0 day mouse hindbrain', '@type': ['experiment', 'dataset', 'item'], 'assay_term_id': 'OBI:0001271', 'possible_controls': [], 'assembly': [], 'revoked_files': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:06:32.429336+00:00', 'biosample_type': 'tissue', 'accession': 'ENCSR308SIN', 'replicates': [], 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'alternate_accessions': []}]}
# row 49 created: ENCSR308SIN
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'documents': ['/documents/7c6b71e2-87bd-467a-9cec-f8969ae92c57/', '/documents/9fb8e06c-d145-447a-a606-e7f3dc44b549/'], 'original_files': [], 'related_files': [], 'biosample_term_name': 'neural tube', '@type': ['experiment', 'dataset', 'item'], 'aliases': ['ali-mortazavi:P0-mouse-neural tube-mirna-seq'], 'uuid': 'f2e52466-9835-41a8-a0e0-bd92c7f2dfe8', 'contributing_files': [], 'description': 'miRNA-seq  on postnatal 0 day mouse neural tube', '@id': '/experiments/ENCSR236BQO/', 'dataset_type': 'experiment', 'award': '/awards/U54HG004576/', 'assay_term_name': 'RNA-seq', 'schema_version': '6', 'status': 'proposed', 'files': [], 'assay_synonyms': ['transcription profiling by high throughput sequencing', 'RNA-seq assay'], 'dbxrefs': [], 'assay_term_id': 'OBI:0001271', 'possible_controls': [], 'assembly': [], 'revoked_files': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:06:32.660862+00:00', 'biosample_type': 'tissue', 'accession': 'ENCSR236BQO', 'references': [], 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'replicates': [], 'alternate_accessions': []}]}
# row 50 created: ENCSR236BQO
# Reponse {'@type': ['result'], 'status': 'success', '@graph': [{'documents': ['/documents/7c6b71e2-87bd-467a-9cec-f8969ae92c57/', '/documents/9fb8e06c-d145-447a-a606-e7f3dc44b549/'], 'assay_synonyms': ['transcription profiling by high throughput sequencing', 'RNA-seq assay'], 'related_files': [], 'alternate_accessions': [], 'uuid': '3b31408d-95ee-4f80-9d29-00cbb98ff86b', 'dbxrefs': [], 'contributing_files': [], '@id': '/experiments/ENCSR047EJT/', 'assembly': [], 'biosample_type': 'tissue', 'award': '/awards/U54HG004576/', 'assay_term_name': 'RNA-seq', 'assay_term_id': 'OBI:0001271', 'status': 'proposed', 'biosample_term_name': 'thymus', 'description': 'miRNA-seq  on postnatal 0 day mouse thymus', '@type': ['experiment', 'dataset', 'item'], 'schema_version': '6', 'possible_controls': [], 'dataset_type': 'experiment', 'revoked_files': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:06:32.920897+00:00', 'original_files': [], 'accession': 'ENCSR047EJT', 'references': [], 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'replicates': [], 'aliases': ['ali-mortazavi:P0-mouse-thymus-mirna-seq'], 'files': []}]}
# row 51 created: ENCSR047EJT
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'documents': ['/documents/7c6b71e2-87bd-467a-9cec-f8969ae92c57/', '/documents/9fb8e06c-d145-447a-a606-e7f3dc44b549/'], 'original_files': [], 'related_files': [], 'biosample_term_name': 'heart', '@type': ['experiment', 'dataset', 'item'], 'aliases': ['ali-mortazavi:P0-mouse-heart-mirna-seq'], 'uuid': '51869d16-c012-4cdc-a4da-4a31a2eb83d3', 'contributing_files': [], 'description': 'miRNA-seq  on postnatal 0 day mouse heart', '@id': '/experiments/ENCSR246CIO/', 'dataset_type': 'experiment', 'award': '/awards/U54HG004576/', 'assay_term_name': 'RNA-seq', 'schema_version': '6', 'status': 'proposed', 'files': [], 'assay_synonyms': ['transcription profiling by high throughput sequencing', 'RNA-seq assay'], 'dbxrefs': [], 'assay_term_id': 'OBI:0001271', 'possible_controls': [], 'assembly': [], 'revoked_files': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:06:33.188708+00:00', 'biosample_type': 'tissue', 'accession': 'ENCSR246CIO', 'references': [], 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'replicates': [], 'alternate_accessions': []}]}
# row 52 created: ENCSR246CIO
# Reponse {'@type': ['result'], 'status': 'success', '@graph': [{'documents': ['/documents/7c6b71e2-87bd-467a-9cec-f8969ae92c57/', '/documents/9fb8e06c-d145-447a-a606-e7f3dc44b549/'], 'assay_term_name': 'RNA-seq', 'original_files': [], 'related_files': [], 'alternate_accessions': [], 'uuid': '17c85cb4-de59-4587-a5de-f229f2d6dbeb', 'dbxrefs': [], 'contributing_files': [], '@id': '/experiments/ENCSR161PUT/', 'assembly': [], 'status': 'proposed', 'award': '/awards/U54HG004576/', 'description': 'miRNA-seq  on postnatal 0 day mouse lung', 'assay_term_id': 'OBI:0001271', 'files': [], 'references': [], 'assay_synonyms': ['transcription profiling by high throughput sequencing', 'RNA-seq assay'], '@type': ['experiment', 'dataset', 'item'], 'schema_version': '6', 'possible_controls': [], 'dataset_type': 'experiment', 'revoked_files': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:06:33.455329+00:00', 'biosample_type': 'tissue', 'accession': 'ENCSR161PUT', 'biosample_term_name': 'lung', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'replicates': [], 'aliases': ['ali-mortazavi:P0-mouse-lung-mirna-seq']}]}
# row 53 created: ENCSR161PUT
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'documents': ['/documents/7c6b71e2-87bd-467a-9cec-f8969ae92c57/', '/documents/9fb8e06c-d145-447a-a606-e7f3dc44b549/'], 'assay_synonyms': ['transcription profiling by high throughput sequencing', 'RNA-seq assay'], 'related_files': [], 'biosample_term_name': 'liver', 'aliases': ['ali-mortazavi:P0-mouse-liver-mirna-seq'], 'uuid': 'c9035765-5ed6-4aea-97e1-e1f8ac3957cb', 'dbxrefs': [], 'contributing_files': [], '@id': '/experiments/ENCSR456CZD/', 'dataset_type': 'experiment', 'original_files': [], 'status': 'proposed', 'award': '/awards/U54HG004576/', 'assay_term_name': 'RNA-seq', 'schema_version': '6', 'files': [], 'references': [], 'description': 'miRNA-seq  on postnatal 0 day mouse liver', '@type': ['experiment', 'dataset', 'item'], 'assay_term_id': 'OBI:0001271', 'possible_controls': [], 'assembly': [], 'revoked_files': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:06:33.727422+00:00', 'biosample_type': 'tissue', 'accession': 'ENCSR456CZD', 'replicates': [], 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'alternate_accessions': []}]}
# row 54 created: ENCSR456CZD
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'documents': ['/documents/7c6b71e2-87bd-467a-9cec-f8969ae92c57/', '/documents/9fb8e06c-d145-447a-a606-e7f3dc44b549/'], 'biosample_type': 'tissue', 'related_files': [], '@type': ['experiment', 'dataset', 'item'], 'aliases': ['ali-mortazavi:P0-mouse-skeletal muscle-mirna-seq'], 'uuid': '97ab650c-ea8e-45ea-baf6-b9c05b238196', 'dbxrefs': [], 'date_created': '2015-09-17T21:06:33.960399+00:00', '@id': '/experiments/ENCSR242CPC/', 'assembly': [], 'award': '/awards/U54HG004576/', 'assay_term_name': 'RNA-seq', 'schema_version': '6', 'status': 'proposed', 'biosample_term_name': 'skeletal muscle', 'assay_synonyms': ['transcription profiling by high throughput sequencing', 'RNA-seq assay'], 'contributing_files': [], 'assay_term_id': 'OBI:0001271', 'possible_controls': [], 'dataset_type': 'experiment', 'revoked_files': [], 'lab': '/labs/ali-mortazavi/', 'description': 'miRNA-seq  on postnatal 0 day mouse skeletal muscle', 'references': [], 'original_files': [], 'accession': 'ENCSR242CPC', 'replicates': [], 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'alternate_accessions': [], 'files': []}]}
# row 55 created: ENCSR242CPC
# Reponse {'@type': ['result'], 'status': 'success', '@graph': [{'documents': ['/documents/7c6b71e2-87bd-467a-9cec-f8969ae92c57/', '/documents/9fb8e06c-d145-447a-a606-e7f3dc44b549/'], 'assay_synonyms': ['transcription profiling by high throughput sequencing', 'RNA-seq assay'], 'related_files': [], 'alternate_accessions': [], 'uuid': '31047b37-377a-4445-a4fd-40514beccbe6', 'dbxrefs': [], 'contributing_files': [], '@id': '/experiments/ENCSR694SDO/', 'assembly': [], 'biosample_type': 'tissue', 'award': '/awards/U54HG004576/', 'assay_term_name': 'RNA-seq', 'assay_term_id': 'OBI:0001271', 'status': 'proposed', 'biosample_term_name': 'bladder', 'description': 'miRNA-seq  on postnatal 0 day mouse bladder', '@type': ['experiment', 'dataset', 'item'], 'schema_version': '6', 'possible_controls': [], 'dataset_type': 'experiment', 'revoked_files': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:06:34.240045+00:00', 'original_files': [], 'accession': 'ENCSR694SDO', 'references': [], 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'replicates': [], 'aliases': ['ali-mortazavi:P0-mouse-bladder-mirna-seq'], 'files': []}]}
# row 56 created: ENCSR694SDO
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'documents': ['/documents/7c6b71e2-87bd-467a-9cec-f8969ae92c57/', '/documents/9fb8e06c-d145-447a-a606-e7f3dc44b549/'], 'assay_synonyms': ['transcription profiling by high throughput sequencing', 'RNA-seq assay'], 'related_files': [], 'alternate_accessions': [], 'uuid': '98698c52-fd9d-4156-ac58-b7b0848239b3', 'contributing_files': [], 'description': 'miRNA-seq  on postnatal 0 day mouse stomach', '@id': '/experiments/ENCSR538NTY/', 'dataset_type': 'experiment', 'biosample_type': 'tissue', 'status': 'proposed', 'award': '/awards/U54HG004576/', 'assay_term_name': 'RNA-seq', 'schema_version': '6', 'files': [], 'references': [], 'possible_controls': [], '@type': ['experiment', 'dataset', 'item'], 'assay_term_id': 'OBI:0001271', 'replicates': [], 'assembly': [], 'revoked_files': [], 'dbxrefs': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:06:34.506096+00:00', 'original_files': [], 'accession': 'ENCSR538NTY', 'biosample_term_name': 'stomach', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'aliases': ['ali-mortazavi:P0-mouse-stomach-mirna-seq']}]}
# row 57 created: ENCSR538NTY
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'documents': ['/documents/7c6b71e2-87bd-467a-9cec-f8969ae92c57/', '/documents/9fb8e06c-d145-447a-a606-e7f3dc44b549/'], 'biosample_type': 'tissue', 'related_files': [], '@type': ['experiment', 'dataset', 'item'], 'aliases': ['ali-mortazavi:P0-mouse-intestine-mirna-seq'], 'uuid': '82dc914d-e0de-40ca-8002-e3bb21d08545', 'dbxrefs': [], 'date_created': '2015-09-17T21:06:34.752502+00:00', '@id': '/experiments/ENCSR832DUZ/', 'assembly': [], 'award': '/awards/U54HG004576/', 'assay_term_name': 'RNA-seq', 'schema_version': '6', 'status': 'proposed', 'biosample_term_name': 'intestine', 'assay_synonyms': ['transcription profiling by high throughput sequencing', 'RNA-seq assay'], 'contributing_files': [], 'assay_term_id': 'OBI:0001271', 'possible_controls': [], 'dataset_type': 'experiment', 'revoked_files': [], 'lab': '/labs/ali-mortazavi/', 'description': 'miRNA-seq  on postnatal 0 day mouse intestine', 'references': [], 'original_files': [], 'accession': 'ENCSR832DUZ', 'replicates': [], 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'alternate_accessions': [], 'files': []}]}
# row 58 created: ENCSR832DUZ
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'documents': ['/documents/7c6b71e2-87bd-467a-9cec-f8969ae92c57/', '/documents/9fb8e06c-d145-447a-a606-e7f3dc44b549/'], 'assay_synonyms': ['transcription profiling by high throughput sequencing', 'RNA-seq assay'], 'related_files': [], 'alternate_accessions': [], 'uuid': 'c7b75211-de3b-4e37-b638-55a79e6d02d6', 'contributing_files': [], 'description': 'miRNA-seq  on postnatal 0 day mouse kidney', '@id': '/experiments/ENCSR484EVA/', 'dataset_type': 'experiment', 'biosample_type': 'tissue', 'status': 'proposed', 'award': '/awards/U54HG004576/', 'assay_term_name': 'RNA-seq', 'schema_version': '6', 'files': [], 'references': [], 'possible_controls': [], '@type': ['experiment', 'dataset', 'item'], 'assay_term_id': 'OBI:0001271', 'replicates': [], 'assembly': [], 'revoked_files': [], 'dbxrefs': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:06:35.023612+00:00', 'original_files': [], 'accession': 'ENCSR484EVA', 'biosample_term_name': 'kidney', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'aliases': ['ali-mortazavi:P0-mouse-kidney-mirna-seq']}]}
# row 59 created: ENCSR484EVA
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'documents': ['/documents/7c6b71e2-87bd-467a-9cec-f8969ae92c57/', '/documents/9fb8e06c-d145-447a-a606-e7f3dc44b549/'], 'assay_synonyms': ['transcription profiling by high throughput sequencing', 'RNA-seq assay'], 'related_files': [], 'biosample_term_name': 'adrenals', 'aliases': ['ali-mortazavi:P0-mouse-adrenals-mirna-seq'], 'uuid': '1dce2973-3a9d-4a14-bcc0-fa8ed53294c0', 'dbxrefs': [], 'contributing_files': [], '@id': '/experiments/ENCSR949VVK/', 'dataset_type': 'experiment', 'original_files': [], 'status': 'proposed', 'award': '/awards/U54HG004576/', 'assay_term_name': 'RNA-seq', 'schema_version': '6', 'files': [], 'references': [], 'description': 'miRNA-seq  on postnatal 0 day mouse adrenals', '@type': ['experiment', 'dataset', 'item'], 'assay_term_id': 'OBI:0001271', 'possible_controls': [], 'assembly': [], 'revoked_files': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:06:35.262549+00:00', 'biosample_type': 'tissue', 'accession': 'ENCSR949VVK', 'replicates': [], 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'alternate_accessions': []}]}
# row 60 created: ENCSR949VVK
# 34

# %%
updatesdf = pandas.DataFrame(created, columns=['accession','description'])
updatesdf.to_excel('/tmp/experiments.xlsx')

# %% [markdown]
# # create libraries

# %%
book = gcat.get_file(spreadsheet_name, fmt='pandas_excel')
libraries = book.parse('Libraries')
created = encode.post_sheet('/libraries/', libraries, dry_run=False, verbose=True)
len(created)
# Out:
# Reponse {'@type': ['result'], 'status': 'success', '@graph': [{'documents': [], 'nucleic_acid_term_name': 'miRNA', 'aliases': ['richard-myers:SL107900'], 'uuid': '53f6142d-6d4b-414d-a458-02c4e931ab56', '@type': ['library', 'item'], 'strand_specificity': False, '@id': '/libraries/ENCLB724ILT/', 'size_range': '<30', 'award': '/awards/U54HG004576/', 'biosample': '/biosamples/ENCBS745VOM/', 'status': 'in progress', 'depleted_in_term_name': [], 'nucleic_acid_term_id': 'SO:0000276', 'schema_version': '4', 'treatments': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:07:43.774984+00:00', 'depleted_in_term_id': [], 'accession': 'ENCLB724ILT', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'spikeins_used': [], 'alternate_accessions': []}]}
# row 40 created: ENCLB724ILT
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'documents': [], 'nucleic_acid_term_name': 'miRNA', 'alternate_accessions': [], 'uuid': 'b7a13e32-d30d-423a-88ca-b8840add7cda', '@type': ['library', 'item'], 'strand_specificity': False, '@id': '/libraries/ENCLB671UKP/', 'size_range': '<30', 'award': '/awards/U54HG004576/', 'schema_version': '4', 'status': 'in progress', 'depleted_in_term_name': [], 'nucleic_acid_term_id': 'SO:0000276', 'biosample': '/biosamples/ENCBS720JOH/', 'treatments': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:07:44.086064+00:00', 'depleted_in_term_id': [], 'accession': 'ENCLB671UKP', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'spikeins_used': [], 'aliases': ['richard-myers:SL107901']}]}
# row 41 created: ENCLB671UKP
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'documents': [], 'nucleic_acid_term_name': 'miRNA', 'alternate_accessions': [], 'uuid': '8c9116d9-6201-4cbf-989a-b9170ad4b557', '@type': ['library', 'item'], 'strand_specificity': False, '@id': '/libraries/ENCLB969LUH/', 'size_range': '<30', 'award': '/awards/U54HG004576/', 'schema_version': '4', 'status': 'in progress', 'depleted_in_term_name': [], 'nucleic_acid_term_id': 'SO:0000276', 'biosample': '/biosamples/ENCBS228OBS/', 'treatments': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:07:44.419945+00:00', 'depleted_in_term_id': [], 'accession': 'ENCLB969LUH', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'spikeins_used': [], 'aliases': ['richard-myers:SL107902']}]}
# row 42 created: ENCLB969LUH
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'documents': [], 'nucleic_acid_term_name': 'miRNA', 'aliases': ['richard-myers:SL107903'], 'uuid': '60250878-9b90-4eff-b62d-3c149f02873e', '@type': ['library', 'item'], 'strand_specificity': False, '@id': '/libraries/ENCLB190ZRE/', 'size_range': '<30', 'award': '/awards/U54HG004576/', 'biosample': '/biosamples/ENCBS802FTI/', 'status': 'in progress', 'depleted_in_term_name': [], 'nucleic_acid_term_id': 'SO:0000276', 'schema_version': '4', 'treatments': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:07:44.713828+00:00', 'depleted_in_term_id': [], 'accession': 'ENCLB190ZRE', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'spikeins_used': [], 'alternate_accessions': []}]}
# row 43 created: ENCLB190ZRE
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'documents': [], 'nucleic_acid_term_name': 'miRNA', 'alternate_accessions': [], 'uuid': '77f7ae57-6386-4d74-9469-70ff917306d0', '@type': ['library', 'item'], 'strand_specificity': False, '@id': '/libraries/ENCLB239RXJ/', 'size_range': '<30', 'award': '/awards/U54HG004576/', 'schema_version': '4', 'status': 'in progress', 'depleted_in_term_name': [], 'nucleic_acid_term_id': 'SO:0000276', 'biosample': '/biosamples/ENCBS199NDR/', 'treatments': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:07:44.996941+00:00', 'depleted_in_term_id': [], 'accession': 'ENCLB239RXJ', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'spikeins_used': [], 'aliases': ['richard-myers:SL107904']}]}
# row 44 created: ENCLB239RXJ
# Reponse {'@type': ['result'], 'status': 'success', '@graph': [{'documents': [], 'nucleic_acid_term_name': 'miRNA', 'alternate_accessions': [], 'uuid': 'ea6ba237-243c-4ebf-ba87-32e1ad0e527d', 'nucleic_acid_term_id': 'SO:0000276', 'strand_specificity': False, '@id': '/libraries/ENCLB419EKV/', 'size_range': '<30', 'award': '/awards/U54HG004576/', 'biosample': '/biosamples/ENCBS976DPO/', 'status': 'in progress', 'depleted_in_term_name': [], '@type': ['library', 'item'], 'schema_version': '4', 'treatments': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:07:45.271371+00:00', 'depleted_in_term_id': [], 'accession': 'ENCLB419EKV', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'spikeins_used': [], 'aliases': ['richard-myers:SL107905']}]}
# row 45 created: ENCLB419EKV
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'documents': [], 'nucleic_acid_term_name': 'miRNA', 'aliases': ['richard-myers:SL107906'], 'uuid': 'ee6329ce-a767-408c-94de-9a77f49dbea9', '@type': ['library', 'item'], 'strand_specificity': False, '@id': '/libraries/ENCLB002ZQQ/', 'size_range': '<30', 'award': '/awards/U54HG004576/', 'biosample': '/biosamples/ENCBS141GPQ/', 'status': 'in progress', 'depleted_in_term_name': [], 'nucleic_acid_term_id': 'SO:0000276', 'schema_version': '4', 'treatments': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:07:45.559941+00:00', 'depleted_in_term_id': [], 'accession': 'ENCLB002ZQQ', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'spikeins_used': [], 'alternate_accessions': []}]}
# row 46 created: ENCLB002ZQQ
# Reponse {'@type': ['result'], 'status': 'success', '@graph': [{'documents': [], 'nucleic_acid_term_name': 'miRNA', 'alternate_accessions': [], 'uuid': '048552c3-2d97-4c10-92ad-ff87710eb53e', 'nucleic_acid_term_id': 'SO:0000276', 'strand_specificity': False, '@id': '/libraries/ENCLB557VEK/', 'size_range': '<30', 'award': '/awards/U54HG004576/', 'biosample': '/biosamples/ENCBS468NAL/', 'status': 'in progress', 'depleted_in_term_name': [], '@type': ['library', 'item'], 'schema_version': '4', 'treatments': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:07:45.848969+00:00', 'depleted_in_term_id': [], 'accession': 'ENCLB557VEK', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'spikeins_used': [], 'aliases': ['richard-myers:SL107907']}]}
# row 47 created: ENCLB557VEK
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'documents': [], 'nucleic_acid_term_name': 'miRNA', 'aliases': ['richard-myers:SL107908'], 'uuid': 'da08da5f-4071-450d-8e9d-9e70bab4c9a3', 'nucleic_acid_term_id': 'SO:0000276', 'strand_specificity': False, '@id': '/libraries/ENCLB488ELZ/', 'size_range': '<30', 'award': '/awards/U54HG004576/', 'schema_version': '4', 'status': 'in progress', 'depleted_in_term_name': [], '@type': ['library', 'item'], 'biosample': '/biosamples/ENCBS225RIF/', 'treatments': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:07:46.169308+00:00', 'depleted_in_term_id': [], 'accession': 'ENCLB488ELZ', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'spikeins_used': [], 'alternate_accessions': []}]}
# row 48 created: ENCLB488ELZ
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'documents': [], 'nucleic_acid_term_name': 'miRNA', 'alternate_accessions': [], 'uuid': '0e5d6380-7da8-4d0c-9f97-1fe9ac48134e', '@type': ['library', 'item'], 'strand_specificity': False, '@id': '/libraries/ENCLB811YPP/', 'size_range': '<30', 'award': '/awards/U54HG004576/', 'schema_version': '4', 'status': 'in progress', 'depleted_in_term_name': [], 'nucleic_acid_term_id': 'SO:0000276', 'biosample': '/biosamples/ENCBS046IMM/', 'treatments': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:07:46.479952+00:00', 'depleted_in_term_id': [], 'accession': 'ENCLB811YPP', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'spikeins_used': [], 'aliases': ['richard-myers:SL107909']}]}
# row 49 created: ENCLB811YPP
# Reponse {'@type': ['result'], 'status': 'success', '@graph': [{'documents': [], 'nucleic_acid_term_name': 'miRNA', 'alternate_accessions': [], 'uuid': 'af2165ce-2b37-4839-8c4a-6357536591ed', 'nucleic_acid_term_id': 'SO:0000276', 'strand_specificity': False, '@id': '/libraries/ENCLB032OMQ/', 'size_range': '<30', 'award': '/awards/U54HG004576/', 'biosample': '/biosamples/ENCBS746POP/', 'status': 'in progress', 'depleted_in_term_name': [], '@type': ['library', 'item'], 'schema_version': '4', 'treatments': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:07:46.790704+00:00', 'depleted_in_term_id': [], 'accession': 'ENCLB032OMQ', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'spikeins_used': [], 'aliases': ['richard-myers:SL107910']}]}
# row 50 created: ENCLB032OMQ
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'documents': [], 'nucleic_acid_term_name': 'miRNA', 'aliases': ['richard-myers:SL107911'], 'uuid': 'a24b94ac-5dd3-46a2-b1cd-eedf2f5964d8', 'nucleic_acid_term_id': 'SO:0000276', 'strand_specificity': False, '@id': '/libraries/ENCLB438BDQ/', 'size_range': '<30', 'award': '/awards/U54HG004576/', 'schema_version': '4', 'status': 'in progress', 'depleted_in_term_name': [], '@type': ['library', 'item'], 'biosample': '/biosamples/ENCBS522YOW/', 'treatments': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:07:47.049719+00:00', 'depleted_in_term_id': [], 'accession': 'ENCLB438BDQ', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'spikeins_used': [], 'alternate_accessions': []}]}
# row 51 created: ENCLB438BDQ
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'documents': [], 'nucleic_acid_term_name': 'miRNA', 'alternate_accessions': [], 'uuid': '032bb93c-dbb3-4c0e-b697-5526f759c4ec', '@type': ['library', 'item'], 'strand_specificity': False, '@id': '/libraries/ENCLB772UFX/', 'size_range': '<30', 'award': '/awards/U54HG004576/', 'schema_version': '4', 'status': 'in progress', 'depleted_in_term_name': [], 'nucleic_acid_term_id': 'SO:0000276', 'biosample': '/biosamples/ENCBS066IEL/', 'treatments': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:07:47.320276+00:00', 'depleted_in_term_id': [], 'accession': 'ENCLB772UFX', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'spikeins_used': [], 'aliases': ['richard-myers:SL108092']}]}
# row 52 created: ENCLB772UFX
# Reponse {'@type': ['result'], 'status': 'success', '@graph': [{'documents': [], 'nucleic_acid_term_name': 'miRNA', 'alternate_accessions': [], 'uuid': '1e212c72-8b78-42bc-bcfe-b365946054e6', 'nucleic_acid_term_id': 'SO:0000276', 'strand_specificity': False, '@id': '/libraries/ENCLB385XNA/', 'size_range': '<30', 'award': '/awards/U54HG004576/', 'biosample': '/biosamples/ENCBS681XPR/', 'status': 'in progress', 'depleted_in_term_name': [], '@type': ['library', 'item'], 'schema_version': '4', 'treatments': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:07:47.608902+00:00', 'depleted_in_term_id': [], 'accession': 'ENCLB385XNA', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'spikeins_used': [], 'aliases': ['richard-myers:SL108093']}]}
# row 53 created: ENCLB385XNA
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'documents': [], 'nucleic_acid_term_name': 'miRNA', 'aliases': ['richard-myers:SL108094'], 'uuid': '87148728-3472-4332-8fe9-0286e69fa591', 'nucleic_acid_term_id': 'SO:0000276', 'strand_specificity': False, '@id': '/libraries/ENCLB212WQY/', 'size_range': '<30', 'award': '/awards/U54HG004576/', 'schema_version': '4', 'status': 'in progress', 'depleted_in_term_name': [], '@type': ['library', 'item'], 'biosample': '/biosamples/ENCBS402TUS/', 'treatments': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:07:47.929124+00:00', 'depleted_in_term_id': [], 'accession': 'ENCLB212WQY', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'spikeins_used': [], 'alternate_accessions': []}]}
# row 54 created: ENCLB212WQY
# Reponse {'@type': ['result'], 'status': 'success', '@graph': [{'documents': [], 'nucleic_acid_term_name': 'miRNA', 'aliases': ['richard-myers:SL108095'], 'uuid': '5cec7d70-2283-406f-b8b0-900d1144a212', '@type': ['library', 'item'], 'strand_specificity': False, '@id': '/libraries/ENCLB250HWD/', 'size_range': '<30', 'award': '/awards/U54HG004576/', 'biosample': '/biosamples/ENCBS183YVD/', 'status': 'in progress', 'depleted_in_term_name': [], 'nucleic_acid_term_id': 'SO:0000276', 'schema_version': '4', 'treatments': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:07:48.216180+00:00', 'depleted_in_term_id': [], 'accession': 'ENCLB250HWD', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'spikeins_used': [], 'alternate_accessions': []}]}
# row 55 created: ENCLB250HWD
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'documents': [], 'nucleic_acid_term_name': 'miRNA', 'aliases': ['richard-myers:SL108096'], 'uuid': 'b43285d4-a178-4cf7-8741-a52bc7b3d6be', '@type': ['library', 'item'], 'strand_specificity': False, '@id': '/libraries/ENCLB592QZM/', 'size_range': '<30', 'award': '/awards/U54HG004576/', 'biosample': '/biosamples/ENCBS567ABO/', 'status': 'in progress', 'depleted_in_term_name': [], 'nucleic_acid_term_id': 'SO:0000276', 'schema_version': '4', 'treatments': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:07:48.506904+00:00', 'depleted_in_term_id': [], 'accession': 'ENCLB592QZM', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'spikeins_used': [], 'alternate_accessions': []}]}
# row 56 created: ENCLB592QZM
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'documents': [], 'nucleic_acid_term_name': 'miRNA', 'aliases': ['richard-myers:SL108097'], 'uuid': '863a8fa8-b87d-419b-a165-5c93eb20d3c4', 'nucleic_acid_term_id': 'SO:0000276', 'strand_specificity': False, '@id': '/libraries/ENCLB273SQU/', 'size_range': '<30', 'award': '/awards/U54HG004576/', 'schema_version': '4', 'status': 'in progress', 'depleted_in_term_name': [], '@type': ['library', 'item'], 'biosample': '/biosamples/ENCBS295MUN/', 'treatments': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:07:48.830534+00:00', 'depleted_in_term_id': [], 'accession': 'ENCLB273SQU', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'spikeins_used': [], 'alternate_accessions': []}]}
# row 57 created: ENCLB273SQU
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'documents': [], 'nucleic_acid_term_name': 'miRNA', 'alternate_accessions': [], 'uuid': 'd4124a8f-e9a5-4fc6-81ea-8ac035245290', '@type': ['library', 'item'], 'strand_specificity': False, '@id': '/libraries/ENCLB539OCA/', 'size_range': '<30', 'award': '/awards/U54HG004576/', 'schema_version': '4', 'status': 'in progress', 'depleted_in_term_name': [], 'nucleic_acid_term_id': 'SO:0000276', 'biosample': '/biosamples/ENCBS825LGT/', 'treatments': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:07:49.119997+00:00', 'depleted_in_term_id': [], 'accession': 'ENCLB539OCA', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'spikeins_used': [], 'aliases': ['richard-myers:SL108098']}]}
# row 58 created: ENCLB539OCA
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'documents': [], 'nucleic_acid_term_name': 'miRNA', 'alternate_accessions': [], 'uuid': 'cc610a24-b566-4f31-9bec-87027d883b70', '@type': ['library', 'item'], 'strand_specificity': False, '@id': '/libraries/ENCLB286YGC/', 'size_range': '<30', 'award': '/awards/U54HG004576/', 'schema_version': '4', 'status': 'in progress', 'depleted_in_term_name': [], 'nucleic_acid_term_id': 'SO:0000276', 'biosample': '/biosamples/ENCBS849BXE/', 'treatments': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:07:49.415802+00:00', 'depleted_in_term_id': [], 'accession': 'ENCLB286YGC', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'spikeins_used': [], 'aliases': ['richard-myers:SL108099']}]}
# row 59 created: ENCLB286YGC
# Reponse {'@type': ['result'], 'status': 'success', '@graph': [{'documents': [], 'nucleic_acid_term_name': 'miRNA', 'aliases': ['richard-myers:SL108100'], 'uuid': '76c96b72-2aa6-4c29-a8b8-700e71d6bc08', '@type': ['library', 'item'], 'strand_specificity': False, '@id': '/libraries/ENCLB709YRH/', 'size_range': '<30', 'award': '/awards/U54HG004576/', 'biosample': '/biosamples/ENCBS909QXI/', 'status': 'in progress', 'depleted_in_term_name': [], 'nucleic_acid_term_id': 'SO:0000276', 'schema_version': '4', 'treatments': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:07:49.700853+00:00', 'depleted_in_term_id': [], 'accession': 'ENCLB709YRH', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'spikeins_used': [], 'alternate_accessions': []}]}
# row 60 created: ENCLB709YRH
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'documents': [], 'nucleic_acid_term_name': 'miRNA', 'alternate_accessions': [], 'uuid': 'f8ef034b-0a26-478b-b202-1c86265d1db5', '@type': ['library', 'item'], 'strand_specificity': False, '@id': '/libraries/ENCLB606JXQ/', 'size_range': '<30', 'award': '/awards/U54HG004576/', 'schema_version': '4', 'status': 'in progress', 'depleted_in_term_name': [], 'nucleic_acid_term_id': 'SO:0000276', 'biosample': '/biosamples/ENCBS233QWW/', 'treatments': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:07:49.971817+00:00', 'depleted_in_term_id': [], 'accession': 'ENCLB606JXQ', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'spikeins_used': [], 'aliases': ['richard-myers:SL108101']}]}
# row 61 created: ENCLB606JXQ
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'documents': [], 'nucleic_acid_term_name': 'miRNA', 'aliases': ['richard-myers:SL108102'], 'uuid': '12793ef1-dc16-421f-ae74-5f517cb0d27f', 'nucleic_acid_term_id': 'SO:0000276', 'strand_specificity': False, '@id': '/libraries/ENCLB731JUL/', 'size_range': '<30', 'award': '/awards/U54HG004576/', 'schema_version': '4', 'status': 'in progress', 'depleted_in_term_name': [], '@type': ['library', 'item'], 'biosample': '/biosamples/ENCBS776GWF/', 'treatments': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:07:50.249467+00:00', 'depleted_in_term_id': [], 'accession': 'ENCLB731JUL', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'spikeins_used': [], 'alternate_accessions': []}]}
# row 62 created: ENCLB731JUL
# Reponse {'@type': ['result'], 'status': 'success', '@graph': [{'documents': [], 'nucleic_acid_term_name': 'miRNA', 'alternate_accessions': [], 'uuid': 'e5209650-b682-4015-b217-ead0a19981f2', 'nucleic_acid_term_id': 'SO:0000276', 'strand_specificity': False, '@id': '/libraries/ENCLB020YQP/', 'size_range': '<30', 'award': '/awards/U54HG004576/', 'biosample': '/biosamples/ENCBS903HZW/', 'status': 'in progress', 'depleted_in_term_name': [], '@type': ['library', 'item'], 'schema_version': '4', 'treatments': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:07:50.517274+00:00', 'depleted_in_term_id': [], 'accession': 'ENCLB020YQP', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'spikeins_used': [], 'aliases': ['richard-myers:SL108103']}]}
# row 63 created: ENCLB020YQP
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'documents': [], 'nucleic_acid_term_name': 'miRNA', 'alternate_accessions': [], 'uuid': '94ff9374-9eb6-473c-ae44-7965c8e932d3', '@type': ['library', 'item'], 'strand_specificity': False, '@id': '/libraries/ENCLB083OTU/', 'size_range': '<30', 'award': '/awards/U54HG004576/', 'schema_version': '4', 'status': 'in progress', 'depleted_in_term_name': [], 'nucleic_acid_term_id': 'SO:0000276', 'biosample': '/biosamples/ENCBS314UPI/', 'treatments': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:07:50.792254+00:00', 'depleted_in_term_id': [], 'accession': 'ENCLB083OTU', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'spikeins_used': [], 'aliases': ['richard-myers:SL113819']}]}
# row 64 created: ENCLB083OTU
# Reponse {'@type': ['result'], 'status': 'success', '@graph': [{'documents': [], 'nucleic_acid_term_name': 'miRNA', 'alternate_accessions': [], 'uuid': '649385ad-bcc5-4091-997e-637a6efe0652', 'nucleic_acid_term_id': 'SO:0000276', 'strand_specificity': False, '@id': '/libraries/ENCLB236OWO/', 'size_range': '<30', 'award': '/awards/U54HG004576/', 'biosample': '/biosamples/ENCBS237YNZ/', 'status': 'in progress', 'depleted_in_term_name': [], '@type': ['library', 'item'], 'schema_version': '4', 'treatments': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:07:51.067845+00:00', 'depleted_in_term_id': [], 'accession': 'ENCLB236OWO', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'spikeins_used': [], 'aliases': ['richard-myers:SL113820']}]}
# row 65 created: ENCLB236OWO
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'documents': [], 'nucleic_acid_term_name': 'miRNA', 'alternate_accessions': [], 'uuid': 'b6b620df-f3d4-4e40-8ce9-3bd4e8c0ed46', '@type': ['library', 'item'], 'strand_specificity': False, '@id': '/libraries/ENCLB257VDK/', 'size_range': '<30', 'award': '/awards/U54HG004576/', 'schema_version': '4', 'status': 'in progress', 'depleted_in_term_name': [], 'nucleic_acid_term_id': 'SO:0000276', 'biosample': '/biosamples/ENCBS581DHV/', 'treatments': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:07:51.335130+00:00', 'depleted_in_term_id': [], 'accession': 'ENCLB257VDK', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'spikeins_used': [], 'aliases': ['richard-myers:SL113821']}]}
# row 66 created: ENCLB257VDK
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'documents': [], 'nucleic_acid_term_name': 'miRNA', 'aliases': ['richard-myers:SL113822'], 'uuid': 'd19c0d14-e904-4f87-80d3-e526858059dc', 'nucleic_acid_term_id': 'SO:0000276', 'strand_specificity': False, '@id': '/libraries/ENCLB775WAC/', 'size_range': '<30', 'award': '/awards/U54HG004576/', 'schema_version': '4', 'status': 'in progress', 'depleted_in_term_name': [], '@type': ['library', 'item'], 'biosample': '/biosamples/ENCBS133FDE/', 'treatments': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:07:51.623848+00:00', 'depleted_in_term_id': [], 'accession': 'ENCLB775WAC', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'spikeins_used': [], 'alternate_accessions': []}]}
# row 67 created: ENCLB775WAC
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'documents': [], 'nucleic_acid_term_name': 'miRNA', 'alternate_accessions': [], 'uuid': '60611cbf-1c21-4e8f-ad39-00eb201ac732', '@type': ['library', 'item'], 'strand_specificity': False, '@id': '/libraries/ENCLB422KGA/', 'size_range': '<30', 'award': '/awards/U54HG004576/', 'schema_version': '4', 'status': 'in progress', 'depleted_in_term_name': [], 'nucleic_acid_term_id': 'SO:0000276', 'biosample': '/biosamples/ENCBS300NIO/', 'treatments': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:07:51.938292+00:00', 'depleted_in_term_id': [], 'accession': 'ENCLB422KGA', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'spikeins_used': [], 'aliases': ['richard-myers:SL113823']}]}
# row 68 created: ENCLB422KGA
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'documents': [], 'nucleic_acid_term_name': 'miRNA', 'alternate_accessions': [], 'uuid': '96504a8d-7eb3-4047-996f-d12d35c2d580', '@type': ['library', 'item'], 'strand_specificity': False, '@id': '/libraries/ENCLB892OTH/', 'size_range': '<30', 'award': '/awards/U54HG004576/', 'schema_version': '4', 'status': 'in progress', 'depleted_in_term_name': [], 'nucleic_acid_term_id': 'SO:0000276', 'biosample': '/biosamples/ENCBS471PIU/', 'treatments': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:07:52.224011+00:00', 'depleted_in_term_id': [], 'accession': 'ENCLB892OTH', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'spikeins_used': [], 'aliases': ['richard-myers:SL113824']}]}
# row 69 created: ENCLB892OTH
# Reponse {'@type': ['result'], 'status': 'success', '@graph': [{'documents': [], 'nucleic_acid_term_name': 'miRNA', 'alternate_accessions': [], 'uuid': '38dbb688-a2c9-498a-af3e-9d764a49c6de', 'nucleic_acid_term_id': 'SO:0000276', 'strand_specificity': False, '@id': '/libraries/ENCLB363CBV/', 'size_range': '<30', 'award': '/awards/U54HG004576/', 'biosample': '/biosamples/ENCBS824QSS/', 'status': 'in progress', 'depleted_in_term_name': [], '@type': ['library', 'item'], 'schema_version': '4', 'treatments': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:07:52.508685+00:00', 'depleted_in_term_id': [], 'accession': 'ENCLB363CBV', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'spikeins_used': [], 'aliases': ['richard-myers:SL113825']}]}
# row 70 created: ENCLB363CBV
# Reponse {'@type': ['result'], 'status': 'success', '@graph': [{'documents': [], 'nucleic_acid_term_name': 'miRNA', 'aliases': ['richard-myers:SL113826'], 'uuid': '7f84a152-8f3d-44dd-8539-9b2797a8bf39', '@type': ['library', 'item'], 'strand_specificity': False, '@id': '/libraries/ENCLB983TTG/', 'size_range': '<30', 'award': '/awards/U54HG004576/', 'biosample': '/biosamples/ENCBS925AWF/', 'status': 'in progress', 'depleted_in_term_name': [], 'nucleic_acid_term_id': 'SO:0000276', 'schema_version': '4', 'treatments': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:07:52.782893+00:00', 'depleted_in_term_id': [], 'accession': 'ENCLB983TTG', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'spikeins_used': [], 'alternate_accessions': []}]}
# row 71 created: ENCLB983TTG
# Reponse {'@type': ['result'], 'status': 'success', '@graph': [{'documents': [], 'nucleic_acid_term_name': 'miRNA', 'alternate_accessions': [], 'uuid': '98ef3d9a-4dad-4474-81fb-02c4e213a2d2', 'nucleic_acid_term_id': 'SO:0000276', 'strand_specificity': False, '@id': '/libraries/ENCLB057NCW/', 'size_range': '<30', 'award': '/awards/U54HG004576/', 'biosample': '/biosamples/ENCBS715ONU/', 'status': 'in progress', 'depleted_in_term_name': [], '@type': ['library', 'item'], 'schema_version': '4', 'treatments': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:07:53.101314+00:00', 'depleted_in_term_id': [], 'accession': 'ENCLB057NCW', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'spikeins_used': [], 'aliases': ['richard-myers:SL113827']}]}
# row 72 created: ENCLB057NCW
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'documents': [], 'nucleic_acid_term_name': 'miRNA', 'aliases': ['richard-myers:SL113828'], 'uuid': '6b6b90ec-ade3-4bd9-aac8-d2ee9c2da219', 'nucleic_acid_term_id': 'SO:0000276', 'strand_specificity': False, '@id': '/libraries/ENCLB423VHK/', 'size_range': '<30', 'award': '/awards/U54HG004576/', 'schema_version': '4', 'status': 'in progress', 'depleted_in_term_name': [], '@type': ['library', 'item'], 'biosample': '/biosamples/ENCBS987ARB/', 'treatments': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:07:53.382266+00:00', 'depleted_in_term_id': [], 'accession': 'ENCLB423VHK', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'spikeins_used': [], 'alternate_accessions': []}]}
# row 73 created: ENCLB423VHK
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'documents': [], 'nucleic_acid_term_name': 'miRNA', 'aliases': ['richard-myers:SL113829'], 'uuid': '110cef84-149c-4bd7-8ab1-01fc1994020d', '@type': ['library', 'item'], 'strand_specificity': False, '@id': '/libraries/ENCLB529EZC/', 'size_range': '<30', 'award': '/awards/U54HG004576/', 'biosample': '/biosamples/ENCBS110AZU/', 'status': 'in progress', 'depleted_in_term_name': [], 'nucleic_acid_term_id': 'SO:0000276', 'schema_version': '4', 'treatments': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:07:53.668009+00:00', 'depleted_in_term_id': [], 'accession': 'ENCLB529EZC', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'spikeins_used': [], 'alternate_accessions': []}]}
# row 74 created: ENCLB529EZC
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'documents': [], 'nucleic_acid_term_name': 'miRNA', 'alternate_accessions': [], 'uuid': '6cd3b64a-7d65-4107-980b-47b6c5de57b9', '@type': ['library', 'item'], 'strand_specificity': False, '@id': '/libraries/ENCLB176CAC/', 'size_range': '<30', 'award': '/awards/U54HG004576/', 'schema_version': '4', 'status': 'in progress', 'depleted_in_term_name': [], 'nucleic_acid_term_id': 'SO:0000276', 'biosample': '/biosamples/ENCBS475HQA/', 'treatments': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:07:53.922033+00:00', 'depleted_in_term_id': [], 'accession': 'ENCLB176CAC', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'spikeins_used': [], 'aliases': ['richard-myers:SL113830']}]}
# row 75 created: ENCLB176CAC
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'documents': [], 'nucleic_acid_term_name': 'miRNA', 'aliases': ['richard-myers:SL113831'], 'uuid': 'c858b340-1ec7-4e34-8b2f-ad3208ba82d8', 'nucleic_acid_term_id': 'SO:0000276', 'strand_specificity': False, '@id': '/libraries/ENCLB706GWH/', 'size_range': '<30', 'award': '/awards/U54HG004576/', 'schema_version': '4', 'status': 'in progress', 'depleted_in_term_name': [], '@type': ['library', 'item'], 'biosample': '/biosamples/ENCBS431CVS/', 'treatments': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:07:54.231798+00:00', 'depleted_in_term_id': [], 'accession': 'ENCLB706GWH', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'spikeins_used': [], 'alternate_accessions': []}]}
# row 76 created: ENCLB706GWH
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'documents': [], 'nucleic_acid_term_name': 'miRNA', 'aliases': ['richard-myers:SL113832'], 'uuid': 'f2aec9ea-dc3d-4843-afed-b9032999588b', '@type': ['library', 'item'], 'strand_specificity': False, '@id': '/libraries/ENCLB486PZP/', 'size_range': '<30', 'award': '/awards/U54HG004576/', 'biosample': '/biosamples/ENCBS883PNF/', 'status': 'in progress', 'depleted_in_term_name': [], 'nucleic_acid_term_id': 'SO:0000276', 'schema_version': '4', 'treatments': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:07:54.500468+00:00', 'depleted_in_term_id': [], 'accession': 'ENCLB486PZP', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'spikeins_used': [], 'alternate_accessions': []}]}
# row 77 created: ENCLB486PZP
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'documents': [], 'nucleic_acid_term_name': 'miRNA', 'alternate_accessions': [], 'uuid': 'af978cdb-8101-4293-a1d6-785d6b8c4af4', '@type': ['library', 'item'], 'strand_specificity': False, '@id': '/libraries/ENCLB177PNN/', 'size_range': '<30', 'award': '/awards/U54HG004576/', 'schema_version': '4', 'status': 'in progress', 'depleted_in_term_name': [], 'nucleic_acid_term_id': 'SO:0000276', 'biosample': '/biosamples/ENCBS731ALA/', 'treatments': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:07:54.779988+00:00', 'depleted_in_term_id': [], 'accession': 'ENCLB177PNN', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'spikeins_used': [], 'aliases': ['richard-myers:SL113833']}]}
# row 78 created: ENCLB177PNN
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'documents': [], 'nucleic_acid_term_name': 'miRNA', 'aliases': ['richard-myers:SL113834'], 'uuid': 'd0b0a9ce-118f-4abd-aaa1-eca3e3bf8278', 'nucleic_acid_term_id': 'SO:0000276', 'strand_specificity': False, '@id': '/libraries/ENCLB869CAV/', 'size_range': '<30', 'award': '/awards/U54HG004576/', 'schema_version': '4', 'status': 'in progress', 'depleted_in_term_name': [], '@type': ['library', 'item'], 'biosample': '/biosamples/ENCBS454WSU/', 'treatments': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:07:55.069513+00:00', 'depleted_in_term_id': [], 'accession': 'ENCLB869CAV', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'spikeins_used': [], 'alternate_accessions': []}]}
# row 79 created: ENCLB869CAV
# Reponse {'@type': ['result'], 'status': 'success', '@graph': [{'documents': [], 'nucleic_acid_term_name': 'miRNA', 'alternate_accessions': [], 'uuid': 'c4c04f1a-3e92-43d0-9f9b-03cd477cffe7', 'nucleic_acid_term_id': 'SO:0000276', 'strand_specificity': False, '@id': '/libraries/ENCLB508WQD/', 'size_range': '<30', 'award': '/awards/U54HG004576/', 'biosample': '/biosamples/ENCBS033OJJ/', 'status': 'in progress', 'depleted_in_term_name': [], '@type': ['library', 'item'], 'schema_version': '4', 'treatments': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:07:55.350673+00:00', 'depleted_in_term_id': [], 'accession': 'ENCLB508WQD', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'spikeins_used': [], 'aliases': ['richard-myers:SL113837']}]}
# row 80 created: ENCLB508WQD
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'documents': [], 'nucleic_acid_term_name': 'miRNA', 'aliases': ['richard-myers:SL113838'], 'uuid': '9bd568d9-49d0-4bb7-a43f-0777ce3ded19', 'nucleic_acid_term_id': 'SO:0000276', 'strand_specificity': False, '@id': '/libraries/ENCLB083UKV/', 'size_range': '<30', 'award': '/awards/U54HG004576/', 'schema_version': '4', 'status': 'in progress', 'depleted_in_term_name': [], '@type': ['library', 'item'], 'biosample': '/biosamples/ENCBS804WMS/', 'treatments': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:07:55.619303+00:00', 'depleted_in_term_id': [], 'accession': 'ENCLB083UKV', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'spikeins_used': [], 'alternate_accessions': []}]}
# row 81 created: ENCLB083UKV
# Reponse {'@type': ['result'], 'status': 'success', '@graph': [{'documents': [], 'nucleic_acid_term_name': 'miRNA', 'alternate_accessions': [], 'uuid': 'd440143c-fa23-418f-9946-248186fb97ad', 'nucleic_acid_term_id': 'SO:0000276', 'strand_specificity': False, '@id': '/libraries/ENCLB251GCH/', 'size_range': '<30', 'award': '/awards/U54HG004576/', 'biosample': '/biosamples/ENCBS169PZD/', 'status': 'in progress', 'depleted_in_term_name': [], '@type': ['library', 'item'], 'schema_version': '4', 'treatments': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:07:55.882419+00:00', 'depleted_in_term_id': [], 'accession': 'ENCLB251GCH', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'spikeins_used': [], 'aliases': ['richard-myers:SL113839']}]}
# row 82 created: ENCLB251GCH
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'documents': [], 'nucleic_acid_term_name': 'miRNA', 'aliases': ['richard-myers:SL113840'], 'uuid': 'ce48f611-7d59-485b-9138-597cb59455e7', '@type': ['library', 'item'], 'strand_specificity': False, '@id': '/libraries/ENCLB587AAL/', 'size_range': '<30', 'award': '/awards/U54HG004576/', 'biosample': '/biosamples/ENCBS960FNV/', 'status': 'in progress', 'depleted_in_term_name': [], 'nucleic_acid_term_id': 'SO:0000276', 'schema_version': '4', 'treatments': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:07:56.155989+00:00', 'depleted_in_term_id': [], 'accession': 'ENCLB587AAL', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'spikeins_used': [], 'alternate_accessions': []}]}
# row 83 created: ENCLB587AAL
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'documents': [], 'nucleic_acid_term_name': 'miRNA', 'alternate_accessions': [], 'uuid': '5e1a6caf-d021-49c3-ac0d-8cfcdb7ff04f', '@type': ['library', 'item'], 'strand_specificity': False, '@id': '/libraries/ENCLB993LZM/', 'size_range': '<30', 'award': '/awards/U54HG004576/', 'schema_version': '4', 'status': 'in progress', 'depleted_in_term_name': [], 'nucleic_acid_term_id': 'SO:0000276', 'biosample': '/biosamples/ENCBS489BYD/', 'treatments': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:07:56.446100+00:00', 'depleted_in_term_id': [], 'accession': 'ENCLB993LZM', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'spikeins_used': [], 'aliases': ['richard-myers:SL113841']}]}
# row 84 created: ENCLB993LZM
# Reponse {'@type': ['result'], 'status': 'success', '@graph': [{'documents': [], 'nucleic_acid_term_name': 'miRNA', 'aliases': ['richard-myers:SL113842'], 'uuid': '78bac27b-ef6f-47fd-a2e6-2a01f7bd5971', '@type': ['library', 'item'], 'strand_specificity': False, '@id': '/libraries/ENCLB250OKP/', 'size_range': '<30', 'award': '/awards/U54HG004576/', 'biosample': '/biosamples/ENCBS901BYV/', 'status': 'in progress', 'depleted_in_term_name': [], 'nucleic_acid_term_id': 'SO:0000276', 'schema_version': '4', 'treatments': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:07:56.734135+00:00', 'depleted_in_term_id': [], 'accession': 'ENCLB250OKP', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'spikeins_used': [], 'alternate_accessions': []}]}
# row 85 created: ENCLB250OKP
# Reponse {'@type': ['result'], 'status': 'success', '@graph': [{'documents': [], 'nucleic_acid_term_name': 'miRNA', 'alternate_accessions': [], 'uuid': 'bdfe63dc-fbdf-4c5a-88dd-62a29516ea1d', 'nucleic_acid_term_id': 'SO:0000276', 'strand_specificity': False, '@id': '/libraries/ENCLB263QTM/', 'size_range': '<30', 'award': '/awards/U54HG004576/', 'biosample': '/biosamples/ENCBS310ESD/', 'status': 'in progress', 'depleted_in_term_name': [], '@type': ['library', 'item'], 'schema_version': '4', 'treatments': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:07:57.025370+00:00', 'depleted_in_term_id': [], 'accession': 'ENCLB263QTM', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'spikeins_used': [], 'aliases': ['richard-myers:SL113843']}]}
# row 86 created: ENCLB263QTM
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'documents': [], 'nucleic_acid_term_name': 'miRNA', 'aliases': ['richard-myers:SL113844'], 'uuid': 'c02064e3-80c5-4460-8393-aef7bc2e3f81', '@type': ['library', 'item'], 'strand_specificity': False, '@id': '/libraries/ENCLB332DBP/', 'size_range': '<30', 'award': '/awards/U54HG004576/', 'biosample': '/biosamples/ENCBS897LGY/', 'status': 'in progress', 'depleted_in_term_name': [], 'nucleic_acid_term_id': 'SO:0000276', 'schema_version': '4', 'treatments': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:07:57.327607+00:00', 'depleted_in_term_id': [], 'accession': 'ENCLB332DBP', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'spikeins_used': [], 'alternate_accessions': []}]}
# row 87 created: ENCLB332DBP
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'documents': [], 'nucleic_acid_term_name': 'miRNA', 'aliases': ['richard-myers:SL113845'], 'uuid': '66cd162d-13d2-4fed-8363-326e8b690c00', 'nucleic_acid_term_id': 'SO:0000276', 'strand_specificity': False, '@id': '/libraries/ENCLB724KXY/', 'size_range': '<30', 'award': '/awards/U54HG004576/', 'schema_version': '4', 'status': 'in progress', 'depleted_in_term_name': [], '@type': ['library', 'item'], 'biosample': '/biosamples/ENCBS079WTJ/', 'treatments': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:07:57.586001+00:00', 'depleted_in_term_id': [], 'accession': 'ENCLB724KXY', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'spikeins_used': [], 'alternate_accessions': []}]}
# row 88 created: ENCLB724KXY
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'documents': [], 'nucleic_acid_term_name': 'miRNA', 'alternate_accessions': [], 'uuid': '336d97d5-4a8b-463d-bc4e-70097010672a', '@type': ['library', 'item'], 'strand_specificity': False, '@id': '/libraries/ENCLB507ENX/', 'size_range': '<30', 'award': '/awards/U54HG004576/', 'schema_version': '4', 'status': 'in progress', 'depleted_in_term_name': [], 'nucleic_acid_term_id': 'SO:0000276', 'biosample': '/biosamples/ENCBS898VIJ/', 'treatments': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:07:57.901294+00:00', 'depleted_in_term_id': [], 'accession': 'ENCLB507ENX', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'spikeins_used': [], 'aliases': ['richard-myers:SL113846']}]}
# row 89 created: ENCLB507ENX
# Reponse {'@type': ['result'], 'status': 'success', '@graph': [{'documents': [], 'nucleic_acid_term_name': 'miRNA', 'aliases': ['richard-myers:SL113847'], 'uuid': '782dcd61-ff20-4e5e-89c9-770ec97f0f31', '@type': ['library', 'item'], 'strand_specificity': False, '@id': '/libraries/ENCLB884TJV/', 'size_range': '<30', 'award': '/awards/U54HG004576/', 'biosample': '/biosamples/ENCBS337KCK/', 'status': 'in progress', 'depleted_in_term_name': [], 'nucleic_acid_term_id': 'SO:0000276', 'schema_version': '4', 'treatments': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:07:58.175165+00:00', 'depleted_in_term_id': [], 'accession': 'ENCLB884TJV', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'spikeins_used': [], 'alternate_accessions': []}]}
# row 90 created: ENCLB884TJV
# Reponse {'@type': ['result'], 'status': 'success', '@graph': [{'documents': [], 'nucleic_acid_term_name': 'miRNA', 'alternate_accessions': [], 'uuid': '4d34f7bb-b5f0-4ea0-a4a4-cec0c50c4410', 'nucleic_acid_term_id': 'SO:0000276', 'strand_specificity': False, '@id': '/libraries/ENCLB766DJC/', 'size_range': '<30', 'award': '/awards/U54HG004576/', 'biosample': '/biosamples/ENCBS694SYF/', 'status': 'in progress', 'depleted_in_term_name': [], '@type': ['library', 'item'], 'schema_version': '4', 'treatments': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:07:58.470274+00:00', 'depleted_in_term_id': [], 'accession': 'ENCLB766DJC', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'spikeins_used': [], 'aliases': ['richard-myers:SL113848']}]}
# row 91 created: ENCLB766DJC
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'documents': [], 'nucleic_acid_term_name': 'miRNA', 'alternate_accessions': [], 'uuid': '9a63fb2e-0282-41ba-9ba4-7c5659809459', '@type': ['library', 'item'], 'strand_specificity': False, '@id': '/libraries/ENCLB787ROC/', 'size_range': '<30', 'award': '/awards/U54HG004576/', 'schema_version': '4', 'status': 'in progress', 'depleted_in_term_name': [], 'nucleic_acid_term_id': 'SO:0000276', 'biosample': '/biosamples/ENCBS747AFS/', 'treatments': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:07:58.760635+00:00', 'depleted_in_term_id': [], 'accession': 'ENCLB787ROC', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'spikeins_used': [], 'aliases': ['richard-myers:SL113849']}]}
# row 92 created: ENCLB787ROC
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'documents': [], 'nucleic_acid_term_name': 'miRNA', 'aliases': ['richard-myers:SL113850'], 'uuid': 'd18193ac-615b-419d-9d27-7af26864b2cc', 'nucleic_acid_term_id': 'SO:0000276', 'strand_specificity': False, '@id': '/libraries/ENCLB029DSE/', 'size_range': '<30', 'award': '/awards/U54HG004576/', 'schema_version': '4', 'status': 'in progress', 'depleted_in_term_name': [], '@type': ['library', 'item'], 'biosample': '/biosamples/ENCBS438DQO/', 'treatments': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:07:59.037583+00:00', 'depleted_in_term_id': [], 'accession': 'ENCLB029DSE', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'spikeins_used': [], 'alternate_accessions': []}]}
# row 93 created: ENCLB029DSE
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'documents': [], 'nucleic_acid_term_name': 'miRNA', 'alternate_accessions': [], 'uuid': '779ac712-25b2-4401-b483-0c450e0ebd8d', '@type': ['library', 'item'], 'strand_specificity': False, '@id': '/libraries/ENCLB718QBT/', 'size_range': '<30', 'award': '/awards/U54HG004576/', 'schema_version': '4', 'status': 'in progress', 'depleted_in_term_name': [], 'nucleic_acid_term_id': 'SO:0000276', 'biosample': '/biosamples/ENCBS196YDO/', 'treatments': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:07:59.308980+00:00', 'depleted_in_term_id': [], 'accession': 'ENCLB718QBT', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'spikeins_used': [], 'aliases': ['richard-myers:SL113851']}]}
# row 94 created: ENCLB718QBT
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'documents': [], 'nucleic_acid_term_name': 'miRNA', 'aliases': ['richard-myers:SL113852'], 'uuid': 'f670ce6d-bbe8-4652-97a2-113151302ba1', '@type': ['library', 'item'], 'strand_specificity': False, '@id': '/libraries/ENCLB749OCP/', 'size_range': '<30', 'award': '/awards/U54HG004576/', 'biosample': '/biosamples/ENCBS270QZU/', 'status': 'in progress', 'depleted_in_term_name': [], 'nucleic_acid_term_id': 'SO:0000276', 'schema_version': '4', 'treatments': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:07:59.576844+00:00', 'depleted_in_term_id': [], 'accession': 'ENCLB749OCP', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'spikeins_used': [], 'alternate_accessions': []}]}
# row 95 created: ENCLB749OCP
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'documents': [], 'nucleic_acid_term_name': 'miRNA', 'alternate_accessions': [], 'uuid': '9e26bd56-1566-4f04-97e6-fe1e5e80181d', '@type': ['library', 'item'], 'strand_specificity': False, '@id': '/libraries/ENCLB265MYO/', 'size_range': '<30', 'award': '/awards/U54HG004576/', 'schema_version': '4', 'status': 'in progress', 'depleted_in_term_name': [], 'nucleic_acid_term_id': 'SO:0000276', 'biosample': '/biosamples/ENCBS186LJI/', 'treatments': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:07:59.861166+00:00', 'depleted_in_term_id': [], 'accession': 'ENCLB265MYO', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'spikeins_used': [], 'aliases': ['richard-myers:SL113853']}]}
# row 96 created: ENCLB265MYO
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'documents': [], 'nucleic_acid_term_name': 'miRNA', 'aliases': ['richard-myers:SL113854'], 'uuid': '650c9c9e-bb32-40ff-a6c5-8d9d9bfc974a', 'nucleic_acid_term_id': 'SO:0000276', 'strand_specificity': False, '@id': '/libraries/ENCLB759EFM/', 'size_range': '<30', 'award': '/awards/U54HG004576/', 'schema_version': '4', 'status': 'in progress', 'depleted_in_term_name': [], '@type': ['library', 'item'], 'biosample': '/biosamples/ENCBS098FMC/', 'treatments': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:08:00.138686+00:00', 'depleted_in_term_id': [], 'accession': 'ENCLB759EFM', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'spikeins_used': [], 'alternate_accessions': []}]}
# row 97 created: ENCLB759EFM
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'documents': [], 'nucleic_acid_term_name': 'miRNA', 'aliases': ['richard-myers:SL113856'], 'uuid': '0be6c636-f159-4de0-86ae-099925d8b9a9', '@type': ['library', 'item'], 'strand_specificity': False, '@id': '/libraries/ENCLB085YUC/', 'size_range': '<30', 'award': '/awards/U54HG004576/', 'biosample': '/biosamples/ENCBS809DPZ/', 'status': 'in progress', 'depleted_in_term_name': [], 'nucleic_acid_term_id': 'SO:0000276', 'schema_version': '4', 'treatments': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:08:00.420180+00:00', 'depleted_in_term_id': [], 'accession': 'ENCLB085YUC', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'spikeins_used': [], 'alternate_accessions': []}]}
# row 98 created: ENCLB085YUC
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'documents': [], 'nucleic_acid_term_name': 'miRNA', 'alternate_accessions': [], 'uuid': '39605e90-38a5-4a1d-b3b1-143f46d1d966', '@type': ['library', 'item'], 'strand_specificity': False, '@id': '/libraries/ENCLB740SKA/', 'size_range': '<30', 'award': '/awards/U54HG004576/', 'schema_version': '4', 'status': 'in progress', 'depleted_in_term_name': [], 'nucleic_acid_term_id': 'SO:0000276', 'biosample': '/biosamples/ENCBS437LDX/', 'treatments': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:08:00.690364+00:00', 'depleted_in_term_id': [], 'accession': 'ENCLB740SKA', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'spikeins_used': [], 'aliases': ['richard-myers:SL113857']}]}
# row 99 created: ENCLB740SKA
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'documents': [], 'nucleic_acid_term_name': 'miRNA', 'aliases': ['richard-myers:SL113858'], 'uuid': '29d5bcaf-e52f-4547-a49f-a4cb2959763f', '@type': ['library', 'item'], 'strand_specificity': False, '@id': '/libraries/ENCLB620MTH/', 'size_range': '<30', 'award': '/awards/U54HG004576/', 'biosample': '/biosamples/ENCBS762UVC/', 'status': 'in progress', 'depleted_in_term_name': [], 'nucleic_acid_term_id': 'SO:0000276', 'schema_version': '4', 'treatments': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:08:00.958226+00:00', 'depleted_in_term_id': [], 'accession': 'ENCLB620MTH', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'spikeins_used': [], 'alternate_accessions': []}]}
# row 100 created: ENCLB620MTH
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'documents': [], 'nucleic_acid_term_name': 'miRNA', 'alternate_accessions': [], 'uuid': '0d859ff1-eb91-4e5c-acaa-83d025e02755', '@type': ['library', 'item'], 'strand_specificity': False, '@id': '/libraries/ENCLB855QOK/', 'size_range': '<30', 'award': '/awards/U54HG004576/', 'schema_version': '4', 'status': 'in progress', 'depleted_in_term_name': [], 'nucleic_acid_term_id': 'SO:0000276', 'biosample': '/biosamples/ENCBS796AGC/', 'treatments': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:08:01.229611+00:00', 'depleted_in_term_id': [], 'accession': 'ENCLB855QOK', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'spikeins_used': [], 'aliases': ['richard-myers:SL113859']}]}
# row 101 created: ENCLB855QOK
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'documents': [], 'nucleic_acid_term_name': 'miRNA', 'aliases': ['richard-myers:SL113860'], 'uuid': '9bcd8ad6-470b-40b2-b156-78d313ac1dc5', 'nucleic_acid_term_id': 'SO:0000276', 'strand_specificity': False, '@id': '/libraries/ENCLB890EYS/', 'size_range': '<30', 'award': '/awards/U54HG004576/', 'schema_version': '4', 'status': 'in progress', 'depleted_in_term_name': [], '@type': ['library', 'item'], 'biosample': '/biosamples/ENCBS182YRY/', 'treatments': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:08:01.496188+00:00', 'depleted_in_term_id': [], 'accession': 'ENCLB890EYS', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'spikeins_used': [], 'alternate_accessions': []}]}
# row 102 created: ENCLB890EYS
# Reponse {'@type': ['result'], 'status': 'success', '@graph': [{'documents': [], 'nucleic_acid_term_name': 'miRNA', 'aliases': ['richard-myers:SL113861'], 'uuid': 'a4c186b3-d00d-4836-a1ba-532d6641c385', '@type': ['library', 'item'], 'strand_specificity': False, '@id': '/libraries/ENCLB402ZDO/', 'size_range': '<30', 'award': '/awards/U54HG004576/', 'biosample': '/biosamples/ENCBS623WQD/', 'status': 'in progress', 'depleted_in_term_name': [], 'nucleic_acid_term_id': 'SO:0000276', 'schema_version': '4', 'treatments': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:08:01.777409+00:00', 'depleted_in_term_id': [], 'accession': 'ENCLB402ZDO', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'spikeins_used': [], 'alternate_accessions': []}]}
# row 103 created: ENCLB402ZDO
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'documents': [], 'nucleic_acid_term_name': 'miRNA', 'aliases': ['richard-myers:SL113862'], 'uuid': 'a7ae45fe-c3e8-487f-8f72-ef71cd5a3f75', '@type': ['library', 'item'], 'strand_specificity': False, '@id': '/libraries/ENCLB235HXH/', 'size_range': '<30', 'award': '/awards/U54HG004576/', 'biosample': '/biosamples/ENCBS103FKB/', 'status': 'in progress', 'depleted_in_term_name': [], 'nucleic_acid_term_id': 'SO:0000276', 'schema_version': '4', 'treatments': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:08:02.044481+00:00', 'depleted_in_term_id': [], 'accession': 'ENCLB235HXH', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'spikeins_used': [], 'alternate_accessions': []}]}
# row 104 created: ENCLB235HXH
# Reponse {'@type': ['result'], 'status': 'success', '@graph': [{'documents': [], 'nucleic_acid_term_name': 'miRNA', 'aliases': ['richard-myers:SL113863'], 'uuid': 'fb118afb-ef06-4ba9-8fce-aeccd771292a', '@type': ['library', 'item'], 'strand_specificity': False, '@id': '/libraries/ENCLB067PRU/', 'size_range': '<30', 'award': '/awards/U54HG004576/', 'biosample': '/biosamples/ENCBS540QNA/', 'status': 'in progress', 'depleted_in_term_name': [], 'nucleic_acid_term_id': 'SO:0000276', 'schema_version': '4', 'treatments': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:08:02.309420+00:00', 'depleted_in_term_id': [], 'accession': 'ENCLB067PRU', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'spikeins_used': [], 'alternate_accessions': []}]}
# row 105 created: ENCLB067PRU
# Reponse {'@type': ['result'], 'status': 'success', '@graph': [{'documents': [], 'nucleic_acid_term_name': 'miRNA', 'alternate_accessions': [], 'uuid': '4cc2f180-a6a6-4cfa-9641-bfd0e626ff8d', 'nucleic_acid_term_id': 'SO:0000276', 'strand_specificity': False, '@id': '/libraries/ENCLB513CUQ/', 'size_range': '<30', 'award': '/awards/U54HG004576/', 'biosample': '/biosamples/ENCBS547NQN/', 'status': 'in progress', 'depleted_in_term_name': [], '@type': ['library', 'item'], 'schema_version': '4', 'treatments': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:08:02.562552+00:00', 'depleted_in_term_id': [], 'accession': 'ENCLB513CUQ', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'spikeins_used': [], 'aliases': ['richard-myers:SL113864']}]}
# row 106 created: ENCLB513CUQ
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'documents': [], 'nucleic_acid_term_name': 'miRNA', 'aliases': ['richard-myers:SL113865'], 'uuid': '6c856f5e-9eb0-4d09-b755-eda8ec4473cb', '@type': ['library', 'item'], 'strand_specificity': False, '@id': '/libraries/ENCLB881GRC/', 'size_range': '<30', 'award': '/awards/U54HG004576/', 'biosample': '/biosamples/ENCBS386FVC/', 'status': 'in progress', 'depleted_in_term_name': [], 'nucleic_acid_term_id': 'SO:0000276', 'schema_version': '4', 'treatments': [], 'lab': '/labs/ali-mortazavi/', 'date_created': '2015-09-17T21:08:02.848446+00:00', 'depleted_in_term_id': [], 'accession': 'ENCLB881GRC', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'spikeins_used': [], 'alternate_accessions': []}]}
# row 107 created: ENCLB881GRC
# 68

# %%
if created:
    updates = []
    for row in created:
        updates.append({'uuid': row['uuid'], 'library_accession': row['accession'], 'aliases': row['aliases'][0]})
    updatesdf = pandas.DataFrame(updates, columns=['uuid', 'library_accession', 'aliases'])
    updatesdf.to_excel('/tmp/libraries.xlsx')

# %% [markdown]
# # create replicates

# %%
book = gcat.get_file(spreadsheet_name, fmt='pandas_excel')
replicates = book.parse('Replicates')
created = encode.post_sheet('/replicates/', replicates, dry_run=False, verbose=True)
len(created)
# Out:
# Reponse {'@type': ['result'], 'status': 'success', '@graph': [{'@type': ['replicate', 'item'], 'schema_version': '5', 'biological_replicate_number': 1, 'technical_replicate_number': 1, 'aliases': ['richard-myers:SL107900-rep'], 'uuid': 'e8f60305-ffff-4d07-a5b5-14a7ec722bcd', 'date_created': '2015-09-17T21:11:10.000471+00:00', '@id': '/replicates/e8f60305-ffff-4d07-a5b5-14a7ec722bcd/', 'experiment': '/experiments/ENCSR240IDR/', 'library': '/libraries/ENCLB724ILT/', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'status': 'in progress'}]}
# row 40 created: e8f60305-ffff-4d07-a5b5-14a7ec722bcd
# Reponse {'@type': ['result'], 'status': 'success', '@graph': [{'@type': ['replicate', 'item'], 'schema_version': '5', 'biological_replicate_number': 2, 'technical_replicate_number': 1, 'aliases': ['richard-myers:SL107901-rep'], 'uuid': '3d5ec5c3-9ecc-4efe-b4d1-5ece31236892', 'date_created': '2015-09-17T21:11:10.322438+00:00', '@id': '/replicates/3d5ec5c3-9ecc-4efe-b4d1-5ece31236892/', 'experiment': '/experiments/ENCSR240IDR/', 'status': 'in progress', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'library': '/libraries/ENCLB671UKP/'}]}
# row 41 created: 3d5ec5c3-9ecc-4efe-b4d1-5ece31236892
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'@type': ['replicate', 'item'], 'schema_version': '5', 'biological_replicate_number': 1, 'technical_replicate_number': 1, 'aliases': ['richard-myers:SL107902-rep'], 'uuid': '3c0a72e5-6cae-4448-ad3f-946ae656b678', 'date_created': '2015-09-17T21:11:10.620166+00:00', '@id': '/replicates/3c0a72e5-6cae-4448-ad3f-946ae656b678/', 'experiment': '/experiments/ENCSR152ETW/', 'library': '/libraries/ENCLB969LUH/', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'status': 'in progress'}]}
# row 42 created: 3c0a72e5-6cae-4448-ad3f-946ae656b678
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'@type': ['replicate', 'item'], 'schema_version': '5', 'biological_replicate_number': 2, 'technical_replicate_number': 1, 'aliases': ['richard-myers:SL107903-rep'], 'uuid': '3d467cd3-0824-43a1-8121-711424f32b86', 'date_created': '2015-09-17T21:11:10.898586+00:00', '@id': '/replicates/3d467cd3-0824-43a1-8121-711424f32b86/', 'experiment': '/experiments/ENCSR152ETW/', 'status': 'in progress', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'library': '/libraries/ENCLB190ZRE/'}]}
# row 43 created: 3d467cd3-0824-43a1-8121-711424f32b86
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'@type': ['replicate', 'item'], 'schema_version': '5', 'biological_replicate_number': 1, 'technical_replicate_number': 1, 'aliases': ['richard-myers:SL107904-rep'], 'uuid': '66a3bf3e-4464-4c45-8c2b-76567612b28e', 'date_created': '2015-09-17T21:11:11.187781+00:00', '@id': '/replicates/66a3bf3e-4464-4c45-8c2b-76567612b28e/', 'experiment': '/experiments/ENCSR234WHI/', 'library': '/libraries/ENCLB239RXJ/', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'status': 'in progress'}]}
# row 44 created: 66a3bf3e-4464-4c45-8c2b-76567612b28e
# Reponse {'@type': ['result'], 'status': 'success', '@graph': [{'@type': ['replicate', 'item'], 'schema_version': '5', 'biological_replicate_number': 2, 'technical_replicate_number': 1, 'aliases': ['richard-myers:SL107905-rep'], 'uuid': '246077ef-d41b-4354-8c4a-de8f7f3ad285', 'date_created': '2015-09-17T21:11:11.484910+00:00', '@id': '/replicates/246077ef-d41b-4354-8c4a-de8f7f3ad285/', 'experiment': '/experiments/ENCSR234WHI/', 'library': '/libraries/ENCLB419EKV/', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'status': 'in progress'}]}
# row 45 created: 246077ef-d41b-4354-8c4a-de8f7f3ad285
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'@type': ['replicate', 'item'], 'schema_version': '5', 'biological_replicate_number': 1, 'technical_replicate_number': 1, 'aliases': ['richard-myers:SL107906-rep'], 'uuid': '6c49230d-b876-48d9-9c91-4d63ec5e5499', 'date_created': '2015-09-17T21:11:11.797817+00:00', '@id': '/replicates/6c49230d-b876-48d9-9c91-4d63ec5e5499/', 'experiment': '/experiments/ENCSR091ZTZ/', 'library': '/libraries/ENCLB002ZQQ/', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'status': 'in progress'}]}
# row 46 created: 6c49230d-b876-48d9-9c91-4d63ec5e5499
# Reponse {'@type': ['result'], 'status': 'success', '@graph': [{'@type': ['replicate', 'item'], 'schema_version': '5', 'biological_replicate_number': 2, 'technical_replicate_number': 1, 'aliases': ['richard-myers:SL107907-rep'], 'uuid': 'eab09f6a-0adc-48e6-9fb9-90e98dbaa054', 'date_created': '2015-09-17T21:11:12.107333+00:00', '@id': '/replicates/eab09f6a-0adc-48e6-9fb9-90e98dbaa054/', 'experiment': '/experiments/ENCSR091ZTZ/', 'library': '/libraries/ENCLB557VEK/', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'status': 'in progress'}]}
# row 47 created: eab09f6a-0adc-48e6-9fb9-90e98dbaa054
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'@type': ['replicate', 'item'], 'schema_version': '5', 'biological_replicate_number': 1, 'technical_replicate_number': 1, 'aliases': ['richard-myers:SL107908-rep'], 'uuid': '5b816d4d-1f8b-44f1-9ffe-27268054f435', 'date_created': '2015-09-17T21:11:12.406765+00:00', '@id': '/replicates/5b816d4d-1f8b-44f1-9ffe-27268054f435/', 'experiment': '/experiments/ENCSR829OXY/', 'library': '/libraries/ENCLB488ELZ/', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'status': 'in progress'}]}
# row 48 created: 5b816d4d-1f8b-44f1-9ffe-27268054f435
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'@type': ['replicate', 'item'], 'schema_version': '5', 'biological_replicate_number': 2, 'technical_replicate_number': 1, 'aliases': ['richard-myers:SL107909-rep'], 'uuid': '21b6e6e5-63de-4cfb-8206-e0ca6442655b', 'date_created': '2015-09-17T21:11:12.684230+00:00', '@id': '/replicates/21b6e6e5-63de-4cfb-8206-e0ca6442655b/', 'experiment': '/experiments/ENCSR829OXY/', 'status': 'in progress', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'library': '/libraries/ENCLB811YPP/'}]}
# row 49 created: 21b6e6e5-63de-4cfb-8206-e0ca6442655b
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'@type': ['replicate', 'item'], 'schema_version': '5', 'biological_replicate_number': 1, 'technical_replicate_number': 1, 'aliases': ['richard-myers:SL107910-rep'], 'uuid': 'f220c799-ae10-46e7-b4d7-f3fbb91eee2b', 'date_created': '2015-09-17T21:11:13.043293+00:00', '@id': '/replicates/f220c799-ae10-46e7-b4d7-f3fbb91eee2b/', 'experiment': '/experiments/ENCSR489FQD/', 'status': 'in progress', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'library': '/libraries/ENCLB032OMQ/'}]}
# row 50 created: f220c799-ae10-46e7-b4d7-f3fbb91eee2b
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'@type': ['replicate', 'item'], 'schema_version': '5', 'biological_replicate_number': 2, 'technical_replicate_number': 1, 'aliases': ['richard-myers:SL107911-rep'], 'uuid': '2d316e18-c39a-438d-b884-c03cf771fcbc', 'date_created': '2015-09-17T21:11:13.349575+00:00', '@id': '/replicates/2d316e18-c39a-438d-b884-c03cf771fcbc/', 'experiment': '/experiments/ENCSR489FQD/', 'status': 'in progress', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'library': '/libraries/ENCLB438BDQ/'}]}
# row 51 created: 2d316e18-c39a-438d-b884-c03cf771fcbc
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'@type': ['replicate', 'item'], 'schema_version': '5', 'biological_replicate_number': 1, 'technical_replicate_number': 1, 'aliases': ['richard-myers:SL108092-rep'], 'uuid': 'e544b3a2-e1c2-4203-bc88-179574603275', 'date_created': '2015-09-17T21:11:13.642954+00:00', '@id': '/replicates/e544b3a2-e1c2-4203-bc88-179574603275/', 'experiment': '/experiments/ENCSR900DXS/', 'library': '/libraries/ENCLB772UFX/', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'status': 'in progress'}]}
# row 52 created: e544b3a2-e1c2-4203-bc88-179574603275
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'@type': ['replicate', 'item'], 'schema_version': '5', 'biological_replicate_number': 2, 'technical_replicate_number': 1, 'aliases': ['richard-myers:SL108093-rep'], 'uuid': 'cfe3573f-d1bf-4add-90d6-d8a03c65bd55', 'date_created': '2015-09-17T21:11:13.950972+00:00', '@id': '/replicates/cfe3573f-d1bf-4add-90d6-d8a03c65bd55/', 'experiment': '/experiments/ENCSR900DXS/', 'status': 'in progress', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'library': '/libraries/ENCLB385XNA/'}]}
# row 53 created: cfe3573f-d1bf-4add-90d6-d8a03c65bd55
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'@type': ['replicate', 'item'], 'schema_version': '5', 'biological_replicate_number': 1, 'technical_replicate_number': 1, 'aliases': ['richard-myers:S
', 'status': 'in progress', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'library': '/libraries/ENCLB983TTG/'}]}
# row 71 created: 6dac2fdd-3ad5-4490-aa54-712ac2786136
# Reponse {'@type': ['result'], 'status': 'success', '@graph': [{'@type': ['replicate', 'item'], 'schema_version': '5', 'biological_replicate_number': 1, 'technical_replicate_number': 1, 'aliases': ['richard-myers:SL113827-rep'], 'uuid': 'bdc8d1a3-096b-4123-9bee-940f29ff7999', 'date_created': '2015-09-17T21:11:19.804000+00:00', '@id': '/replicates/bdc8d1a3-096b-4123-9bee-940f29ff7999/', 'experiment': '/experiments/ENCSR974QTI/', 'library': '/libraries/ENCLB057NCW/', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'status': 'in progress'}]}
# row 72 created: bdc8d1a3-096b-4123-9bee-940f29ff7999
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'@type': ['replicate', 'item'], 'schema_version': '5', 'biological_replicate_number': 2, 'technical_replicate_number': 1, 'aliases': ['richard-myers:SL113828-rep'], 'uuid': 'f4e2ae6b-f4e5-4d91-b26e-cc8035a03621', 'date_created': '2015-09-17T21:11:20.096056+00:00', '@id': '/replicates/f4e2ae6b-f4e5-4d91-b26e-cc8035a03621/', 'experiment': '/experiments/ENCSR974QTI/', 'status': 'in progress', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'library': '/libraries/ENCLB423VHK/'}]}
# row 73 created: f4e2ae6b-f4e5-4d91-b26e-cc8035a03621
# Reponse {'@type': ['result'], 'status': 'success', '@graph': [{'@type': ['replicate', 'item'], 'schema_version': '5', 'biological_replicate_number': 1, 'technical_replicate_number': 1, 'aliases': ['richard-myers:SL113829-rep'], 'uuid': 'f2d04966-dc25-4a9c-a00d-6df5e555ab31', 'date_created': '2015-09-17T21:11:20.359942+00:00', '@id': '/replicates/f2d04966-dc25-4a9c-a00d-6df5e555ab31/', 'experiment': '/experiments/ENCSR580VUW/', 'status': 'in progress', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'library': '/libraries/ENCLB529EZC/'}]}
# row 74 created: f2d04966-dc25-4a9c-a00d-6df5e555ab31
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'@type': ['replicate', 'item'], 'schema_version': '5', 'biological_replicate_number': 2, 'technical_replicate_number': 1, 'aliases': ['richard-myers:SL113830-rep'], 'uuid': '96c5183e-1db0-4593-8037-5416bea589df', 'date_created': '2015-09-17T21:11:20.626875+00:00', '@id': '/replicates/96c5183e-1db0-4593-8037-5416bea589df/', 'experiment': '/experiments/ENCSR580VUW/', 'library': '/libraries/ENCLB176CAC/', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'status': 'in progress'}]}
# row 75 created: 96c5183e-1db0-4593-8037-5416bea589df
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'@type': ['replicate', 'item'], 'schema_version': '5', 'biological_replicate_number': 1, 'technical_replicate_number': 1, 'aliases': ['richard-myers:SL113831-rep'], 'uuid': '594bfdcb-e40d-4525-ac17-4a4cad951442', 'date_created': '2015-09-17T21:11:20.880009+00:00', '@id': '/replicates/594bfdcb-e40d-4525-ac17-4a4cad951442/', 'experiment': '/experiments/ENCSR498DIP/', 'status': 'in progress', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'library': '/libraries/ENCLB706GWH/'}]}
# row 76 created: 594bfdcb-e40d-4525-ac17-4a4cad951442
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'@type': ['replicate', 'item'], 'schema_version': '5', 'biological_replicate_number': 2, 'technical_replicate_number': 1, 'aliases': ['richard-myers:SL113832-rep'], 'uuid': '3be43872-b148-4c09-9dfd-ae21e5a3528c', 'date_created': '2015-09-17T21:11:21.115707+00:00', '@id': '/replicates/3be43872-b148-4c09-9dfd-ae21e5a3528c/', 'experiment': '/experiments/ENCSR498DIP/', 'library': '/libraries/ENCLB486PZP/', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'status': 'in progress'}]}
# row 77 created: 3be43872-b148-4c09-9dfd-ae21e5a3528c
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'@type': ['replicate', 'item'], 'schema_version': '5', 'biological_replicate_number': 1, 'technical_replicate_number': 1, 'aliases': ['richard-myers:SL113833-rep'], 'uuid': '3022ae23-f183-4bec-8c77-2789b4b7234d', 'date_created': '2015-09-17T21:11:21.353109+00:00', '@id': '/replicates/3022ae23-f183-4bec-8c77-2789b4b7234d/', 'experiment': '/experiments/ENCSR497ERE/', 'status': 'in progress', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'library': '/libraries/ENCLB177PNN/'}]}
# row 78 created: 3022ae23-f183-4bec-8c77-2789b4b7234d
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'@type': ['replicate', 'item'], 'schema_version': '5', 'biological_replicate_number': 2, 'technical_replicate_number': 1, 'aliases': ['richard-myers:SL113834-rep'], 'uuid': 'de8c0091-f6db-4247-b0ae-64183ea7011b', 'date_created': '2015-09-17T21:11:21.609222+00:00', '@id': '/replicates/de8c0091-f6db-4247-b0ae-64183ea7011b/', 'experiment': '/experiments/ENCSR497ERE/', 'library': '/libraries/ENCLB869CAV/', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'status': 'in progress'}]}
# row 79 created: de8c0091-f6db-4247-b0ae-64183ea7011b
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'@type': ['replicate', 'item'], 'schema_version': '5', 'biological_replicate_number': 1, 'technical_replicate_number': 1, 'aliases': ['richard-myers:SL113837-rep'], 'uuid': '3dde4164-5c67-4bfb-8f61-df047208b56f', 'date_created': '2015-09-17T21:11:21.864026+00:00', '@id': '/replicates/3dde4164-5c67-4bfb-8f61-df047208b56f/', 'experiment': '/experiments/ENCSR267CQC/', 'status': 'in progress', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'library': '/libraries/ENCLB508WQD/'}]}
# row 80 created: 3dde4164-5c67-4bfb-8f61-df047208b56f
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'@type': ['replicate', 'item'], 'schema_version': '5', 'biological_replicate_number': 2, 'technical_replicate_number': 1, 'aliases': ['richard-myers:SL113838-rep'], 'uuid': 'a2593182-80c9-4d10-a2fe-20765e74aab3', 'date_created': '2015-09-17T21:11:22.100077+00:00', '@id': '/replicates/a2593182-80c9-4d10-a2fe-20765e74aab3/', 'experiment': '/experiments/ENCSR267CQC/', 'library': '/libraries/ENCLB083UKV/', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'status': 'in progress'}]}
# row 81 created: a2593182-80c9-4d10-a2fe-20765e74aab3
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'@type': ['replicate', 'item'], 'schema_version': '5', 'biological_replicate_number': 1, 'technical_replicate_number': 1, 'aliases': ['richard-myers:SL113839-rep'], 'uuid': '118f2653-ee82-48cc-8535-d3682323f64a', 'date_created': '2015-09-17T21:11:22.345663+00:00', '@id': '/replicates/118f2653-ee82-48cc-8535-d3682323f64a/', 'experiment': '/experiments/ENCSR353XMS/', 'library': '/libraries/ENCLB251GCH/', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'status': 'in progress'}]}
# row 82 created: 118f2653-ee82-48cc-8535-d3682323f64a
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'@type': ['replicate', 'item'], 'schema_version': '5', 'biological_replicate_number': 2, 'technical_replicate_number': 1, 'aliases': ['richard-myers:SL113840-rep'], 'uuid': '96f15d98-6458-4eff-9cb4-1436aba163cf', 'date_created': '2015-09-17T21:11:22.590480+00:00', '@id': '/replicates/96f15d98-6458-4eff-9cb4-1436aba163cf/', 'experiment': '/experiments/ENCSR353XMS/', 'status': 'in progress', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'library': '/libraries/ENCLB587AAL/'}]}
# row 83 created: 96f15d98-6458-4eff-9cb4-1436aba163cf
# Reponse {'@type': ['result'], 'status': 'success', '@graph': [{'@type': ['replicate', 'item'], 'schema_version': '5', 'biological_replicate_number': 1, 'technical_replicate_number': 1, 'aliases': ['richard-myers:SL113841-rep'], 'uuid': '2c9f1c68-6e7f-4b65-8f7e-2d30578623ed', 'date_created': '2015-09-17T21:11:22.833923+00:00', '@id': '/replicates/2c9f1c68-6e7f-4b65-8f7e-2d30578623ed/', 'experiment': '/experiments/ENCSR308SIN/', 'library': '/libraries/ENCLB993LZM/', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'status': 'in progress'}]}
# row 84 created: 2c9f1c68-6e7f-4b65-8f7e-2d30578623ed
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'@type': ['replicate', 'item'], 'schema_version': '5', 'biological_replicate_number': 2, 'technical_replicate_number': 1, 'aliases': ['richard-myers:SL113842-rep'], 'uuid': '611a4d7f-4505-4d30-b166-72bc0c0b15a1', 'date_created': '2015-09-17T21:11:23.082774+00:00', '@id': '/replicates/611a4d7f-4505-4d30-b166-72bc0c0b15a1/', 'experiment': '/experiments/ENCSR308SIN/', 'status': 'in progress', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'library': '/libraries/ENCLB250OKP/'}]}
# row 85 created: 611a4d7f-4505-4d30-b166-72bc0c0b15a1
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'@type': ['replicate', 'item'], 'schema_version': '5', 'biological_replicate_number': 1, 'technical_replicate_number': 1, 'aliases': ['richard-myers:SL113843-rep'], 'uuid': 'abe48467-0787-48f5-af54-bc424c8627de', 'date_created': '2015-09-17T21:11:23.328633+00:00', '@id': '/replicates/abe48467-0787-48f5-af54-bc424c8627de/', 'experiment': '/experiments/ENCSR236BQO/', 'status': 'in progress', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'library': '/libraries/ENCLB263QTM/'}]}
# row 86 created: abe48467-0787-48f5-af54-bc424c8627de
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'@type': ['replicate', 'item'], 'schema_version': '5', 'biological_replicate_number': 2, 'technical_replicate_number': 1, 'aliases': ['richard-myers:SL113844-rep'], 'uuid': '561b5687-b6d7-43c1-b517-89ab331c2c36', 'date_created': '2015-09-17T21:11:23.579452+00:00', '@id': '/replicates/561b5687-b6d7-43c1-b517-89ab331c2c36/', 'experiment': '/experiments/ENCSR236BQO/', 'library': '/libraries/ENCLB332DBP/', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'status': 'in progress'}]}
# row 87 created: 561b5687-b6d7-43c1-b517-89ab331c2c36
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'@type': ['replicate', 'item'], 'schema_version': '5', 'biological_replicate_number': 1, 'technical_replicate_number': 1, 'aliases': ['richard-myers:SL113845-rep'], 'uuid': 'c2704763-9454-4292-a3c1-f66f6ed8a539', 'date_created': '2015-09-17T21:11:23.825025+00:00', '@id': '/replicates/c2704763-9454-4292-a3c1-f66f6ed8a539/', 'experiment': '/experiments/ENCSR047EJT/', 'status': 'in progress', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'library': '/libraries/ENCL
', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'status': 'in progress'}]}
# row 105 created: 103431ac-891c-4070-8fcc-1a0b14aea784
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'@type': ['replicate', 'item'], 'schema_version': '5', 'biological_replicate_number': 1, 'technical_replicate_number': 1, 'aliases': ['richard-myers:SL113864-rep'], 'uuid': 'b32027d6-16d4-4729-9fa1-2398a8cecc74', 'date_created': '2015-09-17T21:11:28.498462+00:00', '@id': '/replicates/b32027d6-16d4-4729-9fa1-2398a8cecc74/', 'experiment': '/experiments/ENCSR949VVK/', 'library': '/libraries/ENCLB513CUQ/', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'status': 'in progress'}]}
# row 106 created: b32027d6-16d4-4729-9fa1-2398a8cecc74
# Reponse {'@type': ['result'], 'status': 'success', '@graph': [{'@type': ['replicate', 'item'], 'schema_version': '5', 'biological_replicate_number': 2, 'technical_replicate_number': 1, 'aliases': ['richard-myers:SL113865-rep'], 'uuid': '5297dbfd-857a-432d-9437-4791be922179', 'date_created': '2015-09-17T21:11:28.744247+00:00', '@id': '/replicates/5297dbfd-857a-432d-9437-4791be922179/', 'experiment': '/experiments/ENCSR949VVK/', 'library': '/libraries/ENCLB881GRC/', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'status': 'in progress'}]}
# row 107 created: 5297dbfd-857a-432d-9437-4791be922179
# /home/diane/proj/htsworkflow/htsworkflow/submission/encoded.py:391: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   sheet['uuid'][i] = uuid
# 68

# %%
if created:
    updatesdf = pandas.DataFrame(created, columns=['uuid', 'experiment', 'library'])
    updatesdf.to_excel('/tmp/replicates.xlsx')

# %% [markdown]
# # Create spike

# %%
lab = 'barbara-wold'
award = 'U54HG006998'

# %%
import imp
import htsworkflow.submission.encoded

# %%
imp.reload(htsworkflow.submission.encoded)
# Out:
# <module 'htsworkflow.submission.encoded' from '/home/diane/proj/htsworkflow/htsworkflow/submission/encoded.py'>

# %%
from htsworkflow.submission.encoded import Document

# %%
profile_6_concentration = Document(
  "/home/diane/proj/encode3-curation/ERCC 1000X sequences for Diane June25_2015.pdf",
  "spike-in concentrations",
  "ERCC-only concentrations that are 1000x single cell spike-ins"
)

# %%
concentration_uuid = '/documents/394ce5f5-cf93-4cc6-b0fc-92ec1fb6b45a/'
concentration_document = profile_6_concentration.create_if_needed(encode, concentration_uuid)

# %%
document_id = concentration_document['@graph'][0]['@id']
document_id
# Out:
# '/documents/394ce5f5-cf93-4cc6-b0fc-92ec1fb6b45a/'

# %%
ERCC = {
    'description': 'ERCC-only spike-ins that are 1000x single cell spike-ins"',
    'dataset_type': 'spike-ins',
    'related_files': ['/files/ENCFF001RTP'],
    'award': award,
    'lab': lab,
    'documents': [document_id],
}
encode.validate(ERCC, '/datasets/')
ERCC_accession = '/datasets/ENCSR884LPM/'
if ERCC_accession is None:
    print(encode.post_json('/datasets/', ERCC))
# Out:
# {'@type': ['result'], 'status': 'success', '@graph': [{'assembly': [], 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'dbxrefs': [], '@type': ['dataset', 'item'], 'lab': '/labs/barbara-wold/', 'revoked_files': [], 'aliases': [], 'related_files': ['/files/ENCFF001RTP/'], 'status': 'proposed', 'dataset_type': 'spike-ins', 'files': ['/files/ENCFF001RTP/'], 'documents': ['/documents/394ce5f5-cf93-4cc6-b0fc-92ec1fb6b45a/'], 'date_created': '2015-06-26T00:08:45.243031+00:00', 'alternate_accessions': [], 'contributing_files': [], 'accession': 'ENCSR884LPM', 'schema_version': '6', 'references': [], '@id': '/datasets/ENCSR884LPM/', 'award': '/awards/U54HG006998/', 'original_files': [], 'uuid': '19bf00b0-f0d2-48b3-a4c7-a7d2108cbc0e', 'description': 'ERCC-only spike-ins that are 1000x single cell spike-ins"'}]}

# %%
def make_manifest(spreadsheet_name, submission_root, map_name):
    y3q3_book = gcat.get_file(spreadsheet_name, fmt='pandas_excel')
    libraries = y3q3_book.parse('Libraries')
    replicates = y3q3_book.parse('Replicates')
    
    pongo = paramiko.SSHClient()
    pongo.set_missing_host_key_policy(paramiko.WarningPolicy())
    pongo.connect('pongo.cacr.caltech.edu', username='diane')
    sftp = pongo.open_sftp()
    sftp.chdir(submission_root)
    files = 0
    for line in sftp.open(map_name):
        # skip comments
        line = line.strip()
        if len(line) == 0 or line.startswith('#'):
            continue

        library_id, dirname = line.split()
        alias = 'barbara-wold:{}'.format(library_id)
        library_row = libraries[libraries['aliases:array'] == alias]
        replicate_row = replicates[replicates['library'] == alias]
        for filename in sftp.listdir(dirname):
            if filename.endswith('fastq.gz'):
                relative_path = os.path.join(dirname, filename)
                metadata = {
                    'dataset': list(replicate_row['experiment'])[0],
                    'submitted_file_name': relative_path,
                    'replicate': list(replicate_row['uuid'])[0],
                    'lab': list(library_row['lab'])[0],
                    'award': list(library_row['award'])[0],
                }
                #display.display_pretty(metadata)
                print('<http://jumpgate.caltech.edu/wiki/SubmissionsLog/encode-y3q3#'+dirname+'>')
                print('  encode3:dataset "{}" ;'.format(metadata['dataset']))
                print('  encode3:replicate "{}" ;'.format(metadata['replicate']))
                print('  encode3:lab "{}" ;'.format(metadata['lab']))
                print('  encode3:award "{}" .'.format(metadata['award']))

                print('<file:///woldlab/castor/home/diane/proj/submission/encode-y3q3/'+relative_path+'>')
                print('  encode3:output_type "reads" ;')
                print('  encode3:read_length 100 ; ')
                print('  encode3:file_format "fastq" .')
                files += 1

    print('generated {} records'.format(files))

# %%
make_manifest(spreadsheet_name, 'proj/submission/encode-y3q3', 'mice.txt')
# Out:
# <http://jumpgate.caltech.edu/wiki/SubmissionsLog/encode-y3q3#15272-LC_758_C57Bl6_layer_V_pyramidal_neuron_single_cell>
#   encode3:dataset "ENCSR746LUP" ;
#   encode3:replicate "0e68587e-327b-4129-850a-2645b80ea93f" ;
#   encode3:lab "barbara-wold" ;
#   encode3:award "U54HG006998" .
# <file:///woldlab/castor/home/diane/proj/submission/encode-y3q3/15272-LC_758_C57Bl6_layer_V_pyramidal_neuron_single_cell/15272_HBE4EADXX_c116_l2.fastq.gz>
#   encode3:output_type "reads" ;
#   encode3:read_length 100 ;
#   encode3:file_format "fastq" .
# <http://jumpgate.caltech.edu/wiki/SubmissionsLog/encode-y3q3#15272-LC_758_C57Bl6_layer_V_pyramidal_neuron_single_cell>
#   encode3:dataset "ENCSR746LUP" ;
#   encode3:replicate "0e68587e-327b-4129-850a-2645b80ea93f" ;
#   encode3:lab "barbara-wold" ;
#   encode3:award "U54HG006998" .
# <file:///woldlab/castor/home/diane/proj/submission/encode-y3q3/15272-LC_758_C57Bl6_layer_V_pyramidal_neuron_single_cell/15272_HBE4EADXX_c116_l1.fastq.gz>
#   encode3:output_type "reads" ;
#   encode3:read_length 100 ;
#   encode3:file_format "fastq" .
# <http://jumpgate.caltech.edu/wiki/SubmissionsLog/encode-y3q3#15273-LC_759_C57Bl6_layer_V_pyramidal_neuron_single_cell>
#   encode3:dataset "ENCSR198EIH" ;
#   encode3:replicate "026f916c-b37e-4a20-a51f-83b97458daef" ;
#   encode3:lab "barbara-wold" ;
#   encode3:award "U54HG006998" .
# <file:///woldlab/castor/home/diane/proj/submission/encode-y3q3/15273-LC_759_C57Bl6_layer_V_pyramidal_neuron_single_cell/15273_H00EWBCXX_c116_l1.fastq.gz>
#   encode3:output_type "reads" ;
#   encode3:read_length 100 ;
#   encode3:file_format "fastq" .
# <http://jumpgate.caltech.edu/wiki/SubmissionsLog/encode-y3q3#15273-LC_759_C57Bl6_layer_V_pyramidal_neuron_single_cell>
#   encode3:dataset "ENCSR198EIH" ;
#   encode3:replicate "026f916c-b37e-4a20-a51f-83b97458daef" ;
#   encode3:lab "barbara-wold" ;
#   encode3:award "U54HG006998" .
# <file:///woldlab/castor/home/diane/proj/submission/encode-y3q3/15273-LC_759_C57Bl6_layer_V_pyramidal_neuron_single_cell/15273_HBE4EADXX_c116_l2.fastq.gz>
#   encode3:output_type "reads" ;
#   encode3:read_length 100 ;
#   encode3:file_format "fastq" .
# <http://jumpgate.caltech.edu/wiki/SubmissionsLog/encode-y3q3#15273-LC_759_C57Bl6_layer_V_pyramidal_neuron_single_cell>
#   encode3:dataset "ENCSR198EIH" ;
#   encode3:replicate "026f916c-b37e-4a20-a51f-83b97458daef" ;
#   encode3:lab "barbara-wold" ;
#   encode3:award "U54HG006998" .
# <file:///woldlab/castor/home/diane/proj/submission/encode-y3q3/15273-LC_759_C57Bl6_layer_V_pyramidal_neuron_single_cell/15273_HBE4EADXX_c116_l1.fastq.gz>
#   encode3:output_type "reads" ;
#   encode3:read_length 100 ;
#   encode3:file_format "fastq" .
# <http://jumpgate.caltech.edu/wiki/SubmissionsLog/encode-y3q3#15273-LC_759_C57Bl6_layer_V_pyramidal_neuron_single_cell>
#   encode3:dataset "ENCSR198EIH" ;
#   encode3:replicate "026f916c-b37e-4a20-a51f-83b97458daef" ;
#   encode3:lab "barbara-wold" ;
#   encode3:award "U54HG006998" .
# <file:///woldlab/castor/home/diane/proj/submission/encode-y3q3/15273-LC_759_C57Bl6_layer_V_pyramidal_neuron_single_cell/15273_H00EWBCXX_c116_l2.fastq.gz>
#   encode3:output_type "reads" ;
#   encode3:read_length 100 ;
#   encode3:file_format "fastq" .
# <http://jumpgate.caltech.edu/wiki/SubmissionsLog/encode-y3q3#15275-LC_761_C57Bl6_layer_V_pyramidal_neuron_single_cell>
#   encode3:dataset "ENCSR100KRK" ;
#   encode3:replicate "de6b66ee-2b05-4749-8e06-1bfb7b0ee32d" ;
#   encode3:lab "barbara-wold" ;
#   encode3:award "U54HG006998" .
# <file:///woldlab/castor/home/diane/proj/submission/encode-y3q3/15275-LC_761_C57Bl6_layer_V_pyramidal_neuron_single_cell/15275_H00EWBCXX_c116_l1.fastq.gz>
#   encode3:output_type "reads" ;
#   encode3:read_length 100 ;
#   encode3:file_format "fastq" .
# <http://jumpgate.caltech.edu/wiki/SubmissionsLog/encode-y3q3#15275-LC_761_C57Bl6_layer_V_pyramidal_neuron_single_cell>
#   encode3:dataset "ENCSR100KRK" ;
#   encode3:replicate "de6b66ee-2b05-4749-8e06-1bfb7b0ee32d" ;
#   encode3:lab "barbara-wold" ;
#   encode3:award "U54HG006998" .
# <file:///woldlab/castor/home/diane/proj/submission/encode-y3q3/15275-LC_761_C57Bl6_layer_V_pyramidal_neuron_single_cell/15275_HBE4EADXX_c116_l1.fastq.gz>
#   encode3:output_type "reads" ;
#   encode3:read_length 100 ;
#   encode3:file_format "fastq" .
# <http://jumpgate.caltech.edu/wiki/SubmissionsLog/encode-y3q3#15275-LC_761_C57Bl6_layer_V_pyramidal_neuron_single_cell>
#   encode3:dataset "ENCSR100KRK" ;
#   encode3:replicate "de6b66ee-2b05-4749-8e06-1bfb7b0ee32d" ;
#   encode3:lab "barbara-wold" ;
#   encode3:award "U54HG006998" .
# <file:///woldlab/castor/home/diane/proj/submission/encode-y3q3/15275-LC_761_C57Bl6_layer_V_pyramidal_neuron_single_cell/15275_HBE4EADXX_c116_l2.fastq.gz>
#   encode3:output_type "reads" ;
#   encode3:read_length 100 ;
#   encode3:file_format "fastq" .
# <http://jumpgate.caltech.edu/wiki/SubmissionsLog/encode-y3q3#15275-LC_761_C57Bl6_layer_V_pyramidal_neuron_single_cell>
#   encode3:dataset "ENCSR100KRK" ;
#   encode3:replicate "de6b66ee-2b05-4749-8e06-1bfb7b0ee32d" ;
#   encode3:lab "barbara-wold" ;
#   encode3:award "U54HG006998" .
# <file:///woldlab/castor/home/diane/proj/submission/encode-y3q3/15275-LC_761_C57Bl6_layer_V_pyramidal_neuron_single_cell/15275_H00EWBCXX_c116_l2.fastq.gz>
#   encode3:output_type "reads" ;
#   encode3:read_length 100 ;
#   encode3:file_format "fastq" .
# <http://jumpgate.caltech.edu/wiki/SubmissionsLog/encode-y3q3#15276-LC_762_C57Bl6_layer_V_pyramidal_neuron_single_cell>
#   encode3:dataset "ENCSR739YUO" ;
#   encode3:replicate "03975590-a02b-4c16-9089-49e9f849a551" ;
#   encode3:lab "barbara-wold" ;
#   encode3:award "U54HG006998" .
# <file:///woldlab/castor/home/diane/proj/submission/encode-y3q3/15276-LC_762_C57Bl6_layer_V_pyramidal_neuron_single_cell/15276_HBE4EADXX_c116_l2.fastq.gz>
#   encode3:output_type "reads" ;
#   encode3:read_length 100 ;
#   encode3:file_format "fastq" .
# <http://jumpgate.caltech.edu/wiki/SubmissionsLog/encode-y3q3#15276-LC_762_C57Bl6_layer_V_pyramidal_neuron_single_cell>
#   encode3:dataset "ENCSR739YUO" ;
#   encode3:replicate "03975590-a02b-4c16-9089-49e9f849a551" ;
#   encode3:lab "barbara-wold" ;
#   encode3:award "U54HG006998" .
# <file:///woldlab/castor/home/diane/proj/submission/encode-y3q3/15276-LC_762_C57Bl6_layer_V_pyramidal_neuron_single_cell/15276_H00EWBCXX_c116_l2.fastq.gz>
#   encode3:output_type "reads" ;
#   encode3:read_length 100 ;
#   encode3:file_format "fastq" .
# <http://jumpgate.caltech.edu/wiki/SubmissionsLog/encode-y3q3#15276-LC_762_C57Bl6_layer_V_pyramidal_neuron_single_cell>
#   encode3:dataset "ENCSR739YUO" ;
#   encode3:replicate "03975590-a02b-4c16-9089-49e9f849a551" ;
#   encode3:lab "barbara-wold" ;
#   encode3:award "U54HG006998" .
# <file:///woldlab/castor/home/diane/proj/submission/encode-y3q3/15276-LC_762_C57Bl6_layer_V_pyramidal_neuron_single_cell/15276_H00EWBCXX_c116_l1.fastq.gz>
#   encode3:output_type "reads" ;
#   encode3:read_length 100 ;
#   encode3:file_format "fastq" .
# <http://jumpgate.caltech.edu/wiki/SubmissionsLog/encode-y3q3#15276-LC_762_C57Bl6_layer_V_pyramidal_neuron_single_cell>
#   encode3:dataset "ENCSR739YUO" ;
#   encode3:replicate "03975590-a02b-4c16-9089-49e9f849a551" ;
#   encode3:lab "barbara-wold" ;
#   encode3:award "U54HG006998" .
# <file:///woldlab/castor/home/diane/proj/submission/encode-y3q3/15276-LC_762_C57Bl6_layer_V_pyramidal_neuron_single_cell/15276_HBE4EADXX_c116_l1.fastq.gz>
#   encode3:output_type "reads" ;
#   encode3:read_length 100 ;
#   encode3:file_format "fastq" .
# <http://jumpgate.caltech.edu/wiki/SubmissionsLog/encode-y3q3#15277-LC_763_C57Bl6_layer_V_pyramidal_neuron_single_cell>
#   encode3:dataset "ENCSR927IOO" ;
#   encode3:replicate "2174944c-92c0-431d-b8d3-6af249f7e52a" ;
#   encode3:lab "barbara-wold" ;
#   encode3:award "U54HG006998" .
# <file:///woldlab/castor/home/diane/proj/submission/encode-y3q3/15277-LC_763_C57Bl6_layer_V_pyramidal_neuron_single_cell/15277_HBE4EADXX_c116_l1.fastq.gz>
#   encode3:output_type "reads" ;
#   encode3:read_length 100 ;
#   encode3:file_format "fastq" .
# <http://jumpgate.caltech.edu/wiki/SubmissionsLog/encode-y3q3#15277-LC_763_C57Bl6_layer_V_pyramidal_neuron_single_cell>
#   encode3:dataset "ENCSR927IOO" ;
#   encode3:replicate "2174944c-92c0-431d-b8d3-6af249f7e52a" ;
#   encode3:lab "barbara-wold" ;
#   encode3:award "U54HG006998" .
# <file:///woldlab/castor/home/diane/proj/submission/encode-y3q3/15277-LC_763_C57Bl6_layer_V_pyramidal_neuron_single_cell/15277_H00EWBCXX_c116_l2.fastq.gz>
#   encode3:output_type "reads" ;
#   encode3:read_length 100 ;
#   encode3:file_format "fastq" .
# <http://jumpgate.caltech.edu/wiki/SubmissionsLog/encode-y3q3#15277-LC_763_C57Bl6_layer_V_pyramidal_neuron_single_cell>
#   encode3:dataset "ENCSR927IOO" ;
#   encode3:replicate "2174944c-92c0-431d-b8d3-6af249f7e52a" ;
#   encode3:lab "barbara-wold" ;
#   encode3:award "U54HG006998" .
# <file:///woldlab/castor/home/diane/proj/submission/encode-y3q3/15277-LC_763_C57Bl6_layer_V_pyramidal_neuron_single_cell/15277_HBE4EADXX_c116_l2.fastq.gz>
#   encode3:output_type "reads" ;
#   encode3:read_length 100 ;
#   encode3:file_format "fastq" .
# <http://jumpgate.caltech.edu/wiki/SubmissionsLog/encode-y3q3#15277-LC_763_C57Bl6_layer_V_pyramidal_neuron_single_cell>
#   encode3:dataset "ENCSR927IOO" ;
#   encode3:replicate "2174944c-92c0-431d-b8d3-6af249f7e52a" ;
#   encode3:lab "barbara-wold" ;
#   encode3:award "U54HG006998" .
# <file:///woldlab/castor/home/diane/proj/submission/encode-y3q3/15277-LC_763_C57Bl6_layer_V_pyramidal_neuron_single_cell/15277_H00EWBCXX_c116_l1.fastq.gz>
#   encode3:output_type "reads" ;
#   encode3:read_length 100 ;
#   encode3:file_format "fastq" .
# <http://jumpgate.caltech.edu/wiki/SubmissionsLog/encode-y3q3#15278-LC_767_C57Bl6_layer_V_pyramidal_neuron_single_cell>
#   encode3:dataset "ENCSR846FYI" ;
#   encode3:replicate "a92133a6-e847-4076-a827-2fac96e91333" ;
#   encode3:lab "barbara-wold" ;
#   encode3:award "U54HG006998" .
# <file:///woldlab/castor/home/diane/proj/submission/encode-y3q3/15278-LC_767_C57Bl6_layer_V_pyramidal_neuron_single_cell/15278_H00EWBCXX_c116_l2.fastq.gz>
#   encode3:output_type "reads" ;
#   encode3:read_length 100 ;
#   encode3:file_format "fastq" .
# <http://jumpgate.caltech.edu/wiki/SubmissionsLog/encode-y3q3#15278-LC_767_C57Bl6_layer_V_pyramidal_neuron_single_cell>
#   encode3:dataset "ENCSR846FYI" ;
#   encode3:replicate "a92133a6-e847-4076-a827-2fac96e91333" ;
#   encode3:lab "barbara-wold" ;
#   encode3:award "U54HG006998" .
# <file:///woldlab/castor/home/diane/proj/submission/encode-y3q3/15278-LC_767_C57Bl6_layer_V_pyramidal_neuron_single_cell/15278_HBE4EADXX_c116_l1.fastq.gz>
#   encode3:output_type "reads" ;
#   encode3:read_length 100 ;
#   encode3:file_format "fastq" .
# <http://jumpgate.caltech.edu/wiki/SubmissionsLog/encode-y3q3#15278-LC_767_C57Bl6_layer_V_pyramidal_neuron_single_cell>
#   encode3:dataset "ENCSR846FYI" ;
#   encode3:replicate "a92133a6-e847-4076-a827-2fac96e91333" ;
#   encode3:lab "barbara-wold" ;
#   encode3:award "U54HG006998" .
# <file:///woldlab/castor/home/diane/proj/submission/encode-y3q3/15278-LC_767_C57Bl6_layer_V_pyramidal_neuron_single_cell/15278_HBE4EADXX_c116_l2.fastq.gz>
#   encode3:output_type "reads" ;
#   encode3:read_length 100 ;
#   encode3:file_format "fastq" .
# <http://jumpgate.caltech.edu/wiki/SubmissionsLog/encode-y3q3#15278-LC_767_C57Bl6_layer_V_pyramidal_neuron_single_cell>
#   encode3:dataset "ENCSR846FYI" ;
#   encode3:replicate "a92133a6-e847-4076-a827-2fac96e91333" ;
#   encode3:lab "barbara-wold" ;
#   encode3:award "U54HG006998" .
# <file:///woldlab/castor/home/diane/proj/submission/encode-y3q3/15278-LC_767_C57Bl6_layer_V_pyramidal_neuron_single_cell/15278_H00EWBCXX_c116_l1.fastq.gz>
#   encode3:output_type "reads" ;
#   encode3:read_length 100 ;
#   encode3:file_format "fastq" .
# <http://jumpgate.caltech.edu/wiki/SubmissionsLog/encode-y3q3#15279-LC_768_C57Bl6_layer_V_pyramidal_neuron_single_cell>
#   encode3:dataset "ENCSR427FOY" ;
#   encode3:replicate "82942f63-d2ab-4cc2-b3b1-f49b87b44488" ;
#   encode3:lab "barbara-wold" ;
#   encode3:award "U54HG006998" .
# <file:///woldlab/castor/home/diane/proj/submission/encode-y3q3/15279-LC_768_C57Bl6_layer_V_pyramidal_neuron_single_cell/15279_HBE4EADXX_c116_l2.fastq.gz>
#   encode3:output_type "reads" ;
#   encode3:read_length 100 ;
#   encode3:file_format "fastq" .
# <http://jumpgate.caltech.edu/wiki/SubmissionsLog/encode-y3q3#15279-LC_768_C57Bl6_layer_V_pyramidal_neuron_single_cell>
#   encode3:dataset "ENCSR427FOY" ;
#   encode3:replicate "82942f63-d2ab-4cc2-b3b1-f49b87b44488" ;
#   encode3:lab "barbara-wold" ;
#   encode3:award "U54HG006998" .
# <file:///woldlab/castor/home/diane/proj/submission/encode-y3q3/15279-LC_768_C57Bl6_layer_V_pyramidal_neuron_single_cell/15279_HBE4EADXX_c116_l1.fastq.gz>
#   encode3:output_type "reads" ;
#   encode3:read_length 100 ;
#   encode3:file_format "fastq" .
# <http://jumpgate.caltech.edu/wiki/SubmissionsLog/encode-y3q3#15280-LC_769_C57Bl6_layer_V_pyramidal_neuron_single_cell>
#   encode3:dataset "ENCSR390KQJ" ;
#   encode3:replicate "3d378d88-a9a6-4322-9251-52f86fae5020" ;
#   encode3:lab "barbara-wold" ;
#   encode3:award "U54HG006998" .
# <file:///woldlab/castor/home/diane/proj/submission/encode-y3q3/15280-LC_769_C57Bl6_layer_V_pyramidal_neuron_single_cell/15280_HBE4EADXX_c116_l1.fastq.gz>
#   encode3:output_type "reads" ;
#   encode3:read_length 100 ;
#   encode3:file_format "fastq" .
# <http://jumpgate.caltech.edu/wiki/SubmissionsLog/encode-y3q3#15280-LC_769_C57Bl6_layer_V_pyramidal_neuron_single_cell>
#   encode3:dataset "ENCSR390KQJ" ;
#   encode3:replicate "3d378d88-a9a6-4322-9251-52f86fae5020" ;
#   encode3:lab "barbara-wold" ;
#   encode3:award "U54HG006998" .
# <file:///woldlab/castor/home/diane/proj/submission/encode-y3q3/15280-LC_769_C57Bl6_layer_V_pyramidal_neuron_single_cell/15280_HBE4EADXX_c116_l2.fastq.gz>
#   encode3:output_type "reads" ;
#   encode3:read_length 100 ;
#   encode3:file_format "fastq" .
# <http://jumpgate.caltech.edu/wiki/SubmissionsLog/encode-y3q3#15281-LC_770_C57Bl6_layer_V_pyramidal_neuron_single_cell>
#   encode3:dataset "ENCSR138VRG" ;
#   encode3:replicate "6c99af24-c93b-49f3-86c4-21f18d4abb3a" ;
#   encode3:lab "barbara-wold" ;
#   encode3:award "U54HG006998" .
# <file:///woldlab/castor/home/diane/proj/submission/encode-y3q3/15281-LC_770_C57Bl6_layer_V_pyramidal_neuron_single_cell/15281_H00EWBCXX_c116_l2.fastq.gz>
#   encode3:output_type "reads" ;
#   encode3:read_length 100 ;
#   encode3:file_format "fastq" .
# <http://jumpgate.caltech.edu/wiki/SubmissionsLog/encode-y3q3#15281-LC_770_C57Bl6_layer_V_pyramidal_neuron_single_cell>
#   encode3:dataset "ENCSR138VRG" ;
#   encode3:replicate "6c99af24-c93b-49f3-86c4-21f18d4abb3a" ;
#   encode3:lab "barbara-wold" ;
#   encode3:award "U54HG006998" .
# <file:///woldlab/castor/home/diane/proj/submission/encode-y3q3/15281-LC_770_C57Bl6_layer_V_pyramidal_neuron_single_cell/15281_H00EWBCXX_c116_l1.fastq.gz>
#   encode3:output_type "reads" ;
#   encode3:read_length 100 ;
#   encode3:file_format "fastq" .
# <http://jumpgate.caltech.edu/wiki/SubmissionsLog/encode-y3q3#15281-LC_770_C57Bl6_layer_V_pyramidal_neuron_single_cell>
#   encode3:dataset "ENCSR138VRG" ;
#   encode3:replicate "6c99af24-c93b-49f3-86c4-21f18d4abb3a" ;
#   encode3:lab "barbara-wold" ;
#   encode3:award "U54HG006998" .
# <file:///woldlab/castor/home/diane/proj/submission/encode-y3q3/15281-LC_770_C57Bl6_layer_V_pyramidal_neuron_single_cell/15281_HBE4EADXX_c116_l2.fastq.gz>
#   encode3:output_type "reads" ;
#   encode3:read_length 100 ;
#   encode3:file_format "fastq" .
# <http://jumpgate.caltech.edu/wiki/SubmissionsLog/encode-y3q3#15281-LC_770_C57Bl6_layer_V_pyramidal_neuron_single_cell>
#   encode3:dataset "ENCSR138VRG" ;
#   encode3:replicate "6c99af24-c93b-49f3-86c4-21f18d4abb3a" ;
#   encode3:lab "barbara-wold" ;
#   encode3:award "U54HG006998" .
# <file:///woldlab/castor/home/diane/proj/submission/encode-y3q3/15281-LC_770_C57Bl6_layer_V_pyramidal_neuron_single_cell/15281_HBE4EADXX_c116_l1.fastq.gz>
#   encode3:output_type "reads" ;
#   encode3:read_length 100 ;
#   encode3:file_format "fastq" .
# <http://jumpgate.caltech.edu/wiki/SubmissionsLog/encode-y3q3#15282-LC_771_C57Bl6_layer_V_pyramidal_neuron_single_cell>
#   encode3:dataset "ENCSR782WIL" ;
#   encode3:replicate "dc98fd1e-53e5-4e69-94e9-76682f54dd65" ;
#   encode3:lab "barbara-wold" ;
#   encode3:award "U54HG006998" .
# <file:///woldlab/castor/home/diane/proj/submission/encode-y3q3/15282-LC_771_C57Bl6_layer_V_pyramidal_neuron_single_cell/15282_H00EWBCXX_c116_l2.fastq.gz>
#   encode3:output_type "reads" ;
#   encode3:read_length 100 ;
#   encode3:file_format "fastq" .
# <http://jumpgate.caltech.edu/wiki/SubmissionsLog/encode-y3q3#15282-LC_771_C57Bl6_layer_V_pyramidal_neuron_single_cell>
#   encode3:dataset "ENCSR782WIL" ;
#   encode3:replicate "dc98fd1e-53e5-4e69-94e9-76682f54dd65" ;
#   encode3:lab "barbara-wold" ;
#   encode3:award "U54HG006998" .
# <file:///woldlab/castor/home/diane/proj/submission/encode-y3q3/15282-LC_771_C57Bl6_layer_V_pyramidal_neuron_single_cell/15282_HBE4EADXX_c116_l1.fastq.gz>
#   encode3:output_type "reads" ;
#   encode3:read_length 100 ;
#   encode3:file_format "fastq" .
# <http://jumpgate.caltech.edu/wiki/SubmissionsLog/encode-y3q3#15282-LC_771_C57Bl6_layer_V_pyramidal_neuron_single_cell>
#   encode3:dataset "ENCSR782WIL" ;
#   encode3:replicate "dc98fd1e-53e5-4e69-94e9-76682f54dd65" ;
#   encode3:lab "barbara-wold" ;
#   encode3:award "U54HG006998" .
# <file:///woldlab/castor/home/diane/proj/submission/encode-y3q3/15282-LC_771_C57Bl6_layer_V_pyramidal_neuron_single_cell/15282_HBE4EADXX_c116_l2.fastq.gz>
#   encode3:output_type "reads" ;
#   encode3:read_length 100 ;
#   encode3:file_format "fastq" .
# <http://jumpgate.caltech.edu/wiki/SubmissionsLog/encode-y3q3#15282-LC_771_C57Bl6_layer_V_pyramidal_neuron_single_cell>
#   encode3:dataset "ENCSR782WIL" ;
#   encode3:replicate "dc98fd1e-53e5-4e69-94e9-76682f54dd65" ;
#   encode3:lab "barbara-wold" ;
#   encode3:award "U54HG006998" .
# <file:///woldlab/castor/home/diane/proj/submission/encode-y3q3/15282-LC_771_C57Bl6_layer_V_pyramidal_neuron_single_cell/15282_H00EWBCXX_c116_l1.fastq.gz>
#   encode3:output_type "reads" ;
#   encode3:read_length 100 ;
#   encode3:file_format "fastq" .
# <http://jumpgate.caltech.edu/wiki/SubmissionsLog/encode-y3q3#15283-LC_772_C57Bl6_layer_V_pyramidal_neuron_single_cell>
#   encode3:dataset "ENCSR195BCE" ;
#   encode3:replicate "c4dec325-a7e5-45cf-bbe0-8fdb8da12a0a" ;
#   encode3:lab "barbara-wold" ;
#   encode3:award "U54HG006998" .
# <file:///woldlab/castor/home/diane/proj/submission/encode-y3q3/15283-LC_772_C57Bl6_layer_V_pyramidal_neuron_single_cell/15283_H00EWBCXX_c116_l2.fastq.gz>
#   encode3:output_type "reads" ;
#   encode3:read_length 100 ;
#   encode3:file_format "fastq" .
# <http://jumpgate.caltech.edu/wiki/SubmissionsLog/encode-y3q3#15283-LC_772_C57Bl6_layer_V_pyramidal_neuron_single_cell>
#   encode3:dataset "ENCS
C57Bl6_layer_V_pyramidal_neuron_single_cell>
#   encode3:dataset "ENCSR220HFQ" ;
#   encode3:replicate "c7c54a78-68e1-43c6-ac0f-826dc994efc6" ;
#   encode3:lab "barbara-wold" ;
#   encode3:award "U54HG006998" .
# <file:///woldlab/castor/home/diane/proj/submission/encode-y3q3/15352-LC776_C57Bl6_layer_V_pyramidal_neuron_single_cell/15352_H00EWBCXX_c116_l1.fastq.gz>
#   encode3:output_type "reads" ;
#   encode3:read_length 100 ;
#   encode3:file_format "fastq" .
# <http://jumpgate.caltech.edu/wiki/SubmissionsLog/encode-y3q3#15352-LC776_C57Bl6_layer_V_pyramidal_neuron_single_cell>
#   encode3:dataset "ENCSR220HFQ" ;
#   encode3:replicate "c7c54a78-68e1-43c6-ac0f-826dc994efc6" ;
#   encode3:lab "barbara-wold" ;
#   encode3:award "U54HG006998" .
# <file:///woldlab/castor/home/diane/proj/submission/encode-y3q3/15352-LC776_C57Bl6_layer_V_pyramidal_neuron_single_cell/15352_H00EWBCXX_c116_l2.fastq.gz>
#   encode3:output_type "reads" ;
#   encode3:read_length 100 ;
#   encode3:file_format "fastq" .
# <http://jumpgate.caltech.edu/wiki/SubmissionsLog/encode-y3q3#15353-LC777_C57Bl6_layer_V_pyramidal_neuron_single_cell>
#   encode3:dataset "ENCSR298YHA" ;
#   encode3:replicate "76aaf51c-d572-4b69-b81a-66e944a291ee" ;
#   encode3:lab "barbara-wold" ;
#   encode3:award "U54HG006998" .
# <file:///woldlab/castor/home/diane/proj/submission/encode-y3q3/15353-LC777_C57Bl6_layer_V_pyramidal_neuron_single_cell/15353_H00EWBCXX_c116_l1.fastq.gz>
#   encode3:output_type "reads" ;
#   encode3:read_length 100 ;
#   encode3:file_format "fastq" .
# <http://jumpgate.caltech.edu/wiki/SubmissionsLog/encode-y3q3#15353-LC777_C57Bl6_layer_V_pyramidal_neuron_single_cell>
#   encode3:dataset "ENCSR298YHA" ;
#   encode3:replicate "76aaf51c-d572-4b69-b81a-66e944a291ee" ;
#   encode3:lab "barbara-wold" ;
#   encode3:award "U54HG006998" .
# <file:///woldlab/castor/home/diane/proj/submission/encode-y3q3/15353-LC777_C57Bl6_layer_V_pyramidal_neuron_single_cell/15353_H00EWBCXX_c116_l2.fastq.gz>
#   encode3:output_type "reads" ;
#   encode3:read_length 100 ;
#   encode3:file_format "fastq" .
# <http://jumpgate.caltech.edu/wiki/SubmissionsLog/encode-y3q3#15354-LC779_C57Bl6_layer_V_pyramidal_neuron_single_cell>
#   encode3:dataset "ENCSR909YEQ" ;
#   encode3:replicate "bd8aa4cf-01b8-48d2-9641-f98298df2c0a" ;
#   encode3:lab "barbara-wold" ;
#   encode3:award "U54HG006998" .
# <file:///woldlab/castor/home/diane/proj/submission/encode-y3q3/15354-LC779_C57Bl6_layer_V_pyramidal_neuron_single_cell/15354_H00EWBCXX_c116_l2.fastq.gz>
#   encode3:output_type "reads" ;
#   encode3:read_length 100 ;
#   encode3:file_format "fastq" .
# <http://jumpgate.caltech.edu/wiki/SubmissionsLog/encode-y3q3#15354-LC779_C57Bl6_layer_V_pyramidal_neuron_single_cell>
#   encode3:dataset "ENCSR909YEQ" ;
#   encode3:replicate "bd8aa4cf-01b8-48d2-9641-f98298df2c0a" ;
#   encode3:lab "barbara-wold" ;
#   encode3:award "U54HG006998" .
# <file:///woldlab/castor/home/diane/proj/submission/encode-y3q3/15354-LC779_C57Bl6_layer_V_pyramidal_neuron_single_cell/15354_H00EWBCXX_c116_l1.fastq.gz>
#   encode3:output_type "reads" ;
#   encode3:read_length 100 ;
#   encode3:file_format "fastq" .
# <http://jumpgate.caltech.edu/wiki/SubmissionsLog/encode-y3q3#15304-LC_805_C57Bl6_layer_V_pyramidal_neuron_pool-split>
#   encode3:dataset "ENCSR734SOQ" ;
#   encode3:replicate "758908db-a6af-4f95-b9cc-0e9f70fd132d" ;
#   encode3:lab "barbara-wold" ;
#   encode3:award "U54HG006998" .
# <file:///woldlab/castor/home/diane/proj/submission/encode-y3q3/15304-LC_805_C57Bl6_layer_V_pyramidal_neuron_pool-split/15304_H22Y2BCXX_c116_l2.fastq.gz>
#   encode3:output_type "reads" ;
#   encode3:read_length 100 ;
#   encode3:file_format "fastq" .
# <http://jumpgate.caltech.edu/wiki/SubmissionsLog/encode-y3q3#15304-LC_805_C57Bl6_layer_V_pyramidal_neuron_pool-split>
#   encode3:dataset "ENCSR734SOQ" ;
#   encode3:replicate "758908db-a6af-4f95-b9cc-0e9f70fd132d" ;
#   encode3:lab "barbara-wold" ;
#   encode3:award "U54HG006998" .
# <file:///woldlab/castor/home/diane/proj/submission/encode-y3q3/15304-LC_805_C57Bl6_layer_V_pyramidal_neuron_pool-split/15304_H22Y2BCXX_c116_l1.fastq.gz>
#   encode3:output_type "reads" ;
#   encode3:read_length 100 ;
#   encode3:file_format "fastq" .
# <http://jumpgate.caltech.edu/wiki/SubmissionsLog/encode-y3q3#15305-LC_806_C57Bl6_layer_V_pyramidal_neuron_pool-split>
#   encode3:dataset "ENCSR734SOQ" ;
#   encode3:replicate "d5518af9-4640-4ee2-8cdc-137a416e76cd" ;
#   encode3:lab "barbara-wold" ;
#   encode3:award "U54HG006998" .
# <file:///woldlab/castor/home/diane/proj/submission/encode-y3q3/15305-LC_806_C57Bl6_layer_V_pyramidal_neuron_pool-split/15305_H22Y2BCXX_c116_l2.fastq.gz>
#   encode3:output_type "reads" ;
#   encode3:read_length 100 ;
#   encode3:file_format "fastq" .
# <http://jumpgate.caltech.edu/wiki/SubmissionsLog/encode-y3q3#15305-LC_806_C57Bl6_layer_V_pyramidal_neuron_pool-split>
#   encode3:dataset "ENCSR734SOQ" ;
#   encode3:replicate "d5518af9-4640-4ee2-8cdc-137a416e76cd" ;
#   encode3:lab "barbara-wold" ;
#   encode3:award "U54HG006998" .
# <file:///woldlab/castor/home/diane/proj/submission/encode-y3q3/15305-LC_806_C57Bl6_layer_V_pyramidal_neuron_pool-split/15305_H22Y2BCXX_c116_l1.fastq.gz>
#   encode3:output_type "reads" ;
#   encode3:read_length 100 ;
#   encode3:file_format "fastq" .
# <http://jumpgate.caltech.edu/wiki/SubmissionsLog/encode-y3q3#15306-LC_807_C57Bl6_layer_V_pyramidal_neuron_pool-split>
#   encode3:dataset "ENCSR734SOQ" ;
#   encode3:replicate "660353e9-6757-4fe7-a139-376a72407c87" ;
#   encode3:lab "barbara-wold" ;
#   encode3:award "U54HG006998" .
# <file:///woldlab/castor/home/diane/proj/submission/encode-y3q3/15306-LC_807_C57Bl6_layer_V_pyramidal_neuron_pool-split/15306_HBE4EADXX_c116_l1.fastq.gz>
#   encode3:output_type "reads" ;
#   encode3:read_length 100 ;
#   encode3:file_format "fastq" .
# <http://jumpgate.caltech.edu/wiki/SubmissionsLog/encode-y3q3#15306-LC_807_C57Bl6_layer_V_pyramidal_neuron_pool-split>
#   encode3:dataset "ENCSR734SOQ" ;
#   encode3:replicate "660353e9-6757-4fe7-a139-376a72407c87" ;
#   encode3:lab "barbara-wold" ;
#   encode3:award "U54HG006998" .
# <file:///woldlab/castor/home/diane/proj/submission/encode-y3q3/15306-LC_807_C57Bl6_layer_V_pyramidal_neuron_pool-split/15306_HBE4EADXX_c116_l2.fastq.gz>
#   encode3:output_type "reads" ;
#   encode3:read_length 100 ;
#   encode3:file_format "fastq" .
# <http://jumpgate.caltech.edu/wiki/SubmissionsLog/encode-y3q3#15306-LC_807_C57Bl6_layer_V_pyramidal_neuron_pool-split>
#   encode3:dataset "ENCSR734SOQ" ;
#   encode3:replicate "660353e9-6757-4fe7-a139-376a72407c87" ;
#   encode3:lab "barbara-wold" ;
#   encode3:award "U54HG006998" .
# <file:///woldlab/castor/home/diane/proj/submission/encode-y3q3/15306-LC_807_C57Bl6_layer_V_pyramidal_neuron_pool-split/15306_H2KWCBCXX_c116_l1.fastq.gz>
#   encode3:output_type "reads" ;
#   encode3:read_length 100 ;
#   encode3:file_format "fastq" .
# <http://jumpgate.caltech.edu/wiki/SubmissionsLog/encode-y3q3#15306-LC_807_C57Bl6_layer_V_pyramidal_neuron_pool-split>
#   encode3:dataset "ENCSR734SOQ" ;
#   encode3:replicate "660353e9-6757-4fe7-a139-376a72407c87" ;
#   encode3:lab "barbara-wold" ;
#   encode3:award "U54HG006998" .
# <file:///woldlab/castor/home/diane/proj/submission/encode-y3q3/15306-LC_807_C57Bl6_layer_V_pyramidal_neuron_pool-split/15306_H2KWCBCXX_c116_l2.fastq.gz>
#   encode3:output_type "reads" ;
#   encode3:read_length 100 ;
#   encode3:file_format "fastq" .
# <http://jumpgate.caltech.edu/wiki/SubmissionsLog/encode-y3q3#15307-LC_807_C57Bl6_layer_V_pyramidal_neuron_pool-split>
#   encode3:dataset "ENCSR734SOQ" ;
#   encode3:replicate "dca08887-470d-4c35-8328-5d439fffde46" ;
#   encode3:lab "barbara-wold" ;
#   encode3:award "U54HG006998" .
# <file:///woldlab/castor/home/diane/proj/submission/encode-y3q3/15307-LC_807_C57Bl6_layer_V_pyramidal_neuron_pool-split/15307_H22WHBCXX_c116_l2.fastq.gz>
#   encode3:output_type "reads" ;
#   encode3:read_length 100 ;
#   encode3:file_format "fastq" .
# <http://jumpgate.caltech.edu/wiki/SubmissionsLog/encode-y3q3#15307-LC_807_C57Bl6_layer_V_pyramidal_neuron_pool-split>
#   encode3:dataset "ENCSR734SOQ" ;
#   encode3:replicate "dca08887-470d-4c35-8328-5d439fffde46" ;
#   encode3:lab "barbara-wold" ;
#   encode3:award "U54HG006998" .
# <file:///woldlab/castor/home/diane/proj/submission/encode-y3q3/15307-LC_807_C57Bl6_layer_V_pyramidal_neuron_pool-split/15307_H22WHBCXX_c116_l1.fastq.gz>
#   encode3:output_type "reads" ;
#   encode3:read_length 100 ;
#   encode3:file_format "fastq" .
# <http://jumpgate.caltech.edu/wiki/SubmissionsLog/encode-y3q3#15308-LC_808_C57Bl6_layer_V_pyramidal_neuron_pool-split>
#   encode3:dataset "ENCSR734SOQ" ;
#   encode3:replicate "49f0cda6-241e-4290-976e-790160eb9d2d" ;
#   encode3:lab "barbara-wold" ;
#   encode3:award "U54HG006998" .
# <file:///woldlab/castor/home/diane/proj/submission/encode-y3q3/15308-LC_808_C57Bl6_layer_V_pyramidal_neuron_pool-split/15308_H22WHBCXX_c116_l1.fastq.gz>
#   encode3:output_type "reads" ;
#   encode3:read_length 100 ;
#   encode3:file_format "fastq" .
# <http://jumpgate.caltech.edu/wiki/SubmissionsLog/encode-y3q3#15308-LC_808_C57Bl6_layer_V_pyramidal_neuron_pool-split>
#   encode3:dataset "ENCSR734SOQ" ;
#   encode3:replicate "49f0cda6-241e-4290-976e-790160eb9d2d" ;
#   encode3:lab "barbara-wold" ;
#   encode3:award "U54HG006998" .
# <file:///woldlab/castor/home/diane/proj/submission/encode-y3q3/
C57Bl6_layer_V_pyramidal_neuron_pool-split>
#   encode3:dataset "ENCSR734SOQ" ;
#   encode3:replicate "29aae4a9-abde-4f25-b896-eef59d9cbfae" ;
#   encode3:lab "barbara-wold" ;
#   encode3:award "U54HG006998" .
# <file:///woldlab/castor/home/diane/proj/submission/encode-y3q3/15362-LC_819_C57Bl6_layer_V_pyramidal_neuron_pool-split/15362_H00EWBCXX_c116_l1.fastq.gz>
#   encode3:output_type "reads" ;
#   encode3:read_length 100 ;
#   encode3:file_format "fastq" .
# <http://jumpgate.caltech.edu/wiki/SubmissionsLog/encode-y3q3#15362-LC_819_C57Bl6_layer_V_pyramidal_neuron_pool-split>
#   encode3:dataset "ENCSR734SOQ" ;
#   encode3:replicate "29aae4a9-abde-4f25-b896-eef59d9cbfae" ;
#   encode3:lab "barbara-wold" ;
#   encode3:award "U54HG006998" .
# <file:///woldlab/castor/home/diane/proj/submission/encode-y3q3/15362-LC_819_C57Bl6_layer_V_pyramidal_neuron_pool-split/15362_H00EWBCXX_c116_l2.fastq.gz>
#   encode3:output_type "reads" ;
#   encode3:read_length 100 ;
#   encode3:file_format "fastq" .
# <http://jumpgate.caltech.edu/wiki/SubmissionsLog/encode-y3q3#13443-LCMD-501_Mm_Castaneus_x_C57Bl-Purkinje-30-pool>
#   encode3:dataset "ENCSR805QYO" ;
#   encode3:replicate "231cba46-f29b-4af5-88f1-58b417def3da" ;
#   encode3:lab "barbara-wold" ;
#   encode3:award "U54HG006998" .
# <file:///woldlab/castor/home/diane/proj/submission/encode-y3q3/13443-LCMD-501_Mm_Castaneus_x_C57Bl-Purkinje-30-pool/13443_HANWAADXX_c116_l1.fastq.gz>
#   encode3:output_type "reads" ;
#   encode3:read_length 100 ;
#   encode3:file_format "fastq" .
# <http://jumpgate.caltech.edu/wiki/SubmissionsLog/encode-y3q3#13443-LCMD-501_Mm_Castaneus_x_C57Bl-Purkinje-30-pool>
#   encode3:dataset "ENCSR805QYO" ;
#   encode3:replicate "231cba46-f29b-4af5-88f1-58b417def3da" ;
#   encode3:lab "barbara-wold" ;
#   encode3:award "U54HG006998" .
# <file:///woldlab/castor/home/diane/proj/submission/encode-y3q3/13443-LCMD-501_Mm_Castaneus_x_C57Bl-Purkinje-30-pool/13443_D1L1DACXX_c108_l8.fastq.gz>
#   encode3:output_type "reads" ;
#   encode3:read_length 100 ;
#   encode3:file_format "fastq" .
# <http://jumpgate.caltech.edu/wiki/SubmissionsLog/encode-y3q3#13443-LCMD-501_Mm_Castaneus_x_C57Bl-Purkinje-30-pool>
#   encode3:dataset "ENCSR805QYO" ;
#   encode3:replicate "231cba46-f29b-4af5-88f1-58b417def3da" ;
#   encode3:lab "barbara-wold" ;
#   encode3:award "U54HG006998" .
# <file:///woldlab/castor/home/diane/proj/submission/encode-y3q3/13443-LCMD-501_Mm_Castaneus_x_C57Bl-Purkinje-30-pool/13443_HANWAADXX_c116_l2.fastq.gz>
#   encode3:output_type "reads" ;
#   encode3:read_length 100 ;
#   encode3:file_format "fastq" .
# <http://jumpgate.caltech.edu/wiki/SubmissionsLog/encode-y3q3#13444-LCMD-502_Mm_Castaneus_x_C57Bl-Purkinje-30-pool>
#   encode3:dataset "ENCSR805QYO" ;
#   encode3:replicate "09a3e0aa-a3d8-4d5a-b87c-ef74acaa3ca4" ;
#   encode3:lab "barbara-wold" ;
#   encode3:award "U54HG006998" .
# <file:///woldlab/castor/home/diane/proj/submission/encode-y3q3/13444-LCMD-502_Mm_Castaneus_x_C57Bl-Purkinje-30-pool/13444_D1L1DACXX_c108_l8.fastq.gz>
#   encode3:output_type "reads" ;
#   encode3:read_length 100 ;
#   encode3:file_format "fastq" .
# <http://jumpgate.caltech.edu/wiki/SubmissionsLog/encode-y3q3#13444-LCMD-502_Mm_Castaneus_x_C57Bl-Purkinje-30-pool>
#   encode3:dataset "ENCSR805QYO" ;
#   encode3:replicate "09a3e0aa-a3d8-4d5a-b87c-ef74acaa3ca4" ;
#   encode3:lab "barbara-wold" ;
#   encode3:award "U54HG006998" .
# <file:///woldlab/castor/home/diane/proj/submission/encode-y3q3/13444-LCMD-502_Mm_Castaneus_x_C57Bl-Purkinje-30-pool/13444_HAUJ6ADXX_c116_l2.fastq.gz>
#   encode3:output_type "reads" ;
#   encode3:read_length 100 ;
#   encode3:file_format "fastq" .
# <http://jumpgate.caltech.edu/wiki/SubmissionsLog/encode-y3q3#13444-LCMD-502_Mm_Castaneus_x_C57Bl-Purkinje-30-pool>
#   encode3:dataset "ENCSR805QYO" ;
#   encode3:replicate "09a3e0aa-a3d8-4d5a-b87c-ef74acaa3ca4" ;
#   encode3:lab "barbara-wold" ;
#   encode3:award "U54HG006998" .
# <file:///woldlab/castor/home/diane/proj/submission/encode-y3q3/13444-LCMD-502_Mm_Castaneus_x_C57Bl-Purkinje-30-pool/13444_HAUJ6ADXX_c116_l1.fastq.gz>
#   encode3:output_type "reads" ;
#   encode3:read_length 100 ;
#   encode3:file_format "fastq" .
# <http://jumpgate.caltech.edu/wiki/SubmissionsLog/encode-y3q3#13445-LCMD-503_Mm_Castaneus_x_C57Bl-granule-layer-area-dissection>
#   encode3:dataset "ENCSR822EWO" ;
#   encode3:replicate "387733b1-edcb-4884-bca4-ef26bb1b9a8d" ;
#   encode3:lab "barbara-wold" ;
#   encode3:award "U54HG006998" .
# <file:///woldlab/castor/home/diane/proj/submission/encode-y3q3/13445-LCMD-503_Mm_Castaneus_x_C57Bl-granule-layer-area-dissection/13445_D1L1DACXX_c108_l7.fastq.gz>
#   encode3:output_type "reads" ;
#   encode3:read_length 100 ;
#   encode3:file_format "fastq" .
# <http://jumpgate.caltech.edu/wiki/SubmissionsLog/encode-y3q3#13445-LCMD-503_Mm_Castaneus_x_C57Bl-granule-layer-area-dissection>
#   encode3:dataset "ENCSR822EWO" ;
#   encode3:replicate "387733b1-edcb-4884-bca4-ef26bb1b9a8d" ;
#   encode3:lab "barbara-wold" ;
#   encode3:award "U54HG006998" .
# <file:///woldlab/castor/home/diane/proj/submission/encode-y3q3/13445-LCMD-503_Mm_Castaneus_x_C57Bl-granule-layer-area-dissection/13445_HANWAADXX_c116_l2.fastq.gz>
#   encode3:output_type "reads" ;
#   encode3:read_length 100 ;
#   encode3:file_format "fastq" .
# <http://jumpgate.caltech.edu/wiki/SubmissionsLog/encode-y3q3#13445-LCMD-503_Mm_Castaneus_x_C57Bl-granule-layer-area-dissection>
#   encode3:dataset "ENCSR822EWO" ;
#   encode3:replicate "387733b1-edcb-4884-bca4-ef26bb1b9a8d" ;
#   encode3:lab "barbara-wold" ;
#   encode3:award "U54HG006998" .
# <file:///woldlab/castor/home/diane/proj/submission/encode-y3q3/13445-LCMD-503_Mm_Castaneus_x_C57Bl-granule-layer-area-dissection/13445_HANWAADXX_c116_l1.fastq.gz>
#   encode3:output_type "reads" ;
#   encode3:read_length 100 ;
#   encode3:file_format "fastq" .
# <http://jumpgate.caltech.edu/wiki/SubmissionsLog/encode-y3q3#13446-LCMD-504_Mm_Castaneus_x_C57Bl-granule-layer-area-dissection>
#   encode3:dataset "ENCSR822EWO" ;
#   encode3:replicate "3d6b0e2d-2a95-47a3-a92c-abd81e67e29a" ;
#   encode3:lab "barbara-wold" ;
#   encode3:award "U54HG006998" .
# <file:///woldlab/castor/home/diane/proj/submission/encode-y3q3/13446-LCMD-504_Mm_Castaneus_x_C57Bl-granule-layer-area-dissection/13446_HANWAADXX_c116_l2.fastq.gz>
#   encode3:output_type "reads" ;
#   encode3:read_length 100 ;
#   encode3:file_format "fastq" .
# <http://jumpgate.caltech.edu/wiki/SubmissionsLog/encode-y3q3#13446-LCMD-504_Mm_Castaneus_x_C57Bl-granule-layer-area-dissection>
#   encode3:dataset "ENCSR822EWO" ;
#   encode3:replicate "3d6b0e2d-2a95-47a3-a92c-abd81e67e29a" ;
#   encode3:lab "barbara-wold" ;
#   encode3:award "U54HG006998" .
# <file:///woldlab/castor/home/diane/proj/submission/encode-y3q3/13446-LCMD-504_Mm_Castaneus_x_C57Bl-granule-layer-area-dissection/13446_HANWAADXX_c116_l1.fastq.gz>
#   encode3:output_type "reads" ;
#   encode3:read_length 100 ;
#   encode3:file_format "fastq" .
# <http://jumpgate.caltech.edu/wiki/SubmissionsLog/encode-y3q3#13446-LCMD-504_Mm_Castaneus_x_C57Bl-granule-layer-area-dissection>
#   encode3:dataset "ENCSR822EWO" ;
#   encode3:replicate "3d6b0e2d-2a95-47a3-a92c-abd81e67e29a" ;
#   encode3:lab "barbara-wold" ;
#   encode3:award "U54HG006998" .
# <file:///woldlab/castor/home/diane/proj/submission/encode-y3q3/13446-LCMD-504_Mm_Castaneus_x_C57Bl-granule-layer-area-dissection/13446_D1L1DACXX_c108_l7.fastq.gz>
#   encode3:output_type "reads" ;
#   encode3:read_length 100 ;
#   encode3:file_format "fastq" .
# generated 100 records
# /usr/lib/python3/dist-packages/paramiko/client.py:580: UserWarning: Unknown ssh-rsa host key for pongo.cacr.caltech.edu: b'6833531597d6176b45c27f33e9406a12'
#   (key.get_name(), hostname, hexlify(key.get_fingerprint())))

# %%
make_manifest(spreadsheet_name, 'proj/submission/encode-y3q3', 'human-liver.txt')
# Out:
# <http://jumpgate.caltech.edu/wiki/SubmissionsLog/encode-y3q3#15096-paired-end-human_liver_STL010_10ngs>
#   encode3:dataset "ENCSR388ZNJ" ;
#   encode3:replicate "a37a8cff-5bf7-47fc-b9a0-fa2aafebb9c3" ;
#   encode3:lab "barbara-wold" ;
#   encode3:award "U54HG006998" .
# <file:///woldlab/castor/home/diane/proj/submission/encode-y3q3/15096-paired-end-human_liver_STL010_10ngs/15096_H00EWBCXX_c116_l2.fastq.gz>
#   encode3:output_type "reads" ;
#   encode3:read_length 100 ;
#   encode3:file_format "fastq" .
# <http://jumpgate.caltech.edu/wiki/SubmissionsLog/encode-y3q3#15096-paired-end-human_liver_STL010_10ngs>
#   encode3:dataset "ENCSR388ZNJ" ;
#   encode3:replicate "a37a8cff-5bf7-47fc-b9a0-fa2aafebb9c3" ;
#   encode3:lab "barbara-wold" ;
#   encode3:award "U54HG006998" .
# <file:///woldlab/castor/home/diane/proj/submission/encode-y3q3/15096-paired-end-human_liver_STL010_10ngs/15096_H00EWBCXX_c116_l1.fastq.gz>
#   encode3:output_type "reads" ;
#   encode3:read_length 100 ;
#   encode3:file_format "fastq" .
# <http://jumpgate.caltech.edu/wiki/SubmissionsLog/encode-y3q3#15097-paired-end-human_liver_STL011_10ngs>
#   encode3:dataset "ENCSR388ZNJ" ;
#   encode3:replicate "384e35e0-74bc-4c00-be81-571a2ca6613f" ;
#   encode3:lab "barbara-wold" ;
#   encode3:award "U54HG006998" .
# <file:///woldlab/castor/home/diane/proj/submission/encode-y3q3/15097-paired-end-human_liver_STL011_10ngs/15097_HCCLHADXX_c116_l1.fastq.gz>
#   encode3:output_type "reads" ;
#   encode3:read_length 100 ;
#   encode3:file_format "fastq" .
# <http://jumpgate.caltech.edu/wiki/SubmissionsLog/encode-y3q3#15097-paired-end-human_liver_STL011_10ngs>
#   encode3:dataset "ENCSR388ZNJ" ;
#   encode3:replicate "384e35e0-74bc-4c00-be81-571a2ca6613f" ;
#   encode3:lab "barbara-wold" ;
#   encode3:award "U54HG006998" .
# <file:///woldlab/castor/home/diane/proj/submission/encode-y3q3/15097-paired-end-human_liver_STL011_10ngs/15097_HCCLHADXX_c116_l2.fastq.gz>
#   encode3:output_type "reads" ;
#   encode3:read_length 100 ;
#   encode3:file_format "fastq" .
# generated 4 records
# /usr/lib/python3/dist-packages/paramiko/client.py:580: UserWarning: Unknown ssh-rsa host key for pongo.cacr.caltech.edu: b'6833531597d6176b45c27f33e9406a12'
#   (key.get_name(), hostname, hexlify(key.get_fingerprint())))
